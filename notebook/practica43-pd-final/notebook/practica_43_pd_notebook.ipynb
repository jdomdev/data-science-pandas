# %% [markdown]
# # Práctica 43: Limpieza, manejo y transformación de datos con Pandas

# %% [markdown]
# ####  Cargar el fichero **retail2.csv** en un dataframe de Pandas y efectuar todas las operaciones de consulta, exploración y limpieza de datos que sean necesarios algunos pasos de limpieza están de forma explícita como preguntas. Los ficheros contienen varias columnas y algunas de ellas tienen datos que podrían necesitar limpieza o tratamiento.

# %% [markdown]
# **El fichero contiene información sobre transacciones de una tienda minorista. Los campos y su significado se muestran a continuación:**

# %% [markdown]
# `InvoiceNo`: Número de factura que identifica de manera única cada transacción.
#
#
# `StockCode`:Código de stock que identifica de manera única cada producto.
#
#
# `Descrption`.Descripción del producto.
#
#
# `Quantity`: Cantidad de productos comprados (puede contener valores negativos que indican devoluciones).
#
# `InvoiceDate`: Fecha y hora en que se realizó la transacción.
#
#
# `UnitPrice`:Precio unitario del producto (algunos valores pueden estar en centavos en lugar de dólares).
#
#
# `CustomerID`:ID único del cliente que realizó la compra.
#
#
# `Country`:País donde reside el cliente (puede contener inconsistencias en mayúsculas/minúsculas y caracteres especiales).
#
# `CustomerName`:Nombre completo del cliente.
#
#
# `Email`:Dirección de correo electrónico del cliente.
#
# `Address`:Dirección del cliente.
#
#
#
# `PhoneNumber`:Número de teléfono del cliente.
#
#
#
# `Category`: Categoría del producto (por ejemplo, 'Electronics', 'Clothing', 'Home & Garden').
#
# `Supplier`: Proveedor del producto.
#
# `StockLevel`: Nivel de inventario del producto.
#
# `Discount`: Descuento aplicado al producto (en porcentaje).
#
# `SaleChannel`: Canal de venta (por ejemplo, 'Online', 'In-Store').
#
# `ReturnStatus`: Estado de devolución del producto ('Returned', 'Not Returned').
#
# `ProductWeight`: Peso del producto. Unidad: kilogramos.
#
# `ProductDimensions`: Dimensiones del producto. Unidad: en el formato 'LxWxH cm'.
#
# `ShippingCost`: Costo de envío. Unidad:dólares.
#
# `SalesRegion`: Región de ventas (por ejemplo, 'North America', 'Europe', 'Asia').
#
# `PromotionCode`: Código de promoción aplicado a la compra.
#
# `PaymentMethod`: Método de pago (por ejemplo, 'Credit Card', 'PayPal', 'Bank Transfer').

# %% [markdown]
# # Parte 1. Data Cleaning and Preparation (Capítulo 7 - Wes McKinney)

# %% [markdown]
# - Cargue los datasets `retail2.csv` y `exchange_rates.csv` en DataFrames de pandas.

# %%
# Importación biblioteca pandas
import pandas as pd

# %%
# Lectura fichero csv 
# retail2_df = pd.read_csv("../data/retail2.csv", sep=',', header=0, index_col=0) # Con argumentos
retail2_df = pd.read_csv("../data/retail2.csv") # Sin argumentos
# Visualización
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 4        NaN     22634    {"description": "BAKING SET 9 PIECE RETROSPOT"}
#
#   Quantity      InvoiceDate UnitPrice  CustomerID         Country  \
# 0        6  12/1/2010 12:28      4.25       17763  United Kingdom
# 1      100  12/1/2010 10:16     795.0       15939  United Kingdom
# 2        6  12/1/2010 13:23      1.85       12295  United Kingdom
# 3       10  12/1/2010 11:32      1.65       15685  United Kingdom
# 4        6  12/1/2010 11:07      4.95       11696  United Kingdom
#
#      CustomerName                      Email  ... StockLevel Discount  \
# 0   David Johnson     david.johnson@mail.com  ...        853    17.28
# 1  Henry Williams    henry.williams@test.org  ...        910     9.08
# 2      Jane Brown        jane.brown@mail.com  ...        578    45.42
# 3   Frank Johnson  frank.johnson@example.com  ...         75    29.17
# 4       Eva Smith         eva.smith@mail.com  ...        435    20.04
#
#   SaleChannel  ReturnStatus  ProductWeight  ProductDimensions ShippingCost  \
# 0      Online  Not Returned           3.81        37x38x83 cm         7.14
# 1      Online  Not Returned           9.51         8x65x86 cm        12.48
# 2    In-Store      Returned           7.35        17x71x89 cm        14.27
# 3      Online      Returned           6.03         45x4x36 cm        15.54
# 4      Online  Not Returned           1.64        70x31x19 cm        13.39
#
#      SalesRegion  PromotionCode  PaymentMethod
# 0  North America         SALE15  Bank Transfer
# 1           Asia         SALE15  Bank Transfer
# 2  North America      DISCOUNT5  Bank Transfer
# 3           Asia            NaN         PayPal
# 4      Australia        PROMO10  Bank Transfer
#
# [5 rows x 24 columns]

# %%
# Lectura fichero csv 
exchange_rates_df = pd.read_csv("../data/exchange_rates.csv")
# Visualización
exchange_rates_df.head()
# Out:
#          Date  ExchangeRate
# 0  2020-01-01          1.20
# 1  2020-01-02          1.19
# 2  2020-01-03          1.18
# 3  2020-01-04          1.21
# 4  2020-01-05          1.20

# %%
exchange_rates_df.shape
# Out:
# (60, 2)

# %% [markdown]
# ## Pregunta 1
# **Identificación de valores faltantes:**
# - Identifique las columnas con valores faltantes en el dataset `retail`.

# %%
# Contabilización valores faltantes por columna
missing_values = retail2_df.isnull().sum()
# Visualización de las columnas con valores faltantes
missing_columns = missing_values[missing_values > 0]
print(missing_columns)
# Out:
# InvoiceNo        20
# Description      27
# InvoiceDate       5
# Country           1
# PromotionCode    81
# dtype: int64

# %% [markdown]
# ## Pregunta 2
# **Eliminar valores faltantes:**
# - Elimine las filas del dataset `retail` donde las columnas críticas (`InvoiceNo`, `StockCode`, `Quantity`, `UnitPrice`, `CustomerID`) tengan valores faltantes.

# %%
# Filas x columnas df original
retail2_df.shape
# Out:
# (440, 24)

# %%
# Eliminación de filas de las columnas críticas con valores faltantes
critical_columns = ['InvoiceNo', 'StockCode', 'Quantity', 'UnitPrice', 'CustomerID']
retail2_df = retail2_df.dropna(subset=critical_columns)
# Visualización dataframe limpio
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#   Quantity      InvoiceDate UnitPrice  CustomerID         Country  \
# 0        6  12/1/2010 12:28      4.25       17763  United Kingdom
# 1      100  12/1/2010 10:16     795.0       15939  United Kingdom
# 2        6  12/1/2010 13:23      1.85       12295  United Kingdom
# 3       10  12/1/2010 11:32      1.65       15685  United Kingdom
# 5        6  12/1/2010 14:24      4.25       11946  United Kingdom
#
#      CustomerName                      Email  ... StockLevel Discount  \
# 0   David Johnson     david.johnson@mail.com  ...        853    17.28
# 1  Henry Williams    henry.williams@test.org  ...        910     9.08
# 2      Jane Brown        jane.brown@mail.com  ...        578    45.42
# 3   Frank Johnson  frank.johnson@example.com  ...         75    29.17
# 5     Alice Smith       alice.smith@mail.com  ...        103    23.10
#
#   SaleChannel  ReturnStatus  ProductWeight  ProductDimensions ShippingCost  \
# 0      Online  Not Returned           3.81        37x38x83 cm         7.14
# 1      Online  Not Returned           9.51         8x65x86 cm        12.48
# 2    In-Store      Returned           7.35        17x71x89 cm        14.27
# 3      Online      Returned           6.03         45x4x36 cm        15.54
# 5    In-Store      Returned           1.64        61x54x39 cm         5.15
#
#      SalesRegion  PromotionCode  PaymentMethod
# 0  North America         SALE15  Bank Transfer
# 1           Asia         SALE15  Bank Transfer
# 2  North America      DISCOUNT5  Bank Transfer
# 3           Asia            NaN         PayPal
# 5  North America        PROMO20         PayPal
#
# [5 rows x 24 columns]

# %%
# Filas x columnas df limpio
retail2_df.shape
# Out:
# (420, 24)

# %% [markdown]
# ## Pregunta 3
# **Conversión de tipos de datos:**
# - Convierta la columna `InvoiceDate` del dataset `retail` a un formato de datetime.

# %%
# Tipo de dato de columna 'InvoiceDate' ANTES de transformación
print(retail2_df['InvoiceDate'].dtype)
# Out:
# object

# %%
# Función para recoger las fechas que no se pueden transformar
def check_invalid_dates(date_series):
    invalid_dates = []
    for date in date_series:
        try:
            # Intentar convertir la fecha
            pd.to_datetime(date, format='%d/%m/%Y %H:%M')
        except (ValueError, TypeError):
            # Si hay un error, agregar la fecha a la lista de fechas inválidas
            invalid_dates.append(date)
    return invalid_dates

# Aplicar la función a la columna 'InvoiceDate'
invalid_dates = check_invalid_dates(retail2_df['InvoiceDate'])

# Mostrar las fechas problemáticas
invalid_dates
# Out:
# ['01/12/2010 25:61',
#  '30/02/2010 00:00',
#  'Date: 12/1/2010 14:26',
#  '30/02/2010 00:00',
#  '01-12-2010 10:09',
#  'Date: 12/1/2010 13:46',
#  '01/12/2010 25:61',
#  '01/12/2010 25:61',
#  '01/12/2010 25:61',
#  '01/12/2010 25:61',
#  '01-12-2010 11:27',
#  'Date: 12/1/2010 9:14',
#  'Date: 01/01/2050 00:00',
#  '01/12/2010 25:61',
#  'Date: 12/1/2010 9:23',
#  '01-12-2010 09:47',
#  '30/02/2010 00:00',
#  '01/12/2010 25:61',
#  '01/12/2010 25:61',
#  'Date: 12/1/2010 11:05',
#  '01/12/2010 25:61',
#  'Date: 12/1/2010 15:02',
#  '30/02/2010 00:00',
#  'Date: 12/1/2010 14:47',
#  '01-12-2010 13:42',
#  '30/02/2010 00:00',
#  'Date: 12/1/2010 9:33',
#  '30/02/2010 00:00',
#  '01/12/2010 25:61',
#  'Date: 12/1/2010 14:43']

# %%
import numpy as np

def clean_date(date):
    if pd.isna(date):
        return np.nan
    # Transformación de tipo('InvoiceDate': object -> 'CleanedInvoiceDate': string)
    date_str = str(date)
    # Eliminación de espacios
    date_str = date_str.strip()
    # Elimina non-breaking spaces y otros caracteres
    date_str = date_str.replace('\xa0', ' ').strip()
    # Eliminación de espacios múltiples
    import re
    date_str = re.sub(r'\s+', ' ', date_str).strip()  
    # TEST:
    # print([c for c in date_str]) # Muestra cada carácter en la cadena
    # print(date_str.encode('utf-8')) # Muestra la representación en bytes

    # Eliminar prefijo "Date:"
    date_str = date_str.split('Date:')[-1]
    # Clave para fechas que además de ir precedidas de la cadena 'Date:' 
    # también llevan un espacio antes
    date_str = date_str.strip()
    # Reemplazar los separadores de fecha no estándar
    date_str = date_str.replace('-', '/')
    # Test
    # print(f"** CLEANED Date: {date_str}")
    
    # Comprobación si la fecha es Febrero y tiene 28 días de máximo
    month_numb = int(date_str.split(' ')[0].split('/')[1])
    if month_numb == 2:
        day_numb = int(date_str.split(' ')[0].split('/')[0])
        if day_numb > 28:
            date_str = date_str.replace(date_str.split(' ')[0].split('/')[0], '28')

    # Extracción de la hora y los minutos de la fecha
    # y conversión a entero
    hour_numb = int(date_str.split(' ')[1].split(':')[0])
    min_numb = int(date_str.split(' ')[1].split(':')[1])
    # Comprobación de hora y minuto y cambio en la fecha de tipo string
    if hour_numb > 23:
        date_str = date_str.replace(date_str.split(' ')[1].split(':')[0], '00')        
    if min_numb > 59:
        date_str = date_str.replace(date_str.split(' ')[1].split(':')[1], '59')
    
    return date_str

# Aplicar la limpieza
retail2_df['CleanedInvoiceDate'] = retail2_df['InvoiceDate'].apply(clean_date)
# Conversión forzada de columna 'InvoiceDate' a datetime
# retail2_df['InvoiceDate'] = pd.to_datetime(retail2_df['CleanedInvoiceDate'], 
#                                           format='%d/%m/%Y %H:%M', 
#                                           errors='coerce')
#print(retail2_df.head(20))
retail2_df['CleanedInvoiceDate'] = pd.to_datetime(retail2_df['CleanedInvoiceDate'], 
                                                    format='%d/%m/%Y %H:%M', 
                                                    errors='coerce')
retail2_df[15:25]
# Out:
#     InvoiceNo StockCode                                        Description  \
# 16   536676.0     22749            ***FELTCRAFT PRINCESS CHARLOTTE DOLL***
# 17   536375.0     22960  ["description": "JAM MAKING SET WITH JARS: det...
# 18   536457.0     22960                     ***JAM MAKING SET WITH JARS***
# 19   536696.0     22112                         CHOCOLATE HOT WATER BOTTLE
# 20   536695.0     22139                    RETROSPOT TEA SET CERAMIC 11 PC
# 21   536443.0     22112                         CHOCOLATE HOT WATER BOTTLE
# 22   536587.0     21724                               RED HARMONICA IN BOX
# 23   536628.0    84029G                KNITTED UNION FLAG HOT WATER BOTTLE
# 26   536683.0     21777     {"description": "RECIPE BOX WITH METAL HEART"}
# 27   536608.0     22112                         CHOCOLATE HOT WATER BOTTLE
#
#    Quantity            InvoiceDate UnitPrice  CustomerID  \
# 16        8       01/12/2010 25:61      3.75       15085
# 17        6       30/02/2010 00:00      4.25       15637
# 18        6        12/1/2010 10:27      4.25       11116
# 19       10  Date: 12/1/2010 14:26      3.39       10492
# 20       -6        12/1/2010 14:25      6.95       18811
# 21       10        12/1/2010 10:13      3.39       17888
# 22       10        12/1/2010 12:37      1.25       16474
# 23        6       30/02/2010 00:00      3.39       19738
# 26        4        12/1/2010 14:13      7.95       19467
# 27       10        12/1/2010 12:58      3.39       12743
#
#                                       Country   CustomerName  \
# 16  ### FELTCRAFT PRINCESS CHARLOTTE DOLL ###   John Johnson
# 17                             United Kingdom   Grace Wilson
# 18                             United Kingdom   Alice Taylor
# 19                             United Kingdom     Bob Wilson
# 20                             United Kingdom   John Johnson
# 21                             United Kingdom      Eva Jones
# 22                             United Kingdom   David Taylor
# 23                             United Kingdom    Alice Smith
# 26                             United Kingdom   David Wilson
# 27                             United Kingdom  Alice Johnson
#
#                         Email  ... Discount SaleChannel  ReturnStatus  \
# 16   john.johnson@example.com  ...    46.12      Online      Returned
# 17   grace.wilson@example.com  ...    35.36    In-Store  Not Returned
# 18      alice.taylor@demo.net  ...     7.63      Online  Not Returned
# 19     bob.wilson@example.com  ...    28.81      Online      Returned
# 20      john.johnson@demo.net  ...    30.34    In-Store  Not Returned
# 21         eva.jones@demo.net  ...    21.21      Online      Returned
# 22      david.taylor@demo.net  ...    36.82      Online  Not Returned
# 23    alice.smith@example.com  ...    46.72    In-Store      Returned
# 26      david.wilson@mail.com  ...     5.66      Online  Not Returned
# 27  alice.johnson@example.com  ...    49.24    In-Store  Not Returned
#
#    ProductWeight  ProductDimensions  ShippingCost    SalesRegion  \
# 16          3.11        45x61x47 cm         17.01      Australia
# 17          5.30        21x80x85 cm          8.00  South America
# 18          4.38        75x36x99 cm          7.51  South America
# 19          2.98        19x20x57 cm          6.57  South America
# 20          6.16        18x47x49 cm         14.55         Europe
# 21          1.48        14x15x31 cm         15.60      Australia
# 22          2.99          1x54x3 cm          5.47  South America
# 23          3.73        16x87x57 cm         19.04      Australia
# 26          2.08        76x24x28 cm         15.64  South America
# 27          5.19         8x92x36 cm         18.06      Australia
#
#    PromotionCode  PaymentMethod  CleanedInvoiceDate
# 16     DISCOUNT5      Gift Card 2010-12-01 00:59:00
# 17        SALE15  Bank Transfer 2010-02-28 00:00:00
# 18       PROMO10           Cash 2010-01-12 10:27:00
# 19     DISCOUNT5         PayPal 2010-01-12 14:26:00
# 20       PROMO20           Cash 2010-01-12 14:25:00
# 21     DISCOUNT5    Credit Card 2010-01-12 10:13:00
# 22     DISCOUNT5    Credit Card 2010-01-12 12:37:00
# 23           NaN      Gift Card 2010-02-28 00:00:00
# 26        SALE15           Cash 2010-01-12 14:13:00
# 27       PROMO20    Credit Card 2010-01-12 12:58:00
#
# [10 rows x 25 columns]

# %%
# Reordenación Columnas
# IMPORTANTE: Hay que convertir 'retail2_df.columns' de 'index' a 'list'
old_order_list = list(retail2_df.columns)
new_order_list = ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 
                  'InvoiceDate', 'CleanedInvoiceDate','UnitPrice', 'CustomerID', 'Country',
                  'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier',
                  'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight',
                  'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode', 
                  'PaymentMethod']
retail2_df = retail2_df[new_order_list]
retail2_df[16:24]
# Out:
#     InvoiceNo StockCode                                        Description  \
# 17   536375.0     22960  ["description": "JAM MAKING SET WITH JARS: det...
# 18   536457.0     22960                     ***JAM MAKING SET WITH JARS***
# 19   536696.0     22112                         CHOCOLATE HOT WATER BOTTLE
# 20   536695.0     22139                    RETROSPOT TEA SET CERAMIC 11 PC
# 21   536443.0     22112                         CHOCOLATE HOT WATER BOTTLE
# 22   536587.0     21724                               RED HARMONICA IN BOX
# 23   536628.0    84029G                KNITTED UNION FLAG HOT WATER BOTTLE
# 26   536683.0     21777     {"description": "RECIPE BOX WITH METAL HEART"}
#
#    Quantity            InvoiceDate  CleanedInvoiceDate UnitPrice  CustomerID  \
# 17        6       30/02/2010 00:00 2010-02-28 00:00:00      4.25       15637
# 18        6        12/1/2010 10:27 2010-01-12 10:27:00      4.25       11116
# 19       10  Date: 12/1/2010 14:26 2010-01-12 14:26:00      3.39       10492
# 20       -6        12/1/2010 14:25 2010-01-12 14:25:00      6.95       18811
# 21       10        12/1/2010 10:13 2010-01-12 10:13:00      3.39       17888
# 22       10        12/1/2010 12:37 2010-01-12 12:37:00      1.25       16474
# 23        6       30/02/2010 00:00 2010-02-28 00:00:00      3.39       19738
# 26        4        12/1/2010 14:13 2010-01-12 14:13:00      7.95       19467
#
#            Country  CustomerName  ... StockLevel Discount SaleChannel  \
# 17  United Kingdom  Grace Wilson  ...        435    35.36    In-Store
# 18  United Kingdom  Alice Taylor  ...        447     7.63      Online
# 19  United Kingdom    Bob Wilson  ...        994    28.81      Online
# 20  United Kingdom  John Johnson  ...        308    30.34    In-Store
# 21  United Kingdom     Eva Jones  ...        249    21.21      Online
# 22  United Kingdom  David Taylor  ...        166    36.82      Online
# 23  United Kingdom   Alice Smith  ...        481    46.72    In-Store
# 26  United Kingdom  David Wilson  ...        542     5.66      Online
#
#     ReturnStatus ProductWeight  ProductDimensions  ShippingCost  \
# 17  Not Returned          5.30        21x80x85 cm          8.00
# 18  Not Returned          4.38        75x36x99 cm          7.51
# 19      Returned          2.98        19x20x57 cm          6.57
# 20  Not Returned          6.16        18x47x49 cm         14.55
# 21      Returned          1.48        14x15x31 cm         15.60
# 22  Not Returned          2.99          1x54x3 cm          5.47
# 23      Returned          3.73        16x87x57 cm         19.04
# 26  Not Returned          2.08        76x24x28 cm         15.64
#
#       SalesRegion PromotionCode  PaymentMethod
# 17  South America        SALE15  Bank Transfer
# 18  South America       PROMO10           Cash
# 19  South America     DISCOUNT5         PayPal
# 20         Europe       PROMO20           Cash
# 21      Australia     DISCOUNT5    Credit Card
# 22  South America     DISCOUNT5    Credit Card
# 23      Australia           NaN      Gift Card
# 26  South America        SALE15           Cash
#
# [8 rows x 25 columns]

# %%
# Filtrar filas con problemas
# La virgulilla se utiliza para seleccionar las filas donde la conversión de fecha falló, 
# es decir, donde InvoiceDate no pudo convertirse correctamente a una fecha válida
problem_rows = retail2_df[~pd.to_datetime(retail2_df['InvoiceDate'], 
                                          errors='coerce', 
                                          dayfirst=True).notna()]
print(problem_rows)
# Out:
#      InvoiceNo                       StockCode  \
# 16    536676.0                           22749
# 17    536375.0                           22960
# 19    536696.0                           22112
# 23    536628.0                          84029G
# 32    536439.0                           21914
# 49    536584.0  SET 2 TEA TOWELS I LOVE LONDON
# 54    536656.0                           21731
# 58    536455.0                           21914
# 82    536432.0                           21756
# 90    536605.0                           21731
# 105   536630.0                           22752
# 114   536517.0                           21731
# 116   536384.0                           22570
# 173   536519.0                           22139
# 174   536390.0                           22752
# 183   536393.0                           22111
# 195   536475.0                           22748
# 223   536417.0                           21730
# 231   536604.0                           21914
# 261   536464.0                          85123A
# 281   536630.0                           22752
# 285   536669.0                           22752
# 303   536568.0                          84029E
# 315   536495.0                           22139
# 318   536673.0                           84879
# 335   536732.0                           22633
# 342   536388.0                           22745
# 346   536441.0                           22960
# 364   536717.0                           21731
# 396   536652.0                          85123A
# 415   536375.0                           22960
# 418   536403.0                          84907B
# 421   536369.0                           21756
# 430   536370.0                           21724
# 431   536713.0                          85123A
#
#                                            Description Quantity  \
# 16             ***FELTCRAFT PRINCESS CHARLOTTE DOLL***        8
# 17   ["description": "JAM MAKING SET WITH JARS: det...        6
# 19                          CHOCOLATE HOT WATER BOTTLE       10
# 23                 KNITTED UNION FLAG HOT WATER BOTTLE        6
# 32                                                 NaN       12
# 49                                           ***nan***        3
# 54                       RED TOADSTOOL LED NIGHT LIGHT       12
# 58            {"description": "BLUE HARMONICA IN BOX"}       12
# 82                                 DOORMAT NEW ENGLAND        6
# 90                       RED TOADSTOOL LED NIGHT LIGHT       12
# 105                       SET 7 BABUSHKA NESTING BOXES        2
# 114                      RED TOADSTOOL LED NIGHT LIGHT       12
# 116  {"description": "{"description": "RED GLASS CA...        6
# 173  ["description": "RETROSPOT TEA SET CERAMIC 11 ...        6
# 174                       SET 7 BABUSHKA NESTING BOXES        2
# 183                          SCANDINAVIAN REDS RIBBONS       10
# 195                          POPPY'S PLAYHOUSE KITCHEN       60
# 223                                                NaN        6
# 231                              BLUE HARMONICA IN BOX       12
# 261                 WHITE HANGING HEART T-LIGHT HOLDER        6
# 281                       SET 7 BABUSHKA NESTING BOXES  unknown
# 285                       SET 7 BABUSHKA NESTING BOXES        2
# 303                     RED WOOLLY HOTTIE WHITE HEART.        6
# 315                              InvalidDescription123        6
# 318                      ASSORTED COLOUR BIRD ORNAMENT       32
# 335                             HAND WARMER UNION JACK        6
# 342                    ***POPPY'S PLAYHOUSE BEDROOM***        6
# 346                           JAM MAKING SET WITH JARS        6
# 364                ***RED TOADSTOOL LED NIGHT LIGHT***       12
# 396                 WHITE HANGING HEART T-LIGHT HOLDER        6
# 415  ["description": "JAM MAKING SET WITH JARS: det...        6
# 418  {"description": ["PACK OF 12 RED RETROSPOT TIS...      200
# 421                                DOORMAT NEW ENGLAND        6
# 430                              RED  HARMONICA IN BOX       10
# 431                 WHITE HANGING HEART T-LIGHT HOLDER        6
#
#                 InvoiceDate  CleanedInvoiceDate UnitPrice  CustomerID  \
# 16         01/12/2010 25:61 2010-12-01 00:59:00      3.75       15085
# 17         30/02/2010 00:00 2010-02-28 00:00:00      4.25       15637
# 19    Date: 12/1/2010 14:26 2010-01-12 14:26:00      3.39       10492
# 23         30/02/2010 00:00 2010-02-28 00:00:00      3.39       19738
# 32         01-12-2010 10:09 2010-12-01 10:09:00      1.25       18548
# 49                      NaN                 NaT      4.95       13212
# 54    Date: 12/1/2010 13:46 2010-01-12 13:46:00      1.65       17594
# 58         01/12/2010 25:61 2010-12-01 00:59:00      1.25       16236
# 82         01/12/2010 25:61 2010-12-01 00:59:00      7.95       19653
# 90         01/12/2010 25:61 2010-12-01 00:59:00      1.65       14422
# 105        01/12/2010 25:61 2010-12-01 00:59:00      7.65       13162
# 114        01-12-2010 11:27 2010-12-01 11:27:00      1.65       11913
# 116    Date: 12/1/2010 9:14 2010-01-12 09:14:00      2.95       15520
# 173  Date: 01/01/2050 00:00 2050-01-01 00:00:00      6,95       13240
# 174        01/12/2010 25:61 2010-12-01 00:59:00      7.65       16028
# 183    Date: 12/1/2010 9:23 2010-01-12 09:23:00      1.65       13450
# 195                     NaN                 NaT     210.0       13722
# 223        01-12-2010 09:47 2010-12-01 09:47:00      4.25       12120
# 231                     NaN                 NaT      1.25       17742
# 261        30/02/2010 00:00 2010-02-28 00:00:00      2.55       10992
# 281        01/12/2010 25:61 2010-12-01 00:59:00   unknown       13093
# 285        01/12/2010 25:61 2010-12-01 00:59:00      7.65       13277
# 303                     NaN                 NaT      3.39       17236
# 315   Date: 12/1/2010 11:05 2010-01-12 11:05:00      6.95       12606
# 318        01/12/2010 25:61 2010-12-01 00:59:00      1.69       16432
# 335   Date: 12/1/2010 15:02 2010-01-12 15:02:00      1.85       15693
# 342                     NaN                 NaT       2.1       11988
# 346        30/02/2010 00:00 2010-02-28 00:00:00      4.25       16241
# 364   Date: 12/1/2010 14:47 2010-01-12 14:47:00      1.65       15178
# 396        01-12-2010 13:42 2010-12-01 13:42:00      2.55       10369
# 415        30/02/2010 00:00 2010-02-28 00:00:00      4.25       18342
# 418    Date: 12/1/2010 9:33 2010-01-12 09:33:00      85.0       15119
# 421        30/02/2010 00:00 2010-02-28 00:00:00      7.95       15485
# 430        01/12/2010 25:61 2010-12-01 00:59:00      1.25       11184
# 431   Date: 12/1/2010 14:43 2010-01-12 14:43:00      2.55       14426
#
#                                        Country     CustomerName  ...  \
# 16   ### FELTCRAFT PRINCESS CHARLOTTE DOLL ###     John Johnson  ...
# 17                              United Kingdom     Grace Wilson  ...
# 19                              United Kingdom       Bob Wilson  ...
# 23                              United Kingdom      Alice Smith  ...
# 32                              United Kingdom  Charlie Johnson  ...
# 49                              United Kingdom        Bob Moore  ...
# 54                              United Kingdom       Jane Jones  ...
# 58                              United Kingdom     John Johnson  ...
# 82                              United Kingdom        Bob Jones  ...
# 90                              United Kingdom    Frank Johnson  ...
# 105                             United Kingdom       Jane Brown  ...
# 114                             United Kingdom     Grace Wilson  ...
# 116                             United Kingdom       Jane Smith  ...
# 173                                    Germany      Grace Davis  ...
# 174                                    Germany     Alice Wilson  ...
# 183                                    Germany    Charlie Jones  ...
# 195                                    Germany     Frank Miller  ...
# 223                                    Germany     John Johnson  ...
# 231                                    Germany       Jane Moore  ...
# 261                                    Germany        Bob Davis  ...
# 281                                    Germany        Bob Smith  ...
# 285                                    Germany      John Miller  ...
# 303                                    Denmark      Alice Jones  ...
# 315                                    Denmark      Alice Brown  ...
# 318                                    Denmark    Grace Johnson  ...
# 335                                    Denmark       Eva Miller  ...
# 342                                    Denmark    Alice Johnson  ...
# 346                                    Denmark      David Jones  ...
# 364                               ### U.K. ###    Charlie Moore  ...
# 396                                    England      Bob Johnson  ...
# 415                                    Denmark      Alice Brown  ...
# 418                                    Denmark     David Taylor  ...
# 421                                    Denmark        Bob Davis  ...
# 430                                    Denmark       Jane Brown  ...
# 431                                    Denmark    Henry Johnson  ...
#
#     StockLevel Discount SaleChannel  ReturnStatus ProductWeight  \
# 16         859    46.12      Online      Returned          3.11
# 17         435    35.36    In-Store  Not Returned          5.30
# 19         994    28.81      Online      Returned          2.98
# 23         481    46.72    In-Store      Returned          3.73
# 32         797    25.94    In-Store  Not Returned          0.74
# 49         747     7.04    In-Store      Returned          1.93
# 54         111    18.12    In-Store      Returned          6.02
# 58         848    33.18    In-Store  Not Returned          0.55
# 82         466    27.98    In-Store      Returned          3.38
# 90         645    20.44      Online  Not Returned          1.28
# 105        121     4.97      Online  Not Returned          2.57
# 114        337    44.82    In-Store  Not Returned          6.37
# 116        804     4.28    In-Store  Not Returned          8.06
# 173         25    25.95      Online  Not Returned          2.34
# 174        580     2.35      Online  Not Returned          6.49
# 183        470    35.95      Online  Not Returned          8.79
# 195        692    24.82    In-Store      Returned          3.56
# 223        137    34.61      Online  Not Returned          3.74
# 231        920    35.28    In-Store  Not Returned          5.08
# 261        836    44.30    In-Store      Returned          9.90
# 281        673    21.07      Online      Returned          3.45
# 285        261    17.73    In-Store      Returned          0.46
# 303        550    30.67    In-Store  Not Returned          6.41
# 315        376    38.98      Online      Returned          6.99
# 318        930    48.46      Online      Returned          1.65
# 335        798    13.28    In-Store  Not Returned          0.50
# 342         78    27.54    In-Store      Returned          1.81
# 346        601    12.99      Online      Returned          6.39
# 364        993    32.92      Online      Returned          9.42
# 396        441    27.06      Online      Returned          8.60
# 415        815    37.48    In-Store  Not Returned          4.54
# 418        216     1.23    In-Store  Not Returned          6.76
# 421         15    24.43    In-Store      Returned          7.92
# 430        130    39.74    In-Store  Not Returned          1.52
# 431        411    34.68    In-Store  Not Returned          7.64
#
#      ProductDimensions  ShippingCost    SalesRegion PromotionCode  \
# 16         45x61x47 cm         17.01      Australia     DISCOUNT5
# 17         21x80x85 cm          8.00  South America        SALE15
# 19         19x20x57 cm          6.57  South America     DISCOUNT5
# 23         16x87x57 cm         19.04      Australia           NaN
# 32         73x33x84 cm          6.20      Australia           NaN
# 49         74x74x83 cm         16.85  North America       PROMO10
# 54         34x92x95 cm          8.43      Australia        SALE15
# 58          54x5x94 cm          7.99  South America     DISCOUNT5
# 82         51x19x21 cm         18.69         Europe        SALE15
# 90         47x86x56 cm          7.70           Asia       PROMO10
# 105        44x25x17 cm          8.87           Asia       PROMO10
# 114        53x22x21 cm          7.55  South America     DISCOUNT5
# 116        94x75x62 cm         10.06           Asia       PROMO10
# 173        56x15x29 cm         14.27      Australia       PROMO10
# 174          8x5x29 cm         18.03      Australia        SALE15
# 183        90x13x62 cm         14.77         Europe        SALE15
# 195        40x15x21 cm         11.06      Australia       PROMO10
# 223           4x1x8 cm         12.19  North America           NaN
# 231        87x59x72 cm         16.47  North America        SALE15
# 261        17x37x25 cm         12.88      Australia        SALE15
# 281        73x73x40 cm         18.50  North America     DISCOUNT5
# 285         3x44x51 cm          9.12  North America       PROMO20
# 303        59x87x93 cm         10.86  North America     DISCOUNT5
# 315        66x55x99 cm          6.56      Australia           NaN
# 318        32x96x99 cm          9.11           Asia       PROMO20
# 335        77x98x25 cm          9.87           Asia     DISCOUNT5
# 342        54x47x87 cm         11.98  South America     DISCOUNT5
# 346         17x88x3 cm          7.63  South America       PROMO10
# 364        56x40x98 cm         12.81         Europe     DISCOUNT5
# 396        99x52x76 cm         16.85  North America       PROMO10
# 415        35x64x25 cm          7.20         Europe        SALE15
# 418        72x60x46 cm          5.39      Australia     DISCOUNT5
# 421        27x46x50 cm         13.24  North America     DISCOUNT5
# 430         2x88x72 cm         14.29         Europe       PROMO10
# 431        11x64x77 cm         14.75           Asia           NaN
#
#      PaymentMethod
# 16       Gift Card
# 17   Bank Transfer
# 19          PayPal
# 23       Gift Card
# 32     Credit Card
# 49       Gift Card
# 54     Credit Card
# 58       Gift Card
# 82   Bank Transfer
# 90            Cash
# 105  Bank Transfer
# 114         PayPal
# 116  Bank Transfer
# 173      Gift Card
# 174         PayPal
# 183           Cash
# 195    Credit Card
# 223         PayPal
# 231         PayPal
# 261      Gift Card
# 281    Credit Card
# 285  Bank Transfer
# 303      Gift Card
# 315         PayPal
# 318         PayPal
# 335      Gift Card
# 342    Credit Card
# 346    Credit Card
# 364           Cash
# 396         PayPal
# 415           Cash
# 418         PayPal
# 421  Bank Transfer
# 430  Bank Transfer
# 431    Credit Card
#
# [35 rows x 25 columns]

# %%
# Tipo de dato de columna 'InvoiceDate'
print(retail2_df['InvoiceDate'].dtype)
# Out:
# object

# %%
# Tipo de dato de columna 'CleanedInvoiceDate' DESPUÉS de transformación
print(retail2_df['CleanedInvoiceDate'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ## Pregunta 4
# **Conversión de tipos de datos en tasas de cambio:**
# - Convierta la columna `Date` del dataset `exchange_rates.csv` a un formato de datetime.

# %%
exchange_rates_df['Date'] = pd.to_datetime(exchange_rates_df['Date'])
exchange_rates_df.head()
# Out:
#         Date  ExchangeRate
# 0 2020-01-01          1.20
# 1 2020-01-02          1.19
# 2 2020-01-03          1.18
# 3 2020-01-04          1.21
# 4 2020-01-05          1.20

# %%
exchange_rates_df.shape
# Out:
# (60, 2)

# %% [markdown]
# ## Pregunta 5
# **Filtrado de datos por país:**
# - Filtre el dataset `retail` para mostrar solo las transacciones realizadas en el país 'United Kingdom'.

# %%
# Comprobación de todos los valores de columna 'Country'
country_list = list(retail2_df['Country'])
print(country_list)
# Out:
# ['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', '### FELTCRAFT PRINCESS CHARLOTTE DOLL ###', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'U.K.', 'STRIPED CHARLIE+LOLA CHARLOTTE BAG: details', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', '### united kingdom ###', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'BOX OF VINTAGE JIGSAW BLOCKS', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'united kingdom', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'England', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'united kingdom', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'SCANDINAVIAN REDS RIBBONS', 'Germany', 'Germany', 'Germany', 'Germany', '### CHOCOLATE HOT WATER BOTTLE ###', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germa ...

# %%
import pandas as pd

# Paso 1: Verificar las variantes de 'United Kingdom'
print(retail2_df['Country'].unique())  # Esto mostrará todas las variaciones en la columna 'Country'
# Out:
# ['United Kingdom' '### FELTCRAFT PRINCESS CHARLOTTE DOLL ###'
#  'KNITTED UNION FLAG HOT WATER BOTTLE' 'U.K.'
#  'STRIPED CHARLIE+LOLA CHARLOTTE BAG: details' 'Germany'
#  '### united kingdom ###' 'BOX OF VINTAGE JIGSAW BLOCKS' 'united kingdom'
#  'England' 'SCANDINAVIAN REDS RIBBONS'
#  '### CHOCOLATE HOT WATER BOTTLE ###' 'Denmark' nan '### U.K. ###'
#  'BOX OF VINTAGE ALPHABET BLOCKS' 'RED HARMONICA IN BOX']

# %%
import pandas as pd
import numpy as np
import re

# Paso 1: Lista de variantes de 'United Kingdom'
variantes_uk = ['United Kingdom', 'UK', 'U.K.', 'united kingdom']

# Paso 2: Función para limpiar y unificar nombres de países
def clean_country_name(country_name):
    if pd.isna(country_name) or isinstance(country_name, (float, int)):
        return np.nan
    # Eliminar caracteres especiales y convertir a minúsculas
    country_name = re.sub(r'[^\w\s]', '', country_name).strip().lower()
    # Unificar nombres basados en la lista de variantes
    return 'United Kingdom' if country_name in [name.lower() for name in variantes_uk] else country_name

# Paso 3: Crear la nueva columna 'CleanedCountry' con valor 'United Kingdom' unificado
retail2_df['CleanedCountry'] = retail2_df['Country'].apply(clean_country_name)

# Verificar la nueva columna
#print(retail2_df[['Country', 'CleanedCountry']].head())

# %%
""" import re
import numpy as np

# Paso 1: Definir la expresión regular para las variantes de 'United Kingdom'
regex_uk = r'\b(?:united\s*kingdom|u\.?k\.?)\b'

# Paso 2: Crear la nueva columna 'CleanedCountry', manejando NaN y aplicando la expresión regular
retail2_df['CleanedCountry'] = retail2_df['Country'].apply(
    lambda x: 'United Kingdom' if isinstance(x, str) and re.search(regex_uk, x, re.IGNORECASE) else x
)

# Paso 3: Verificar la nueva columna
# Mostrar las primeras filas para comparar las columnas
#print(retail2_df[['Country', 'CleanedCountry']].head()) """
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\bytetech\AppData\Local\Temp\ipykernel_3396\4001145465.py:1: SyntaxWarning: invalid escape sequence '\s'
#   """ import re
# " import re\nimport numpy as np\n\n# Paso 1: Definir la expresión regular para las variantes de 'United Kingdom'\nregex_uk = r'\x08(?:united\\s*kingdom|u\\.?k\\.?)\x08'\n\n# Paso 2: Crear la nueva columna 'CleanedCountry', manejando NaN y aplicando la expresión regular\nretail2_df['CleanedCountry'] = retail2_df['Country'].apply(\n    lambda x: 'United Kingdom' if isinstance(x, str) and re.search(regex_uk, x, re.IGNORECASE) else x\n)\n\n# Paso 3: Verificar la nueva columna\n# Mostrar las primeras filas para comparar las columnas\n#print(retail2_df[['Country', 'CleanedCountry']].head()) "

# %%
# Paso 1: Lista de variantes de 'United Kingdom'
#variantes_uk = ['United Kingdom', 'UK', 'U.K.', 'united kingdom']

# Paso 2: Crear la nueva columna 'CleanedCountry' con valor 'United Kingdom' unificado
#retail2_df['CleanedCountry'] = retail2_df['Country'].apply(lambda x: 'United Kingdom' if x in variantes_uk else x)

# Paso 3: Verificar la nueva columna
# Mostrar las primeras filas para comparar las columnas
#retail2_df[['Country', 'CleanedCountry']]

# %%
# Slice para comprobar diferencias entre columnas 'Country'-'CleanedCountry'
retail2_df_slice = retail2_df.loc[95:102, ['Country', 'CleanedCountry']]
retail2_df_slice
# Out:
#                                          Country  \
# 95                                United Kingdom
# 96                                United Kingdom
# 97                                          U.K.
# 98   STRIPED CHARLIE+LOLA CHARLOTTE BAG: details
# 99                                United Kingdom
# 100                               United Kingdom
# 101                               United Kingdom
#
#                                 CleanedCountry
# 95                              United Kingdom
# 96                              United Kingdom
# 97                              United Kingdom
# 98   striped charlielola charlotte bag details
# 99                              United Kingdom
# 100                             United Kingdom
# 101                             United Kingdom

# %%
# Reordenación de columnas
old_order_list2 = list(retail2_df.columns)
new_order_list2 = ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
                    'CleanedInvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'CleanedCountry',
                    'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier', 
                    'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight', 
                    'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode', 
                    'PaymentMethod']
retail2_df = retail2_df[new_order_list2]
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#   Quantity      InvoiceDate  CleanedInvoiceDate UnitPrice  CustomerID  \
# 0        6  12/1/2010 12:28 2010-01-12 12:28:00      4.25       17763
# 1      100  12/1/2010 10:16 2010-01-12 10:16:00     795.0       15939
# 2        6  12/1/2010 13:23 2010-01-12 13:23:00      1.85       12295
# 3       10  12/1/2010 11:32 2010-01-12 11:32:00      1.65       15685
# 5        6  12/1/2010 14:24 2010-01-12 14:24:00      4.25       11946
#
#           Country  CleanedCountry  ... StockLevel Discount SaleChannel  \
# 0  United Kingdom  United Kingdom  ...        853    17.28      Online
# 1  United Kingdom  United Kingdom  ...        910     9.08      Online
# 2  United Kingdom  United Kingdom  ...        578    45.42    In-Store
# 3  United Kingdom  United Kingdom  ...         75    29.17      Online
# 5  United Kingdom  United Kingdom  ...        103    23.10    In-Store
#
#    ReturnStatus ProductWeight ProductDimensions  ShippingCost    SalesRegion  \
# 0  Not Returned          3.81       37x38x83 cm          7.14  North America
# 1  Not Returned          9.51        8x65x86 cm         12.48           Asia
# 2      Returned          7.35       17x71x89 cm         14.27  North America
# 3      Returned          6.03        45x4x36 cm         15.54           Asia
# 5      Returned          1.64       61x54x39 cm          5.15  North America
#
#   PromotionCode  PaymentMethod
# 0        SALE15  Bank Transfer
# 1        SALE15  Bank Transfer
# 2     DISCOUNT5  Bank Transfer
# 3           NaN         PayPal
# 5       PROMO20         PayPal
#
# [5 rows x 26 columns]

# %%
# Comprobación de los valores únicos en la columna 'CleanedCountry'
print(retail2_df['CleanedCountry'].unique())
# Out:
# ['United Kingdom' 'feltcraft princess charlotte doll'
#  'knitted union flag hot water bottle'
#  'striped charlielola charlotte bag details' 'germany'
#  'box of vintage jigsaw blocks' 'england' 'scandinavian reds ribbons'
#  'chocolate hot water bottle' 'denmark' nan
#  'box of vintage alphabet blocks' 'red harmonica in box']

# %% [markdown]
# ## Pregunta 6
# **Calcular el total de precios:**
# - Cree una nueva columna `TotalPrice` en el dataset `retail` multiplicando `Quantity` por `UnitPrice`.

# %%
# Primer intento
# retail2_df['TotalPrice'] = retail2_df['Quantity'] * retail2_df['UnitPrice']
# print(retail2_df[['Quantity', 'UnitPrice', 'TotalPrice']].head())

# %%
# Comprobar los tipos de datos de todas las columnas
print(retail2_df.dtypes)

# Ver los tipos de datos específicos de 'Quantity' y 'UnitPrice'
print(f"'Quantity' type: {retail2_df['Quantity'].dtype}")
print(f"'UnitPrice' type: {retail2_df['UnitPrice'].dtype}")
# Out:
# InvoiceNo                    float64
# StockCode                     object
# Description                   object
# Quantity                      object
# InvoiceDate                   object
# CleanedInvoiceDate    datetime64[ns]
# UnitPrice                     object
# CustomerID                     int64
# Country                       object
# CleanedCountry                object
# CustomerName                  object
# Email                         object
# Address                       object
# PhoneNumber                   object
# Category                      object
# Supplier                      object
# StockLevel                     int64
# Discount                     float64
# SaleChannel                   object
# ReturnStatus                  object
# ProductWeight                float64
# ProductDimensions             object
# ShippingCost                 float64
# SalesRegion                   object
# PromotionCode                 object
# PaymentMethod                 object
# dtype: object
# 'Quantity' type: object
# 'UnitPrice' type: object

# %%
# Convertir las columnas a tipo numérico, forzando errores a NaN si no se puede convertir
retail2_df['Quantity'] = pd.to_numeric(retail2_df['Quantity'], errors='coerce')
retail2_df['UnitPrice'] = pd.to_numeric(retail2_df['UnitPrice'], errors='coerce')

# Ver los tipos de datos específicos de 'Quantity' y 'UnitPrice'
print(f"'Quantity' type: {retail2_df['Quantity'].dtype}")
print(f"'UnitPrice' type: {retail2_df['UnitPrice'].dtype}")
# Out:
# 'Quantity' type: float64
# 'UnitPrice' type: float64

# %%
# Segundo intento
retail2_df['TotalPrice'] = retail2_df['Quantity'] * retail2_df['UnitPrice']
print(retail2_df[['Quantity', 'UnitPrice', 'TotalPrice']].head())
# Out:
#    Quantity  UnitPrice  TotalPrice
# 0       6.0       4.25        25.5
# 1     100.0     795.00     79500.0
# 2       6.0       1.85        11.1
# 3      10.0       1.65        16.5
# 5       6.0       4.25        25.5

# %%
old_order_list3 = retail2_df.columns.to_list()
new_order_list3 = ['InvoiceNo',  'StockCode',  'Description', 'UnitPrice', 'Quantity', 'TotalPrice',
                   'InvoiceDate', 'Country', 'CleanedCountry', 'CleanedInvoiceDate', 'CustomerID', 
                    'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier',
                    'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight',
                    'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode',
                    'PaymentMethod']
retail2_df = retail2_df[new_order_list3]
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice      InvoiceDate         Country  \
# 0       4.25       6.0        25.5  12/1/2010 12:28  United Kingdom
# 1     795.00     100.0     79500.0  12/1/2010 10:16  United Kingdom
# 2       1.85       6.0        11.1  12/1/2010 13:23  United Kingdom
# 3       1.65      10.0        16.5  12/1/2010 11:32  United Kingdom
# 5       4.25       6.0        25.5  12/1/2010 14:24  United Kingdom
#
#    CleanedCountry  CleanedInvoiceDate  ...  StockLevel Discount SaleChannel  \
# 0  United Kingdom 2010-01-12 12:28:00  ...         853    17.28      Online
# 1  United Kingdom 2010-01-12 10:16:00  ...         910     9.08      Online
# 2  United Kingdom 2010-01-12 13:23:00  ...         578    45.42    In-Store
# 3  United Kingdom 2010-01-12 11:32:00  ...          75    29.17      Online
# 5  United Kingdom 2010-01-12 14:24:00  ...         103    23.10    In-Store
#
#    ReturnStatus ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0  Not Returned          3.81       37x38x83 cm         7.14  North America
# 1  Not Returned          9.51        8x65x86 cm        12.48           Asia
# 2      Returned          7.35       17x71x89 cm        14.27  North America
# 3      Returned          6.03        45x4x36 cm        15.54           Asia
# 5      Returned          1.64       61x54x39 cm         5.15  North America
#
#    PromotionCode  PaymentMethod
# 0         SALE15  Bank Transfer
# 1         SALE15  Bank Transfer
# 2      DISCOUNT5  Bank Transfer
# 3            NaN         PayPal
# 5        PROMO20         PayPal
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Pregunta 7
# **Extraer mes y año:**
# - Extraiga el mes y el año de la columna `InvoiceDate` y cree dos nuevas columnas: `InvoiceMonth` y `InvoiceYear`.

# %%
# Comprobación del tipo de dato de la columna 'CleanedInvoiceDate'
cleaned_invoicedate_serie = retail2_df['CleanedInvoiceDate']
cleaned_invoicedate_serie.dtype
# Out:
# dtype('<M8[ns]')

# %%
# A) Conversión de la Serie en una SOLA cadena
# cleaned_indt_str = cleaned_invoicedate_serie.to_string()

# B) Convertir cada valor de la Serie a string
cleaned_indt_str = cleaned_invoicedate_serie.astype(str)
# Verificar los primeros valores convertidos
print(cleaned_indt_str.head())
# Out:
# 0    2010-01-12 12:28:00
# 1    2010-01-12 10:16:00
# 2    2010-01-12 13:23:00
# 3    2010-01-12 11:32:00
# 5    2010-01-12 14:24:00
# Name: CleanedInvoiceDate, dtype: object

# %%
# Extracción del mes y año, creando las nuevas columnas
# rellenar a '0' los valores nulos('NaN')
# y convertir a entero para eliminar la coma flotante
retail2_df['InvoiceMonth'] = retail2_df['CleanedInvoiceDate'].dt.month.fillna(0).astype(int)
retail2_df['InvoiceYear'] = retail2_df['CleanedInvoiceDate'].dt.year.fillna(0).astype(int)

retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice      InvoiceDate         Country  \
# 0       4.25       6.0        25.5  12/1/2010 12:28  United Kingdom
# 1     795.00     100.0     79500.0  12/1/2010 10:16  United Kingdom
# 2       1.85       6.0        11.1  12/1/2010 13:23  United Kingdom
# 3       1.65      10.0        16.5  12/1/2010 11:32  United Kingdom
# 5       4.25       6.0        25.5  12/1/2010 14:24  United Kingdom
#
#    CleanedCountry  CleanedInvoiceDate  ...  SaleChannel  ReturnStatus  \
# 0  United Kingdom 2010-01-12 12:28:00  ...       Online  Not Returned
# 1  United Kingdom 2010-01-12 10:16:00  ...       Online  Not Returned
# 2  United Kingdom 2010-01-12 13:23:00  ...     In-Store      Returned
# 3  United Kingdom 2010-01-12 11:32:00  ...       Online      Returned
# 5  United Kingdom 2010-01-12 14:24:00  ...     In-Store      Returned
#
#   ProductWeight ProductDimensions ShippingCost    SalesRegion PromotionCode  \
# 0          3.81       37x38x83 cm         7.14  North America        SALE15
# 1          9.51        8x65x86 cm        12.48           Asia        SALE15
# 2          7.35       17x71x89 cm        14.27  North America     DISCOUNT5
# 3          6.03        45x4x36 cm        15.54           Asia           NaN
# 5          1.64       61x54x39 cm         5.15  North America       PROMO20
#
#    PaymentMethod  InvoiceMonth InvoiceYear
# 0  Bank Transfer             1        2010
# 1  Bank Transfer             1        2010
# 2  Bank Transfer             1        2010
# 3         PayPal             1        2010
# 5         PayPal             1        2010
#
# [5 rows x 29 columns]

# %%
# Reordenación de columnas
old_order_list4 = retail2_df.columns.to_list()
old_order_list4

new_order_list4 = ['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity',
 'TotalPrice', 'InvoiceDate', 'CleanedInvoiceDate',  'InvoiceMonth', 'InvoiceYear', 
 'Country', 'CleanedCountry', 'CustomerID', 'CustomerName', 'Email', 'Address', 'PhoneNumber',
 'Category', 'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight',
 'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode', 'PaymentMethod',]
retail2_df = retail2_df[new_order_list4]
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice      InvoiceDate  CleanedInvoiceDate  \
# 0       4.25       6.0        25.5  12/1/2010 12:28 2010-01-12 12:28:00
# 1     795.00     100.0     79500.0  12/1/2010 10:16 2010-01-12 10:16:00
# 2       1.85       6.0        11.1  12/1/2010 13:23 2010-01-12 13:23:00
# 3       1.65      10.0        16.5  12/1/2010 11:32 2010-01-12 11:32:00
# 5       4.25       6.0        25.5  12/1/2010 14:24 2010-01-12 14:24:00
#
#    InvoiceMonth  InvoiceYear  ... StockLevel Discount  SaleChannel  \
# 0             1         2010  ...        853    17.28       Online
# 1             1         2010  ...        910     9.08       Online
# 2             1         2010  ...        578    45.42     In-Store
# 3             1         2010  ...         75    29.17       Online
# 5             1         2010  ...        103    23.10     In-Store
#
#    ReturnStatus ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0  Not Returned          3.81       37x38x83 cm         7.14  North America
# 1  Not Returned          9.51        8x65x86 cm        12.48           Asia
# 2      Returned          7.35       17x71x89 cm        14.27  North America
# 3      Returned          6.03        45x4x36 cm        15.54           Asia
# 5      Returned          1.64       61x54x39 cm         5.15  North America
#
#   PromotionCode  PaymentMethod
# 0        SALE15  Bank Transfer
# 1        SALE15  Bank Transfer
# 2     DISCOUNT5  Bank Transfer
# 3           NaN         PayPal
# 5       PROMO20         PayPal
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Pregunta 8
# **Eliminar duplicados:**
# - Identifique y elimine las filas duplicadas en el dataset `retail` basadas en la combinación de `InvoiceNo` y `StockCode`.

# %%
retail2_df[10:20]
# Out:
#     InvoiceNo StockCode                                        Description  \
# 11   536377.0     22112                         CHOCOLATE HOT WATER BOTTLE
# 12   536487.0     21724                               RED HARMONICA IN BOX
# 13   536437.0     71053                                WHITE METAL LANTERN
# 14   536467.0    84029G                knitted union flag hot water bottle
# 15   536404.0    84907C                PACK OF 12 BLUE RETROSPOT TISSUES
# 16   536676.0     22749            ***FELTCRAFT PRINCESS CHARLOTTE DOLL***
# 17   536375.0     22960  ["description": "JAM MAKING SET WITH JARS: det...
# 18   536457.0     22960                     ***JAM MAKING SET WITH JARS***
# 19   536696.0     22112                         CHOCOLATE HOT WATER BOTTLE
# 20   536695.0     22139                    RETROSPOT TEA SET CERAMIC 11 PC
#
#     UnitPrice  Quantity  TotalPrice            InvoiceDate  \
# 11       3.39      10.0       33.90         12/1/2010 9:07
# 12       1.25      10.0       12.50        12/1/2010 10:57
# 13       3.39       6.0       20.34        12/1/2010 10:07
# 14       3.39       6.0       20.34        12/1/2010 10:37
# 15       0.85      20.0       17.00         12/1/2010 9:34
# 16       3.75       8.0       30.00       01/12/2010 25:61
# 17       4.25       6.0       25.50       30/02/2010 00:00
# 18       4.25       6.0       25.50        12/1/2010 10:27
# 19       3.39      10.0       33.90  Date: 12/1/2010 14:26
# 20       6.95      -6.0      -41.70        12/1/2010 14:25
#
#     CleanedInvoiceDate  InvoiceMonth  InvoiceYear  ... StockLevel Discount  \
# 11 2010-01-12 09:07:00             1         2010  ...        306     0.91
# 12 2010-01-12 10:57:00             1         2010  ...         98    43.61
# 13 2010-01-12 10:07:00             1         2010  ...        850    46.61
# 14 2010-01-12 10:37:00             1         2010  ...        798    28.26
# 15 2010-01-12 09:34:00             1         2010  ...        335    34.83
# 16 2010-12-01 00:59:00            12         2010  ...        859    46.12
# 17 2010-02-28 00:00:00             2         2010  ...        435    35.36
# 18 2010-01-12 10:27:00             1         2010  ...        447     7.63
# 19 2010-01-12 14:26:00             1         2010  ...        994    28.81
# 20 2010-01-12 14:25:00             1         2010  ...        308    30.34
#
#     SaleChannel  ReturnStatus ProductWeight ProductDimensions ShippingCost  \
# 11       Online      Returned          9.70         1x3x77 cm         6.18
# 12       Online  Not Returned          8.34       92x62x63 cm        10.95
# 13     In-Store  Not Returned          2.20       25x56x33 cm         6.99
# 14     In-Store  Not Returned          1.90        38x6x58 cm        13.51
# 15     In-Store  Not Returned          1.92       44x45x32 cm        15.34
# 16       Online      Returned          3.11       45x61x47 cm        17.01
# 17     In-Store  Not Returned          5.30       21x80x85 cm         8.00
# 18       Online  Not Returned          4.38       75x36x99 cm         7.51
# 19       Online      Returned          2.98       19x20x57 cm         6.57
# 20     In-Store  Not Returned          6.16       18x47x49 cm        14.55
#
#       SalesRegion PromotionCode  PaymentMethod
# 11  South America     DISCOUNT5         PayPal
# 12  North America        SALE15      Gift Card
# 13      Australia       PROMO10      Gift Card
# 14  South America       PROMO20         PayPal
# 15  South America        SALE15           Cash
# 16      Australia     DISCOUNT5      Gift Card
# 17  South America        SALE15  Bank Transfer
# 18  South America       PROMO10           Cash
# 19  South America     DISCOUNT5         PayPal
# 20         Europe       PROMO20           Cash
#
# [10 rows x 29 columns]

# %%
# Comprobación de la forma(filas x columnas)
retail2_df.shape
# Out:
# (420, 29)

# %%
# Identificación y eliminación de las filas duplicadas basadas en las columnas InvoiceNo y StockCode
retail2_df = retail2_df.drop_duplicates(subset=['InvoiceNo', 'StockCode'])

# %%
# Comprobación de la forma(filas x columnas)
retail2_df.shape
# Out:
# (386, 29)

# %% [markdown]
# ## Pregunta 9
# **Reemplazo de valores:**
# - Reemplace todos los valores negativos en la columna `Quantity` con cero.

# %%
# Comprobación de valores negativos en columna 'Quantity' ANTES
retail2_quant_neg_df = retail2_df.loc[retail2_df['Quantity'] < 0, 'Quantity']
retail2_quant_neg_df
# Out:
# 6      -6.0
# 20     -6.0
# 57     -6.0
# 100   -20.0
# 119    -6.0
# 233   -60.0
# 365    -6.0
# 388    -3.0
# 390   -20.0
# Name: Quantity, dtype: float64

# %%
# Reemplazar los valores negativos en la columna Quantity con 0
retail2_df.loc[retail2_df['Quantity'] < 0, 'Quantity'] = 0
retail2_df[20:21]
# Out:
#     InvoiceNo StockCode                 Description  UnitPrice  Quantity  \
# 21   536443.0     22112  CHOCOLATE HOT WATER BOTTLE       3.39      10.0
#
#     TotalPrice      InvoiceDate  CleanedInvoiceDate  InvoiceMonth  \
# 21        33.9  12/1/2010 10:13 2010-01-12 10:13:00             1
#
#     InvoiceYear  ... StockLevel Discount  SaleChannel ReturnStatus  \
# 21         2010  ...        249    21.21       Online     Returned
#
#    ProductWeight ProductDimensions ShippingCost SalesRegion PromotionCode  \
# 21          1.48       14x15x31 cm         15.6   Australia     DISCOUNT5
#
#     PaymentMethod
# 21    Credit Card
#
# [1 rows x 29 columns]

# %%
# Comprobación de valores negativos en columna 'Quantity' DESPUÉS
retail2_quant_neg_df2 = retail2_df.loc[retail2_df['Quantity'] < 0, 'Quantity']
retail2_quant_neg_df2
# Out:
# Series([], Name: Quantity, dtype: float64)

# %% [markdown]
# ## Pregunta 10
# **Transformación de datos:**
# - Cree una nueva columna `DiscountedPrice` aplicando un descuento del 10% al `TotalPrice`.

# %%
# Comprobación del orden de columnas
print(old_order_list4)
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity', 'TotalPrice', 'InvoiceDate', 'Country', 'CleanedCountry', 'CleanedInvoiceDate', 'CustomerID', 'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight', 'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode', 'PaymentMethod', 'InvoiceMonth', 'InvoiceYear']

# %%
# Inserción de la nueva columna en una posición determinada
retail2_df.insert(6, 'DiscountedPrice', (retail2_df['TotalPrice'] * 0.90))
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice  DiscountedPrice      InvoiceDate  \
# 0       4.25       6.0        25.5            22.95  12/1/2010 12:28
# 1     795.00     100.0     79500.0         71550.00  12/1/2010 10:16
# 2       1.85       6.0        11.1             9.99  12/1/2010 13:23
# 3       1.65      10.0        16.5            14.85  12/1/2010 11:32
# 5       4.25       6.0        25.5            22.95  12/1/2010 14:24
#
#    CleanedInvoiceDate  InvoiceMonth  ...  StockLevel Discount SaleChannel  \
# 0 2010-01-12 12:28:00             1  ...         853    17.28      Online
# 1 2010-01-12 10:16:00             1  ...         910     9.08      Online
# 2 2010-01-12 13:23:00             1  ...         578    45.42    In-Store
# 3 2010-01-12 11:32:00             1  ...          75    29.17      Online
# 5 2010-01-12 14:24:00             1  ...         103    23.10    In-Store
#
#    ReturnStatus ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0  Not Returned          3.81       37x38x83 cm         7.14  North America
# 1  Not Returned          9.51        8x65x86 cm        12.48           Asia
# 2      Returned          7.35       17x71x89 cm        14.27  North America
# 3      Returned          6.03        45x4x36 cm        15.54           Asia
# 5      Returned          1.64       61x54x39 cm         5.15  North America
#
#   PromotionCode  PaymentMethod
# 0        SALE15  Bank Transfer
# 1        SALE15  Bank Transfer
# 2     DISCOUNT5  Bank Transfer
# 3           NaN         PayPal
# 5       PROMO20         PayPal
#
# [5 rows x 30 columns]

# %% [markdown]
# # Parte 2. Data Wrangling: Join, Combine, and Reshape (Capítulo 8)

# %% [markdown]
# ## Pregunta 11
# **Merge de datasets:**
# - Realice un merge del dataset `retail` con el dataset `exchange_rates.csv` en las columnas de fecha (`InvoiceDate` de `retail` y `Date` de `exchange_rates.csv`).

# %%
# Comprobación de los tipos de las columnas del 'exchange_rate_df'
exchange_rates_df.dtypes
# Out:
# Date            datetime64[ns]
# ExchangeRate           float64
# dtype: object

# %%
# Comprobación de los tipos de las columnas del 'retail2_df'
retail2_df.dtypes
# Out:
# InvoiceNo                    float64
# StockCode                     object
# Description                   object
# UnitPrice                    float64
# Quantity                     float64
# TotalPrice                   float64
# DiscountedPrice              float64
# InvoiceDate                   object
# CleanedInvoiceDate    datetime64[ns]
# InvoiceMonth                   int64
# InvoiceYear                    int64
# Country                       object
# CleanedCountry                object
# CustomerID                     int64
# CustomerName                  object
# Email                         object
# Address                       object
# PhoneNumber                   object
# Category                      object
# Supplier                      object
# StockLevel                     int64
# Discount                     float64
# SaleChannel                   object
# ReturnStatus                  object
# ProductWeight                float64
# ProductDimensions             object
# ShippingCost                 float64
# SalesRegion                   object
# PromotionCode                 object
# PaymentMethod                 object
# dtype: object

# %%
exchange_rates_df.head()
# Out:
#         Date  ExchangeRate
# 0 2020-01-01          1.20
# 1 2020-01-02          1.19
# 2 2020-01-03          1.18
# 3 2020-01-04          1.21
# 4 2020-01-05          1.20

# %%
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice  DiscountedPrice      InvoiceDate  \
# 0       4.25       6.0        25.5            22.95  12/1/2010 12:28
# 1     795.00     100.0     79500.0         71550.00  12/1/2010 10:16
# 2       1.85       6.0        11.1             9.99  12/1/2010 13:23
# 3       1.65      10.0        16.5            14.85  12/1/2010 11:32
# 5       4.25       6.0        25.5            22.95  12/1/2010 14:24
#
#    CleanedInvoiceDate  InvoiceMonth  ...  StockLevel Discount SaleChannel  \
# 0 2010-01-12 12:28:00             1  ...         853    17.28      Online
# 1 2010-01-12 10:16:00             1  ...         910     9.08      Online
# 2 2010-01-12 13:23:00             1  ...         578    45.42    In-Store
# 3 2010-01-12 11:32:00             1  ...          75    29.17      Online
# 5 2010-01-12 14:24:00             1  ...         103    23.10    In-Store
#
#    ReturnStatus ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0  Not Returned          3.81       37x38x83 cm         7.14  North America
# 1  Not Returned          9.51        8x65x86 cm        12.48           Asia
# 2      Returned          7.35       17x71x89 cm        14.27  North America
# 3      Returned          6.03        45x4x36 cm        15.54           Asia
# 5      Returned          1.64       61x54x39 cm         5.15  North America
#
#   PromotionCode  PaymentMethod
# 0        SALE15  Bank Transfer
# 1        SALE15  Bank Transfer
# 2     DISCOUNT5  Bank Transfer
# 3           NaN         PayPal
# 5       PROMO20         PayPal
#
# [5 rows x 30 columns]

# %%
# Mergeado basado en las columnas de fecha
merged_df = pd.merge(retail2_df, 
                     exchange_rates_df, 
                     left_on='CleanedInvoiceDate', 
                     right_on='Date', 
                     how='left')
merged_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 4   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice  DiscountedPrice      InvoiceDate  \
# 0       4.25       6.0        25.5            22.95  12/1/2010 12:28
# 1     795.00     100.0     79500.0         71550.00  12/1/2010 10:16
# 2       1.85       6.0        11.1             9.99  12/1/2010 13:23
# 3       1.65      10.0        16.5            14.85  12/1/2010 11:32
# 4       4.25       6.0        25.5            22.95  12/1/2010 14:24
#
#    CleanedInvoiceDate  InvoiceMonth  ...  SaleChannel  ReturnStatus  \
# 0 2010-01-12 12:28:00             1  ...       Online  Not Returned
# 1 2010-01-12 10:16:00             1  ...       Online  Not Returned
# 2 2010-01-12 13:23:00             1  ...     In-Store      Returned
# 3 2010-01-12 11:32:00             1  ...       Online      Returned
# 4 2010-01-12 14:24:00             1  ...     In-Store      Returned
#
#   ProductWeight  ProductDimensions ShippingCost    SalesRegion PromotionCode  \
# 0          3.81        37x38x83 cm         7.14  North America        SALE15
# 1          9.51         8x65x86 cm        12.48           Asia        SALE15
# 2          7.35        17x71x89 cm        14.27  North America     DISCOUNT5
# 3          6.03         45x4x36 cm        15.54           Asia           NaN
# 4          1.64        61x54x39 cm         5.15  North America       PROMO20
#
#    PaymentMethod Date ExchangeRate
# 0  Bank Transfer  NaT          NaN
# 1  Bank Transfer  NaT          NaN
# 2  Bank Transfer  NaT          NaN
# 3         PayPal  NaT          NaN
# 4         PayPal  NaT          NaN
#
# [5 rows x 32 columns]

# %%
merged_df.shape
# Out:
# (386, 32)

# %% [markdown]
# ## Pregunta 12
# **Concatenación de datasets:**
# - Concatenar dos subconjuntos del dataset `retail`, uno con las primeras 100 filas y otro con las últimas 100 filas.

# %%
# Extracción primeras 100 filas
first_100 = retail2_df.head(100)

# Extracción últimas 100 filas
last_100 = retail2_df.tail(100)

# Concatenación de subconjuntos
concatenated_df = pd.concat([first_100, last_100], ignore_index=True)

# Visualización
print(concatenated_df)
# Out:
#      InvoiceNo StockCode                                        Description  \
# 0     536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1     536446.0     21756                                DOORMAT NEW ENGLAND
# 2     536633.0     22632                          HAND WARMER RED POLKA DOT
# 3     536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 4     536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
# ..         ...       ...                                                ...
# 195   536713.0    85123A                 WHITE HANGING HEART T-LIGHT HOLDER
# 196   536585.0     21756                                DOORMAT NEW ENGLAND
# 197   536526.0     71053                                WHITE METAL LANTERN
# 198   536368.0     21777                        RECIPE BOX WITH METAL HEART
# 199   536472.0     22632                          HAND WARMER RED POLKA DOT
#
#      UnitPrice  Quantity  TotalPrice  DiscountedPrice            InvoiceDate  \
# 0         4.25       6.0       25.50           22.950        12/1/2010 12:28
# 1       795.00     100.0    79500.00        71550.000        12/1/2010 10:16
# 2         1.85       6.0       11.10            9.990        12/1/2010 13:23
# 3         1.65      10.0       16.50           14.850        12/1/2010 11:32
# 4         4.25       6.0       25.50           22.950        12/1/2010 14:24
# ..         ...       ...         ...              ...                    ...
# 195       2.55       6.0       15.30           13.770  Date: 12/1/2010 14:43
# 196       7.95      10.0       79.50           71.550        12/1/2010 12:35
# 197       3.39       6.0       20.34           18.306        12/1/2010 11:36
# 198     795.00       4.0     3180.00         2862.000         12/1/2010 8:35
# 199       1.85       6.0       11.10            9.990        12/1/2010 10:42
#
#      CleanedInvoiceDate  InvoiceMonth  ...  StockLevel Discount SaleChannel  \
# 0   2010-01-12 12:28:00             1  ...         853    17.28      Online
# 1   2010-01-12 10:16:00             1  ...         910     9.08      Online
# 2   2010-01-12 13:23:00             1  ...         578    45.42    In-Store
# 3   2010-01-12 11:32:00             1  ...          75    29.17      Online
# 4   2010-01-12 14:24:00             1  ...         103    23.10    In-Store
# ..                  ...           ...  ...         ...      ...         ...
# 195 2010-01-12 14:43:00             1  ...         411    34.68    In-Store
# 196 2010-01-12 12:35:00             1  ...          95    11.04      Online
# 197 2010-01-12 11:36:00             1  ...         627     4.12    In-Store
# 198 2010-01-12 08:35:00             1  ...         811     7.55    In-Store
# 199 2010-01-12 10:42:00             1  ...         283    21.62      Online
#
#      ReturnStatus ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0    Not Returned          3.81       37x38x83 cm         7.14  North America
# 1    Not Returned          9.51        8x65x86 cm        12.48           Asia
# 2        Returned          7.35       17x71x89 cm        14.27  North America
# 3        Returned          6.03        45x4x36 cm        15.54           Asia
# 4        Returned          1.64       61x54x39 cm         5.15  North America
# ..            ...           ...               ...          ...            ...
# 195  Not Returned          7.64       11x64x77 cm        14.75           Asia
# 196      Returned          6.22       81x72x21 cm         7.28           Asia
# 197  Not Returned          1.10       18x94x64 cm         5.92  North America
# 198      Returned          7.09       51x88x41 cm         5.87  South America
# 199  Not Returned          0.91       17x76x46 cm        15.43      Australia
#
#     PromotionCode  PaymentMethod
# 0          SALE15  Bank Transfer
# 1          SALE15  Bank Transfer
# 2       DISCOUNT5  Bank Transfer
# 3             NaN         PayPal
# 4         PROMO20         PayPal
# ..            ...            ...
# 195           NaN    Credit Card
# 196       PROMO20    Credit Card
# 197           NaN           Cash
# 198        SALE15         PayPal
# 199       PROMO20    Credit Card
#
# [200 rows x 30 columns]

# %%
concatenated_df.shape
# Out:
# (200, 30)

# %% [markdown]
# ## Pregunta 13
# **Pivot table:**
# - Cree una tabla dinámica (pivot table) que muestre el total de `TotalPrice` para cada `Country` y `InvoiceYear`.

# %%
# Crear una tabla dinámica con pandas
pivot_table = retail2_df.pivot_table(
    values='TotalPrice',          # La columna que deseas agregar en los valores mostrados
    index='CleanedCountry',       # Las filas serán los países
    columns='InvoiceYear',        # Las columnas serán los años de las facturas
    aggfunc='sum',                # Función de agregación, en este caso suma
    fill_value=0                  # Rellena con 0 si hay valores faltantes
)

# Mostrar la tabla dinámica
#print(pivot_table)
pivot_table
# Out:
# InvoiceYear                                    0      1900       2010  2050
# CleanedCountry
# United Kingdom                                14.85 -20.10  121249.13  62.3
# box of vintage alphabet blocks                 0.00   0.00      19.90   0.0
# box of vintage jigsaw blocks                   0.00   0.00      14.85   0.0
# chocolate hot water bottle                     0.00   0.00      33.90   0.0
# denmark                                       32.94  99.92   47117.69  16.5
# england                                        0.00   0.00      67.95   0.0
# feltcraft princess charlotte doll              0.00   0.00      30.00   0.0
# germany                                    12615.00  54.15   46166.91  64.8
# knitted union flag hot water bottle            0.00   0.00      20.34   0.0
# red harmonica in box                           0.00   0.00      12.50   0.0
# scandinavian reds ribbons                      0.00   0.00      33.00   0.0
# striped charlielola charlotte bag details      0.00   0.00      59.00   0.0

# %% [markdown]
# Como han aparecido valores erroneos en 'CleanedCountry':
#
# \"### U.K. ###"
#
# \"### united kingdom ###"
#
# Procedemos a corregirlo

# %% [markdown]
# ## Pregunta 14
# **Reshape con melt:**
# - Transforme el dataset `retail` de formato ancho a largo usando la función `melt` de pandas.

# %%
# Extracción de columnas
cols_list = list(retail2_df.columns)
print(cols_list)
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity', 'TotalPrice', 'DiscountedPrice', 'InvoiceDate', 'CleanedInvoiceDate', 'InvoiceMonth', 'InvoiceYear', 'Country', 'CleanedCountry', 'CustomerID', 'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight', 'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode', 'PaymentMethod']

# %%
# Usando melt para transformar el DataFrame de formato ancho a largo
retail2_long_df = pd.melt(
                    retail2_df,
                    id_vars=['InvoiceNo', 'StockCode', 'Description'],
                    var_name='Variable',
                    value_name='Value'
                )
#print(long_df)
retail2_long_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 4   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#     Variable  Value
# 0  UnitPrice   4.25
# 1  UnitPrice  795.0
# 2  UnitPrice   1.85
# 3  UnitPrice   1.65
# 4  UnitPrice   4.25

# %% [markdown]
# ## Pregunta 15
# **Combinar datos con overlap:**
# - Combine dos DataFrames con columnas `CustomerID` y `TotalPrice`, teniendo en cuenta el overlap entre los datos.

# %%
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice  DiscountedPrice      InvoiceDate  \
# 0       4.25       6.0        25.5            22.95  12/1/2010 12:28
# 1     795.00     100.0     79500.0         71550.00  12/1/2010 10:16
# 2       1.85       6.0        11.1             9.99  12/1/2010 13:23
# 3       1.65      10.0        16.5            14.85  12/1/2010 11:32
# 5       4.25       6.0        25.5            22.95  12/1/2010 14:24
#
#    CleanedInvoiceDate  InvoiceMonth  ...  StockLevel Discount SaleChannel  \
# 0 2010-01-12 12:28:00             1  ...         853    17.28      Online
# 1 2010-01-12 10:16:00             1  ...         910     9.08      Online
# 2 2010-01-12 13:23:00             1  ...         578    45.42    In-Store
# 3 2010-01-12 11:32:00             1  ...          75    29.17      Online
# 5 2010-01-12 14:24:00             1  ...         103    23.10    In-Store
#
#    ReturnStatus ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0  Not Returned          3.81       37x38x83 cm         7.14  North America
# 1  Not Returned          9.51        8x65x86 cm        12.48           Asia
# 2      Returned          7.35       17x71x89 cm        14.27  North America
# 3      Returned          6.03        45x4x36 cm        15.54           Asia
# 5      Returned          1.64       61x54x39 cm         5.15  North America
#
#   PromotionCode  PaymentMethod
# 0        SALE15  Bank Transfer
# 1        SALE15  Bank Transfer
# 2     DISCOUNT5  Bank Transfer
# 3           NaN         PayPal
# 5       PROMO20         PayPal
#
# [5 rows x 30 columns]

# %%
cols_list = list(retail2_df.columns)
print(cols_list)
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity', 'TotalPrice', 'DiscountedPrice', 'InvoiceDate', 'CleanedInvoiceDate', 'InvoiceMonth', 'InvoiceYear', 'Country', 'CleanedCountry', 'CustomerID', 'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight', 'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode', 'PaymentMethod']

# %%
# Creación de un segundo DataFrame basado en retail2_df
secondary_df = retail2_df[['CustomerID', 'TotalPrice']].copy()

# Creación de valores de ejemplo en el segundo DataFrame
# cambiando algunos valores para simular datos diferentes
secondary_df['TotalPrice'] = secondary_df['TotalPrice'] * 1.05  # Simula que los precios aumentaron un 5%

# Combinación los dos DF con pd.merge()
#   - con 'outer' join para combinar todos los datos de ambos DF y manejar el overlap
combined_df = pd.merge(retail2_df, secondary_df, on='CustomerID', how='outer', suffixes=('_orig', '_updated'))

# Visualización de las primeras filas del DF combinado
#print(combined_df.head())
combined_df.head()
# Out:
#    InvoiceNo StockCode                         Description  UnitPrice  \
# 0   536426.0     22623        BOX OF VINTAGE JIGSAW BLOCKS       4.95
# 1   536365.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER       2.55
# 2   536723.0     21724              RED HARMONICA IN BOX         1.25
# 3   536553.0     71053                 WHITE METAL LANTERN       3.39
# 4   536697.0     22634        BAKING SET 9 PIECE RETROSPOT       4.95
#
#    Quantity  TotalPrice_orig  DiscountedPrice      InvoiceDate  \
# 0       3.0            14.85           13.365   12/1/2010 9:56
# 1       6.0            15.30           13.770   12/1/2010 8:26
# 2      10.0            12.50           11.250  12/1/2010 14:53
# 3       6.0            20.34           18.306  12/1/2010 12:03
# 4       6.0            29.70           26.730  12/1/2010 14:27
#
#    CleanedInvoiceDate  InvoiceMonth  ...  Discount SaleChannel  ReturnStatus  \
# 0 2010-01-12 09:56:00             1  ...     25.63      Online  Not Returned
# 1 2010-01-12 08:26:00             1  ...     47.14    In-Store      Returned
# 2 2010-01-12 14:53:00             1  ...     30.85      Online      Returned
# 3 2010-01-12 12:03:00             1  ...     19.22    In-Store      Returned
# 4 2010-01-12 14:27:00             1  ...     47.50      Online      Returned
#
#    ProductWeight ProductDimensions ShippingCost    SalesRegion PromotionCode  \
# 0           4.45       40x90x55 cm        11.42           Asia        SALE15
# 1           3.30       31x24x99 cm         7.05         Europe       PROMO10
# 2           1.86       79x94x37 cm        17.77      Australia           NaN
# 3           3.67       81x87x80 cm         7.52  North America           NaN
# 4           7.72       15x59x26 cm         8.25  South America       PROMO10
#
#    PaymentMethod TotalPrice_updated
# 0    Credit Card            15.5925
# 1    Credit Card            16.0650
# 2    Credit Card            13.1250
# 3    Credit Card            21.3570
# 4  Bank Transfer            31.1850
#
# [5 rows x 31 columns]

# %%
old_order_list5 = list(combined_df.columns)
print(old_order_list5)
#new_order_list5 =
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity', 'TotalPrice_orig', 'DiscountedPrice', 'InvoiceDate', 'CleanedInvoiceDate', 'InvoiceMonth', 'InvoiceYear', 'Country', 'CleanedCountry', 'CustomerID', 'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight', 'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode', 'PaymentMethod', 'TotalPrice_updated']

# %%
# Reordenación de filas del DF combinado
new_order_list5 = ['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity', 'TotalPrice_orig', 'TotalPrice_updated', 
                    'DiscountedPrice', 
                    'InvoiceDate', 'CleanedInvoiceDate', 'InvoiceMonth', 'InvoiceYear', 'Country', 'CleanedCountry', 
                    'CustomerID', 'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier', 'StockLevel', 
                    'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight', 'ProductDimensions', 'ShippingCost', 
                    'SalesRegion', 'PromotionCode', 'PaymentMethod']
combined_df = combined_df[new_order_list5]
combined_df.head()
# Out:
#    InvoiceNo StockCode                         Description  UnitPrice  \
# 0   536426.0     22623        BOX OF VINTAGE JIGSAW BLOCKS       4.95
# 1   536365.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER       2.55
# 2   536723.0     21724              RED HARMONICA IN BOX         1.25
# 3   536553.0     71053                 WHITE METAL LANTERN       3.39
# 4   536697.0     22634        BAKING SET 9 PIECE RETROSPOT       4.95
#
#    Quantity  TotalPrice_orig  TotalPrice_updated  DiscountedPrice  \
# 0       3.0            14.85             15.5925           13.365
# 1       6.0            15.30             16.0650           13.770
# 2      10.0            12.50             13.1250           11.250
# 3       6.0            20.34             21.3570           18.306
# 4       6.0            29.70             31.1850           26.730
#
#        InvoiceDate  CleanedInvoiceDate  ...  StockLevel  Discount SaleChannel  \
# 0   12/1/2010 9:56 2010-01-12 09:56:00  ...         956     25.63      Online
# 1   12/1/2010 8:26 2010-01-12 08:26:00  ...         817     47.14    In-Store
# 2  12/1/2010 14:53 2010-01-12 14:53:00  ...         623     30.85      Online
# 3  12/1/2010 12:03 2010-01-12 12:03:00  ...         596     19.22    In-Store
# 4  12/1/2010 14:27 2010-01-12 14:27:00  ...         613     47.50      Online
#
#    ReturnStatus  ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0  Not Returned           4.45       40x90x55 cm        11.42           Asia
# 1      Returned           3.30       31x24x99 cm         7.05         Europe
# 2      Returned           1.86       79x94x37 cm        17.77      Australia
# 3      Returned           3.67       81x87x80 cm         7.52  North America
# 4      Returned           7.72       15x59x26 cm         8.25  South America
#
#   PromotionCode  PaymentMethod
# 0        SALE15    Credit Card
# 1       PROMO10    Credit Card
# 2           NaN    Credit Card
# 3           NaN    Credit Card
# 4       PROMO10  Bank Transfer
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Pregunta 16
# **Join con índices:**
# - Realice un join de dos DataFrames basándose en los índices.

# %%
# join basado en índices
#   - how='inner': opción por defecto('outer' si quieres incluir todas las filas)
joined_df = retail2_df.join(combined_df, lsuffix='_left', rsuffix='_right')

# Visualizar las primeras filas del DF mediante unión
#print(joined_df.head())
joined_df.head()
# Out:
#    InvoiceNo_left StockCode_left  \
# 0        536578.0          84969
# 1        536446.0          21756
# 2        536633.0          22632
# 3        536522.0          22111
# 5        536694.0          22960
#
#                                     Description_left  UnitPrice_left  \
# 0  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...            4.25
# 1                                DOORMAT NEW ENGLAND          795.00
# 2                          HAND WARMER RED POLKA DOT            1.85
# 3       {"description": "SCANDINAVIAN REDS RIBBONS"}            1.65
# 5      {"description": ["JAM MAKING SET WITH JARS"]}            4.25
#
#    Quantity_left  TotalPrice  DiscountedPrice_left InvoiceDate_left  \
# 0            6.0        25.5                 22.95  12/1/2010 12:28
# 1          100.0     79500.0              71550.00  12/1/2010 10:16
# 2            6.0        11.1                  9.99  12/1/2010 13:23
# 3           10.0        16.5                 14.85  12/1/2010 11:32
# 5            6.0        25.5                 22.95  12/1/2010 14:24
#
#   CleanedInvoiceDate_left  InvoiceMonth_left  ...  StockLevel_right  \
# 0     2010-01-12 12:28:00                  1  ...             956.0
# 1     2010-01-12 10:16:00                  1  ...             817.0
# 2     2010-01-12 13:23:00                  1  ...             623.0
# 3     2010-01-12 11:32:00                  1  ...             596.0
# 5     2010-01-12 14:24:00                  1  ...             952.0
#
#   Discount_right SaleChannel_right  ReturnStatus_right ProductWeight_right  \
# 0          25.63            Online        Not Returned                4.45
# 1          47.14          In-Store            Returned                3.30
# 2          30.85            Online            Returned                1.86
# 3          19.22          In-Store            Returned                3.67
# 5           3.76          In-Store        Not Returned                6.46
#
#   ProductDimensions_right ShippingCost_right SalesRegion_right  \
# 0             40x90x55 cm              11.42              Asia
# 1             31x24x99 cm               7.05            Europe
# 2             79x94x37 cm              17.77         Australia
# 3             81x87x80 cm               7.52     North America
# 5             90x75x38 cm              16.97     South America
#
#   PromotionCode_right PaymentMethod_right
# 0              SALE15         Credit Card
# 1             PROMO10         Credit Card
# 2                 NaN         Credit Card
# 3                 NaN         Credit Card
# 5              SALE15           Gift Card
#
# [5 rows x 61 columns]

# %%
# No ha sido necesario resetear los índices para que coincidan
# retail2_df = retail2_df.reset_index(drop=True)
# combined_df = combined_df.reset_index(drop=True)

# %%
joined_df.columns
# Out:
# Index(['InvoiceNo_left', 'StockCode_left', 'Description_left',
#        'UnitPrice_left', 'Quantity_left', 'TotalPrice', 'DiscountedPrice_left',
#        'InvoiceDate_left', 'CleanedInvoiceDate_left', 'InvoiceMonth_left',
#        'InvoiceYear_left', 'Country_left', 'CleanedCountry_left',
#        'CustomerID_left', 'CustomerName_left', 'Email_left', 'Address_left',
#        'PhoneNumber_left', 'Category_left', 'Supplier_left', 'StockLevel_left',
#        'Discount_left', 'SaleChannel_left', 'ReturnStatus_left',
#        'ProductWeight_left', 'ProductDimensions_left', 'ShippingCost_left',
#        'SalesRegion_left', 'PromotionCode_left', 'PaymentMethod_left',
#        'InvoiceNo_right', 'StockCode_right', 'Description_right',
#        'UnitPrice_right', 'Quantity_right', 'TotalPrice_orig',
#        'TotalPrice_updated', 'DiscountedPrice_right', 'InvoiceDate_right',
#        'CleanedInvoiceDate_right', 'InvoiceMonth_right', 'InvoiceYear_right',
#        'Country_right', 'CleanedCountry_right', 'CustomerID_right',
#        'CustomerName_right', 'Email_right', 'Address_right',
#        'PhoneNumber_right', 'Category_right', 'Supplier_right',
#        'StockLevel_right', 'Discount_right', 'SaleChannel_right',
#        'ReturnStatus_right', 'ProductWeight_right', 'ProductDimensions_right',
#        'ShippingCost_right', 'SalesRegion_right', 'PromotionCode_right',
#        'PaymentMethod_right'],
#       dtype='object')

# %% [markdown]
#  _Columnas sin prefijo_
#
#  __'TotalPrice_orig',__
#
#  __'TotalPrice_updated'__,

# %% [markdown]
# ## Pregunta 17
# **Cambio de nivel de índices:**
# - Cambie los niveles de los índices en un MultiIndex en el dataset `retail`.

# %%
# Creación de MultiIndex con columnas 'InvoiceNo' y 'CustomerID'
retail2_multi_df = retail2_df.set_index(['InvoiceNo', 'CustomerID'])
# Visualización
retail2_multi_df.head()
# Out:
#                      StockCode  \
# InvoiceNo CustomerID
# 536578.0  17763          84969
# 536446.0  15939          21756
# 536633.0  12295          22632
# 536522.0  15685          22111
# 536694.0  11946          22960
#
#                                                             Description  \
# InvoiceNo CustomerID
# 536578.0  17763       ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 536446.0  15939                                     DOORMAT NEW ENGLAND
# 536633.0  12295                               HAND WARMER RED POLKA DOT
# 536522.0  15685            {"description": "SCANDINAVIAN REDS RIBBONS"}
# 536694.0  11946           {"description": ["JAM MAKING SET WITH JARS"]}
#
#                       UnitPrice  Quantity  TotalPrice  DiscountedPrice  \
# InvoiceNo CustomerID
# 536578.0  17763            4.25       6.0        25.5            22.95
# 536446.0  15939          795.00     100.0     79500.0         71550.00
# 536633.0  12295            1.85       6.0        11.1             9.99
# 536522.0  15685            1.65      10.0        16.5            14.85
# 536694.0  11946            4.25       6.0        25.5            22.95
#
#                           InvoiceDate  CleanedInvoiceDate  InvoiceMonth  \
# InvoiceNo CustomerID
# 536578.0  17763       12/1/2010 12:28 2010-01-12 12:28:00             1
# 536446.0  15939       12/1/2010 10:16 2010-01-12 10:16:00             1
# 536633.0  12295       12/1/2010 13:23 2010-01-12 13:23:00             1
# 536522.0  15685       12/1/2010 11:32 2010-01-12 11:32:00             1
# 536694.0  11946       12/1/2010 14:24 2010-01-12 14:24:00             1
#
#                       InvoiceYear  ... StockLevel Discount SaleChannel  \
# InvoiceNo CustomerID               ...
# 536578.0  17763              2010  ...        853    17.28      Online
# 536446.0  15939              2010  ...        910     9.08      Online
# 536633.0  12295              2010  ...        578    45.42    In-Store
# 536522.0  15685              2010  ...         75    29.17      Online
# 536694.0  11946              2010  ...        103    23.10    In-Store
#
#                       ReturnStatus ProductWeight ProductDimensions  \
# InvoiceNo CustomerID
# 536578.0  17763       Not Returned          3.81       37x38x83 cm
# 536446.0  15939       Not Returned          9.51        8x65x86 cm
# 536633.0  12295           Returned          7.35       17x71x89 cm
# 536522.0  15685           Returned          6.03        45x4x36 cm
# 536694.0  11946           Returned          1.64       61x54x39 cm
#
#                      ShippingCost    SalesRegion  PromotionCode  PaymentMethod
# InvoiceNo CustomerID
# 536578.0  17763              7.14  North America         SALE15  Bank Transfer
# 536446.0  15939             12.48           Asia         SALE15  Bank Transfer
# 536633.0  12295             14.27  North America      DISCOUNT5  Bank Transfer
# 536522.0  15685             15.54           Asia            NaN         PayPal
# 536694.0  11946              5.15  North America        PROMO20         PayPal
#
# [5 rows x 28 columns]

# %%
# Intercambio de los niveles del MultiIndex
retail2_swapped_df = retail2_multi_df.swaplevel('InvoiceNo', 'CustomerID')
# Visualizar primeras filas
retail2_swapped_df.head()
# Out:
#                      StockCode  \
# CustomerID InvoiceNo
# 17763      536578.0      84969
# 15939      536446.0      21756
# 12295      536633.0      22632
# 15685      536522.0      22111
# 11946      536694.0      22960
#
#                                                             Description  \
# CustomerID InvoiceNo
# 17763      536578.0   ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 15939      536446.0                                 DOORMAT NEW ENGLAND
# 12295      536633.0                           HAND WARMER RED POLKA DOT
# 15685      536522.0        {"description": "SCANDINAVIAN REDS RIBBONS"}
# 11946      536694.0       {"description": ["JAM MAKING SET WITH JARS"]}
#
#                       UnitPrice  Quantity  TotalPrice  DiscountedPrice  \
# CustomerID InvoiceNo
# 17763      536578.0        4.25       6.0        25.5            22.95
# 15939      536446.0      795.00     100.0     79500.0         71550.00
# 12295      536633.0        1.85       6.0        11.1             9.99
# 15685      536522.0        1.65      10.0        16.5            14.85
# 11946      536694.0        4.25       6.0        25.5            22.95
#
#                           InvoiceDate  CleanedInvoiceDate  InvoiceMonth  \
# CustomerID InvoiceNo
# 17763      536578.0   12/1/2010 12:28 2010-01-12 12:28:00             1
# 15939      536446.0   12/1/2010 10:16 2010-01-12 10:16:00             1
# 12295      536633.0   12/1/2010 13:23 2010-01-12 13:23:00             1
# 15685      536522.0   12/1/2010 11:32 2010-01-12 11:32:00             1
# 11946      536694.0   12/1/2010 14:24 2010-01-12 14:24:00             1
#
#                       InvoiceYear  ... StockLevel Discount SaleChannel  \
# CustomerID InvoiceNo               ...
# 17763      536578.0          2010  ...        853    17.28      Online
# 15939      536446.0          2010  ...        910     9.08      Online
# 12295      536633.0          2010  ...        578    45.42    In-Store
# 15685      536522.0          2010  ...         75    29.17      Online
# 11946      536694.0          2010  ...        103    23.10    In-Store
#
#                       ReturnStatus ProductWeight ProductDimensions  \
# CustomerID InvoiceNo
# 17763      536578.0   Not Returned          3.81       37x38x83 cm
# 15939      536446.0   Not Returned          9.51        8x65x86 cm
# 12295      536633.0       Returned          7.35       17x71x89 cm
# 15685      536522.0       Returned          6.03        45x4x36 cm
# 11946      536694.0       Returned          1.64       61x54x39 cm
#
#                      ShippingCost    SalesRegion  PromotionCode  PaymentMethod
# CustomerID InvoiceNo
# 17763      536578.0          7.14  North America         SALE15  Bank Transfer
# 15939      536446.0         12.48           Asia         SALE15  Bank Transfer
# 12295      536633.0         14.27  North America      DISCOUNT5  Bank Transfer
# 15685      536522.0         15.54           Asia            NaN         PayPal
# 11946      536694.0          5.15  North America        PROMO20         PayPal
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Pregunta 18
# **Reordenamiento de niveles:**
# - Reordene los niveles del índice en un DataFrame con MultiIndex.

# %%
# Verificación del orden de los niveles
print(retail2_swapped_df.index.names)
# Out:
# ['CustomerID', 'InvoiceNo']

# %%
# Reordenaciónd de niveles
retail2_reorder_df = retail2_swapped_df.reorder_levels(['InvoiceNo', 'CustomerID'])
retail2_reorder_df.head()
# Out:
#                      StockCode  \
# InvoiceNo CustomerID
# 536578.0  17763          84969
# 536446.0  15939          21756
# 536633.0  12295          22632
# 536522.0  15685          22111
# 536694.0  11946          22960
#
#                                                             Description  \
# InvoiceNo CustomerID
# 536578.0  17763       ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 536446.0  15939                                     DOORMAT NEW ENGLAND
# 536633.0  12295                               HAND WARMER RED POLKA DOT
# 536522.0  15685            {"description": "SCANDINAVIAN REDS RIBBONS"}
# 536694.0  11946           {"description": ["JAM MAKING SET WITH JARS"]}
#
#                       UnitPrice  Quantity  TotalPrice  DiscountedPrice  \
# InvoiceNo CustomerID
# 536578.0  17763            4.25       6.0        25.5            22.95
# 536446.0  15939          795.00     100.0     79500.0         71550.00
# 536633.0  12295            1.85       6.0        11.1             9.99
# 536522.0  15685            1.65      10.0        16.5            14.85
# 536694.0  11946            4.25       6.0        25.5            22.95
#
#                           InvoiceDate  CleanedInvoiceDate  InvoiceMonth  \
# InvoiceNo CustomerID
# 536578.0  17763       12/1/2010 12:28 2010-01-12 12:28:00             1
# 536446.0  15939       12/1/2010 10:16 2010-01-12 10:16:00             1
# 536633.0  12295       12/1/2010 13:23 2010-01-12 13:23:00             1
# 536522.0  15685       12/1/2010 11:32 2010-01-12 11:32:00             1
# 536694.0  11946       12/1/2010 14:24 2010-01-12 14:24:00             1
#
#                       InvoiceYear  ... StockLevel Discount SaleChannel  \
# InvoiceNo CustomerID               ...
# 536578.0  17763              2010  ...        853    17.28      Online
# 536446.0  15939              2010  ...        910     9.08      Online
# 536633.0  12295              2010  ...        578    45.42    In-Store
# 536522.0  15685              2010  ...         75    29.17      Online
# 536694.0  11946              2010  ...        103    23.10    In-Store
#
#                       ReturnStatus ProductWeight ProductDimensions  \
# InvoiceNo CustomerID
# 536578.0  17763       Not Returned          3.81       37x38x83 cm
# 536446.0  15939       Not Returned          9.51        8x65x86 cm
# 536633.0  12295           Returned          7.35       17x71x89 cm
# 536522.0  15685           Returned          6.03        45x4x36 cm
# 536694.0  11946           Returned          1.64       61x54x39 cm
#
#                      ShippingCost    SalesRegion  PromotionCode  PaymentMethod
# InvoiceNo CustomerID
# 536578.0  17763              7.14  North America         SALE15  Bank Transfer
# 536446.0  15939             12.48           Asia         SALE15  Bank Transfer
# 536633.0  12295             14.27  North America      DISCOUNT5  Bank Transfer
# 536522.0  15685             15.54           Asia            NaN         PayPal
# 536694.0  11946              5.15  North America        PROMO20         PayPal
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Pregunta 19
# **Agregación por nivel:**
# - Realice una agregación de los datos por nivel en un MultiIndex.

# %%
# Agregación de los precios totales('TotalPrice') por cliente('CustomerID')
customer_totalprice = retail2_multi_df.groupby(level='CustomerID')['TotalPrice'].sum()
customer_totalprice
# Out:
# CustomerID
# 10018      14.85
# 10049      15.30
# 10082      12.50
# 10112      20.34
# 10139      29.70
#           ...
# 19741      30.00
# 19765    3180.00
# 19821      30.00
# 19865      15.00
# 19944      16.50
# Name: TotalPrice, Length: 380, dtype: float64

# %% [markdown]
# ## Pregunta 20
# **Creación de MultiIndex:**
# - Cree un MultiIndex a partir de las columnas `Country` y `InvoiceYear` en el dataset `retail`.

# %%
# MultiIndex con columnas 'Country' e 'InvoiceYear'
retail2_multi2_df = retail2_df.set_index(['CleanedCountry', 'InvoiceYear'])

# Visualización
#print(retail2_df.head())
retail2_multi2_df.head()
# Out:
#                             InvoiceNo StockCode  \
# CleanedCountry InvoiceYear
# United Kingdom 2010          536578.0     84969
#                2010          536446.0     21756
#                2010          536633.0     22632
#                2010          536522.0     22111
#                2010          536694.0     22960
#
#                                                                   Description  \
# CleanedCountry InvoiceYear
# United Kingdom 2010         ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
#                2010                                       DOORMAT NEW ENGLAND
#                2010                                 HAND WARMER RED POLKA DOT
#                2010              {"description": "SCANDINAVIAN REDS RIBBONS"}
#                2010             {"description": ["JAM MAKING SET WITH JARS"]}
#
#                             UnitPrice  Quantity  TotalPrice  DiscountedPrice  \
# CleanedCountry InvoiceYear
# United Kingdom 2010              4.25       6.0        25.5            22.95
#                2010            795.00     100.0     79500.0         71550.00
#                2010              1.85       6.0        11.1             9.99
#                2010              1.65      10.0        16.5            14.85
#                2010              4.25       6.0        25.5            22.95
#
#                                 InvoiceDate  CleanedInvoiceDate  InvoiceMonth  \
# CleanedCountry InvoiceYear
# United Kingdom 2010         12/1/2010 12:28 2010-01-12 12:28:00             1
#                2010         12/1/2010 10:16 2010-01-12 10:16:00             1
#                2010         12/1/2010 13:23 2010-01-12 13:23:00             1
#                2010         12/1/2010 11:32 2010-01-12 11:32:00             1
#                2010         12/1/2010 14:24 2010-01-12 14:24:00             1
#
#                             ... StockLevel  Discount SaleChannel  \
# CleanedCountry InvoiceYear  ...
# United Kingdom 2010         ...        853     17.28      Online
#                2010         ...        910      9.08      Online
#                2010         ...        578     45.42    In-Store
#                2010         ...         75     29.17      Online
#                2010         ...        103     23.10    In-Store
#
#                             ReturnStatus ProductWeight ProductDimensions  \
# CleanedCountry InvoiceYear
# United Kingdom 2010         Not Returned          3.81       37x38x83 cm
#                2010         Not Returned          9.51        8x65x86 cm
#                2010             Returned          7.35       17x71x89 cm
#                2010             Returned          6.03        45x4x36 cm
#                2010             Returned          1.64       61x54x39 cm
#
#                            ShippingCost    SalesRegion  PromotionCode  \
# CleanedCountry InvoiceYear
# United Kingdom 2010                7.14  North America         SALE15
#                2010               12.48           Asia         SALE15
#                2010               14.27  North America      DISCOUNT5
#                2010               15.54           Asia            NaN
#                2010                5.15  North America        PROMO20
#
#                             PaymentMethod
# CleanedCountry InvoiceYear
# United Kingdom 2010         Bank Transfer
#                2010         Bank Transfer
#                2010         Bank Transfer
#                2010                PayPal
#                2010                PayPal
#
# [5 rows x 28 columns]

# %%
# Comprobaciónd de los índices de 'retail2_df'
print(retail2_multi2_df.index.names)
# Out:
# ['CleanedCountry', 'InvoiceYear']

# %%
# Comprobación de las columnas de 'retail2_df'
list(retail2_multi2_df.columns)
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'UnitPrice',
#  'Quantity',
#  'TotalPrice',
#  'DiscountedPrice',
#  'InvoiceDate',
#  'CleanedInvoiceDate',
#  'InvoiceMonth',
#  'Country',
#  'CustomerID',
#  'CustomerName',
#  'Email',
#  'Address',
#  'PhoneNumber',
#  'Category',
#  'Supplier',
#  'StockLevel',
#  'Discount',
#  'SaleChannel',
#  'ReturnStatus',
#  'ProductWeight',
#  'ProductDimensions',
#  'ShippingCost',
#  'SalesRegion',
#  'PromotionCode',
#  'PaymentMethod']

# %% [markdown]
# # Parte 3 Data Aggregation and Group Operations (Capitulo 10)

# %% [markdown]
# ## Pregunta 21
# **Agrupación por cliente:**
# - Agrupe los datos del dataset `retail` por `CustomerID` y calcule el total de `TotalPrice` por cliente.

# %%
# Agregación de los precios totales('TotalPrice') por cliente('CustomerID')
customer_totalprice = retail2_multi_df.groupby(level='CustomerID')['TotalPrice'].sum()
customer_totalprice.head()
# Out:
# CustomerID
# 10018    14.85
# 10049    15.30
# 10082    12.50
# 10112    20.34
# 10139    29.70
# Name: TotalPrice, dtype: float64

# %% [markdown]
# ## Pregunta 22
# **Agrupación por producto:**
# - Agrupe los datos del dataset `retail` por `StockCode` y calcule la cantidad total vendida (`Quantity`).

# %%
# Agregación de la cantidad('Quantity') por código en almacén('StockCode')
quantity_stockcode = retail2_df.groupby('StockCode')['Quantity'].sum()
quantity_stockcode.head()
# Out:
# StockCode
# 21723    340.0
# 21724    190.0
# 21730     42.0
# 21731    168.0
# 21754     24.0
# Name: Quantity, dtype: float64

# %% [markdown]
# ## Pregunta 23
# **Agrupación por mes y año:**
# - Agrupe los datos del dataset `retail` por `InvoiceMonth` y `InvoiceYear`, y calcule el total de `TotalPrice`.

# %%
# Agregación del precio final('TotalPrice') por mes de factura('InvoiceMonth') 
# y año de factura('InvoiceYear')
invoicemonthyear_totalprice = retail2_df.groupby(['InvoiceMonth', 'InvoiceYear'])['TotalPrice'].sum()
invoicemonthyear_totalprice.head()
# Out:
# InvoiceMonth  InvoiceYear
# 0             0               12662.79
# 1             1900              133.97
#               2010           214406.75
#               2050              143.60
# 2             2010              134.34
# Name: TotalPrice, dtype: float64

# %% [markdown]
# ## Pregunta 24
# **Conteo de transacciones:**
# - Cuente el número total de transacciones por `Country` y `InvoiceYear`.

# %%
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice  DiscountedPrice      InvoiceDate  \
# 0       4.25       6.0        25.5            22.95  12/1/2010 12:28
# 1     795.00     100.0     79500.0         71550.00  12/1/2010 10:16
# 2       1.85       6.0        11.1             9.99  12/1/2010 13:23
# 3       1.65      10.0        16.5            14.85  12/1/2010 11:32
# 5       4.25       6.0        25.5            22.95  12/1/2010 14:24
#
#    CleanedInvoiceDate  InvoiceMonth  ...  StockLevel Discount SaleChannel  \
# 0 2010-01-12 12:28:00             1  ...         853    17.28      Online
# 1 2010-01-12 10:16:00             1  ...         910     9.08      Online
# 2 2010-01-12 13:23:00             1  ...         578    45.42    In-Store
# 3 2010-01-12 11:32:00             1  ...          75    29.17      Online
# 5 2010-01-12 14:24:00             1  ...         103    23.10    In-Store
#
#    ReturnStatus ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0  Not Returned          3.81       37x38x83 cm         7.14  North America
# 1  Not Returned          9.51        8x65x86 cm        12.48           Asia
# 2      Returned          7.35       17x71x89 cm        14.27  North America
# 3      Returned          6.03        45x4x36 cm        15.54           Asia
# 5      Returned          1.64       61x54x39 cm         5.15  North America
#
#   PromotionCode  PaymentMethod
# 0        SALE15  Bank Transfer
# 1        SALE15  Bank Transfer
# 2     DISCOUNT5  Bank Transfer
# 3           NaN         PayPal
# 5       PROMO20         PayPal
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Pregunta 25
# **Función de agregación personalizada:**
# - Cree una función de agregación personalizada que calcule el promedio y la desviación estándar de `TotalPrice` por `Country`.

# %%
# Definición de función de agregación que calcula 
#   - el promedio 
#   - la desviación estándar
def agg_totalprice(group):
    return pd.Series({
        'MeanTotalPrice': group['TotalPrice'].mean(),
        'StdTotalPrice': group['TotalPrice'].std()
    })
# Agrupación por país (CleanedCountry') y aplicación de la función de agregación
grouped_by_country = retail2_df.groupby('CleanedCountry').apply(agg_totalprice, include_groups=False)
# Visualización
#print(grouped_by_country.head())
grouped_by_country.head(15)
# Out:
#                                            MeanTotalPrice  StdTotalPrice
# CleanedCountry
# United Kingdom                                 905.270000    7211.328349
# box of vintage alphabet blocks                  19.900000            NaN
# box of vintage jigsaw blocks                    14.850000            NaN
# chocolate hot water bottle                      33.900000            NaN
# denmark                                        433.642661    4000.687161
# england                                         16.987500       2.061704
# feltcraft princess charlotte doll               30.000000            NaN
# germany                                        507.766034    3363.844270
# knitted union flag hot water bottle             20.340000            NaN
# red harmonica in box                            12.500000            NaN
# scandinavian reds ribbons                       16.500000       0.000000
# striped charlielola charlotte bag details       59.000000            NaN

# %% [markdown]
# ## Pregunta 26
# **Agrupación y transformaciones:**
# - Agrupe los datos por `CustomerID` y normalice el `TotalPrice` restando la media y dividiendo por la desviación estándar dentro de cada grupo.

# %%
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice  DiscountedPrice      InvoiceDate  \
# 0       4.25       6.0        25.5            22.95  12/1/2010 12:28
# 1     795.00     100.0     79500.0         71550.00  12/1/2010 10:16
# 2       1.85       6.0        11.1             9.99  12/1/2010 13:23
# 3       1.65      10.0        16.5            14.85  12/1/2010 11:32
# 5       4.25       6.0        25.5            22.95  12/1/2010 14:24
#
#    CleanedInvoiceDate  InvoiceMonth  ...  StockLevel Discount SaleChannel  \
# 0 2010-01-12 12:28:00             1  ...         853    17.28      Online
# 1 2010-01-12 10:16:00             1  ...         910     9.08      Online
# 2 2010-01-12 13:23:00             1  ...         578    45.42    In-Store
# 3 2010-01-12 11:32:00             1  ...          75    29.17      Online
# 5 2010-01-12 14:24:00             1  ...         103    23.10    In-Store
#
#    ReturnStatus ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0  Not Returned          3.81       37x38x83 cm         7.14  North America
# 1  Not Returned          9.51        8x65x86 cm        12.48           Asia
# 2      Returned          7.35       17x71x89 cm        14.27  North America
# 3      Returned          6.03        45x4x36 cm        15.54           Asia
# 5      Returned          1.64       61x54x39 cm         5.15  North America
#
#   PromotionCode  PaymentMethod
# 0        SALE15  Bank Transfer
# 1        SALE15  Bank Transfer
# 2     DISCOUNT5  Bank Transfer
# 3           NaN         PayPal
# 5       PROMO20         PayPal
#
# [5 rows x 30 columns]

# %%
print(list(retail2_df.columns))
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity', 'TotalPrice', 'DiscountedPrice', 'InvoiceDate', 'CleanedInvoiceDate', 'InvoiceMonth', 'InvoiceYear', 'Country', 'CleanedCountry', 'CustomerID', 'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight', 'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode', 'PaymentMethod']

# %%
retail2_df['TotalPrice'].dtype
# Out:
# dtype('float64')

# %%
# Agrupación por 'CustomerID' y normalización de 'TotalPrice'
normalized_total_price = retail2_df.groupby('CustomerID')['TotalPrice'].transform(
    lambda x: (x - x.mean()) / x.std()
)
# Inserción nueva columna
retail2_df.insert(7, 'NormalizedTotalPrice', normalized_total_price)
# Visualización
print(retail2_df[['CustomerID', 'TotalPrice', 'NormalizedTotalPrice']].head())
# Out:
#    CustomerID  TotalPrice  NormalizedTotalPrice
# 0       17763        25.5                   NaN
# 1       15939     79500.0                   NaN
# 2       12295        11.1                   NaN
# 3       15685        16.5                   NaN
# 5       11946        25.5                   NaN

# %%
normalized_total_price_serie = retail2_df['NormalizedTotalPrice']
print(normalized_total_price_serie.values)
# Out:
# [        nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#   0.70710678         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.70710678         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#   0.70710678         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan  0.70710678         nan         nan         nan
#          nan         nan -0.70710678         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.70710678         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan -0.70710678
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan  0.70710678         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan]

# %%
print(f"Valores nulos en columna 'NormalizedTotalPrice':\n {retail2_df['NormalizedTotalPrice'].isna().sum()}")
# Out:
# Valores nulos en columna 'NormalizedTotalPrice':
#  378

# %% [markdown]
# ## Pregunta 27
# **Filtrado de grupos:**
# - Filtre los grupos de `CustomerID` que tengan un `TotalPrice` promedio mayor a 500.

# %%
# Agrupación por 'CustomerID' y cálculo del promedio de 'TotalPrice'
grouped_customers = retail2_df.groupby('CustomerID')['TotalPrice'].mean()
# Filtrado de grupos con promedio 'TotalPrice' mayor a 500
filtered_customers = grouped_customers[grouped_customers > 500]
# Obtener solo las filas correspondientes a estos 'CustomerID' filtrados
filtered_retail2_df = retail2_df[retail2_df['CustomerID'].isin(filtered_customers.index)]
# Visualización
# print(filtered_retail2_df.head())
filtered_retail2_df.head()
# Out:
#      InvoiceNo StockCode                          Description  UnitPrice  \
# 1     536446.0     21756                  DOORMAT NEW ENGLAND      795.0
# 33    536543.0     21755             LOVE BUILDING BLOCK WORD      595.0
# 67    536667.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE      339.0
# 121   536403.0    84907B     PACK OF 12 RED RETROSPOT TISSUES       85.0
# 155   536644.0     21777          RECIPE BOX WITH METAL HEART      795.0
#
#      Quantity  TotalPrice  DiscountedPrice  NormalizedTotalPrice  \
# 1       100.0     79500.0          71550.0                   NaN
# 33        3.0      1785.0           1606.5                   NaN
# 67       60.0     20340.0          18306.0                   NaN
# 121     200.0     17000.0          15300.0                   NaN
# 155       4.0      3180.0           2862.0                   NaN
#
#          InvoiceDate  CleanedInvoiceDate  ...  StockLevel  Discount  \
# 1    12/1/2010 10:16 2010-01-12 10:16:00  ...         910      9.08
# 33   12/1/2010 11:53 2010-01-12 11:53:00  ...         900     29.56
# 67   12/1/2010 13:57 2010-01-12 13:57:00  ...         696      3.35
# 121   12/1/2010 9:33 2010-01-12 09:33:00  ...         253     21.07
# 155  12/1/2010 13:34 2010-01-12 13:34:00  ...         192      5.89
#
#     SaleChannel  ReturnStatus  ProductWeight ProductDimensions ShippingCost  \
# 1        Online  Not Returned           9.51        8x65x86 cm        12.48
# 33       Online  Not Returned           9.49       77x92x29 cm        18.42
# 67     In-Store  Not Returned           8.04       52x38x97 cm        11.38
# 121    In-Store      Returned           8.97        6x66x84 cm        15.60
# 155      Online  Not Returned           2.50       72x39x14 cm        15.00
#
#     SalesRegion PromotionCode  PaymentMethod
# 1          Asia        SALE15  Bank Transfer
# 33    Australia           NaN    Credit Card
# 67    Australia       PROMO20         PayPal
# 121   Australia     DISCOUNT5           Cash
# 155        Asia     DISCOUNT5    Credit Card
#
# [5 rows x 31 columns]

# %%
# Comprobación del número de registros filtrados
filtered_retail2_df.shape
# Out:
# (13, 31)

# %% [markdown]
# ## Pregunta 28
# **Aplicación de múltiples funciones:**
# - Aplique múltiples funciones de agregación (suma, promedio, máximo) a la columna `TotalPrice` agrupando por `Country`.

# %%
print(list(retail2_df.columns))
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity', 'TotalPrice', 'DiscountedPrice', 'NormalizedTotalPrice', 'InvoiceDate', 'CleanedInvoiceDate', 'InvoiceMonth', 'InvoiceYear', 'Country', 'CleanedCountry', 'CustomerID', 'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category', 'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus', 'ProductWeight', 'ProductDimensions', 'ShippingCost', 'SalesRegion', 'PromotionCode', 'PaymentMethod']

# %%
# A) Cálculo INDIVIDUALIZADO de funciones de agregación(media, máximo y sumatorio) agrupando por paises
# country_mean = retail2_df.groupby('CleanedCountry')['TotalPrice'].mean()
# country_max = retail2_df.groupby('CleanedCountry')['TotalPrice'].max()
# country_sum = retail2_df.groupby('CleanedCountry')['TotalPrice'].sum()

# B) Cálculo GRUPAL de funciones de agregación a 'TotalPrice' agrupado por 'Country'
aggregated_data = retail2_df.groupby('Country')['TotalPrice'].agg(['sum', 'mean', 'max'])
# Visualización
print(aggregated_data)
# Out:
#                                                    sum        mean       max
# Country
# ### CHOCOLATE HOT WATER BOTTLE ###               33.90   33.900000     33.90
# ### FELTCRAFT PRINCESS CHARLOTTE DOLL ###        30.00   30.000000     30.00
# ### U.K. ###                                     19.80   19.800000     19.80
# ### united kingdom ###                           20.34   20.340000     20.34
# BOX OF VINTAGE ALPHABET BLOCKS                   19.90   19.900000     19.90
# BOX OF VINTAGE JIGSAW BLOCKS                     14.85   14.850000     14.85
# Denmark                                       47267.05  433.642661  41700.00
# England                                          67.95   16.987500     19.50
# Germany                                       58900.86  507.766034  20340.00
# KNITTED UNION FLAG HOT WATER BOTTLE              20.34   20.340000     20.34
# RED HARMONICA IN BOX                             12.50   12.500000     12.50
# SCANDINAVIAN REDS RIBBONS                        33.00   16.500000     16.50
# STRIPED CHARLIE+LOLA CHARLOTTE BAG: details      59.00   59.000000     59.00
# U.K.                                            105.50   35.166667     59.00
# United Kingdom                               121008.60  975.875806  79500.00
# united kingdom                                  151.94   30.388000     47.70

# %% [markdown]
# ## Pregunta 29
# **Creación de columnas derivadas:**
# - Cree una nueva columna `AvgTotalPrice` que contenga el promedio de `TotalPrice` por `CustomerID`.

# %%
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice  DiscountedPrice  NormalizedTotalPrice  \
# 0       4.25       6.0        25.5            22.95                   NaN
# 1     795.00     100.0     79500.0         71550.00                   NaN
# 2       1.85       6.0        11.1             9.99                   NaN
# 3       1.65      10.0        16.5            14.85                   NaN
# 5       4.25       6.0        25.5            22.95                   NaN
#
#        InvoiceDate  CleanedInvoiceDate  ...  StockLevel  Discount SaleChannel  \
# 0  12/1/2010 12:28 2010-01-12 12:28:00  ...         853     17.28      Online
# 1  12/1/2010 10:16 2010-01-12 10:16:00  ...         910      9.08      Online
# 2  12/1/2010 13:23 2010-01-12 13:23:00  ...         578     45.42    In-Store
# 3  12/1/2010 11:32 2010-01-12 11:32:00  ...          75     29.17      Online
# 5  12/1/2010 14:24 2010-01-12 14:24:00  ...         103     23.10    In-Store
#
#    ReturnStatus  ProductWeight ProductDimensions ShippingCost    SalesRegion  \
# 0  Not Returned           3.81       37x38x83 cm         7.14  North America
# 1  Not Returned           9.51        8x65x86 cm        12.48           Asia
# 2      Returned           7.35       17x71x89 cm        14.27  North America
# 3      Returned           6.03        45x4x36 cm        15.54           Asia
# 5      Returned           1.64       61x54x39 cm         5.15  North America
#
#   PromotionCode  PaymentMethod
# 0        SALE15  Bank Transfer
# 1        SALE15  Bank Transfer
# 2     DISCOUNT5  Bank Transfer
# 3           NaN         PayPal
# 5       PROMO20         PayPal
#
# [5 rows x 31 columns]

# %%
# Cálculo de la media de precio final agrupado por cliente
totalprice_avg = retail2_df.groupby('CustomerID')['TotalPrice'].transform('mean')
# Inserción de la nueva fila 
retail2_df.insert(6, 'TotalPriceAvg', totalprice_avg)
# Visualización
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice  TotalPriceAvg  DiscountedPrice  \
# 0       4.25       6.0        25.5           25.5            22.95
# 1     795.00     100.0     79500.0        79500.0         71550.00
# 2       1.85       6.0        11.1           11.1             9.99
# 3       1.65      10.0        16.5           16.5            14.85
# 5       4.25       6.0        25.5           25.5            22.95
#
#    NormalizedTotalPrice      InvoiceDate  ... StockLevel  Discount  \
# 0                   NaN  12/1/2010 12:28  ...        853     17.28
# 1                   NaN  12/1/2010 10:16  ...        910      9.08
# 2                   NaN  12/1/2010 13:23  ...        578     45.42
# 3                   NaN  12/1/2010 11:32  ...         75     29.17
# 5                   NaN  12/1/2010 14:24  ...        103     23.10
#
#    SaleChannel  ReturnStatus ProductWeight  ProductDimensions ShippingCost  \
# 0       Online  Not Returned          3.81        37x38x83 cm         7.14
# 1       Online  Not Returned          9.51         8x65x86 cm        12.48
# 2     In-Store      Returned          7.35        17x71x89 cm        14.27
# 3       Online      Returned          6.03         45x4x36 cm        15.54
# 5     In-Store      Returned          1.64        61x54x39 cm         5.15
#
#      SalesRegion PromotionCode  PaymentMethod
# 0  North America        SALE15  Bank Transfer
# 1           Asia        SALE15  Bank Transfer
# 2  North America     DISCOUNT5  Bank Transfer
# 3           Asia           NaN         PayPal
# 5  North America       PROMO20         PayPal
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Pregunta 30
# **Uso de transformaciones window:**
# - Utilice una transformación de ventana para calcular la media móvil de 3 períodos de `TotalPrice` para cada `CustomerID`.

# %%
retail2_df.head()
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
# 3   536522.0     22111       {"description": "SCANDINAVIAN REDS RIBBONS"}
# 5   536694.0     22960      {"description": ["JAM MAKING SET WITH JARS"]}
#
#    UnitPrice  Quantity  TotalPrice  TotalPriceAvg  DiscountedPrice  \
# 0       4.25       6.0        25.5           25.5            22.95
# 1     795.00     100.0     79500.0        79500.0         71550.00
# 2       1.85       6.0        11.1           11.1             9.99
# 3       1.65      10.0        16.5           16.5            14.85
# 5       4.25       6.0        25.5           25.5            22.95
#
#    NormalizedTotalPrice      InvoiceDate  ... StockLevel  Discount  \
# 0                   NaN  12/1/2010 12:28  ...        853     17.28
# 1                   NaN  12/1/2010 10:16  ...        910      9.08
# 2                   NaN  12/1/2010 13:23  ...        578     45.42
# 3                   NaN  12/1/2010 11:32  ...         75     29.17
# 5                   NaN  12/1/2010 14:24  ...        103     23.10
#
#    SaleChannel  ReturnStatus ProductWeight  ProductDimensions ShippingCost  \
# 0       Online  Not Returned          3.81        37x38x83 cm         7.14
# 1       Online  Not Returned          9.51         8x65x86 cm        12.48
# 2     In-Store      Returned          7.35        17x71x89 cm        14.27
# 3       Online      Returned          6.03         45x4x36 cm        15.54
# 5     In-Store      Returned          1.64        61x54x39 cm         5.15
#
#      SalesRegion PromotionCode  PaymentMethod
# 0  North America        SALE15  Bank Transfer
# 1           Asia        SALE15  Bank Transfer
# 2  North America     DISCOUNT5  Bank Transfer
# 3           Asia           NaN         PayPal
# 5  North America       PROMO20         PayPal
#
# [5 rows x 32 columns]

# %%
# Ordenación de los datos por 'CustomerID' y de un índice temporal (por ejemplo, 'CleanedInvoiceDate')
retail2_df = retail2_df.sort_values(['CustomerID', 'CleanedInvoiceDate'])
# Cálculo de la media móvil de 3 períodos de 'TotalPrice' por 'CustomerID'
#   - Rolling window: La función rolling('window=3') define una ventana móvil de 3 períodos
#   - 'min_periods=1' asegura que se calcule un valor incluso si hay menos de 3 observaciones al principio
customer_totalprice_moving_avg = retail2_df.groupby('CustomerID')['TotalPrice'].transform(
    lambda x: x.rolling(window=3, min_periods=1).mean()
    )
retail2_df.insert(9, 'CustomerTotalPriceMovingAvg', customer_totalprice_moving_avg)
# Visualización 10 primeros registros
print(retail2_df[['CustomerID', 'CleanedInvoiceDate', 'TotalPrice', 'CustomerTotalPriceMovingAvg']].head(10))
# Out:
#      CustomerID  CleanedInvoiceDate  TotalPrice  CustomerTotalPriceMovingAvg
# 310       10018 2010-01-12 09:56:00       14.85                        14.85
# 307       10049 2010-01-12 08:26:00       15.30                        15.30
# 387       10082 2010-01-12 14:53:00       12.50                        12.50
# 293       10112 2010-01-12 12:03:00       20.34                        20.34
# 296       10139 2010-01-12 14:27:00       29.70                        29.70
# 200       10152 2010-01-12 11:28:00       25.50                        25.50
# 216       10166 2010-01-12 12:56:00       25.50                        25.50
# 235       10174 2010-01-12 11:11:00       15.30                        15.30
# 337       10201 2010-01-12 10:23:00       20.34                        20.34
# 139       10270 1900-01-01 00:00:00       12.50                        12.50

# %% [markdown]
# # Parte 4 - Time Series (capítulo 11)

# %% [markdown]
# ## Pregunta 31
# **Conversión a índice de tiempo:**
# - Convierta la columna `InvoiceDate` a un índice de tiempo en el dataset `retail`.

# %%
# Como la columna ha sido transformada a tipo datetime,
# se establece 'CleanedInvoiceDate' como índice del DF
retail2_df.set_index('CleanedInvoiceDate', inplace=True)
# Visualización
retail2_df.head()
# Out:
#                      InvoiceNo StockCode                         Description  \
# CleanedInvoiceDate
# 2010-01-12 09:56:00   536426.0     22623        BOX OF VINTAGE JIGSAW BLOCKS
# 2010-01-12 08:26:00   536365.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# 2010-01-12 14:53:00   536723.0     21724              RED HARMONICA IN BOX
# 2010-01-12 12:03:00   536553.0     71053                 WHITE METAL LANTERN
# 2010-01-12 14:27:00   536697.0     22634        BAKING SET 9 PIECE RETROSPOT
#
#                      UnitPrice  Quantity  TotalPrice  TotalPriceAvg  \
# CleanedInvoiceDate
# 2010-01-12 09:56:00       4.95       3.0       14.85          14.85
# 2010-01-12 08:26:00       2.55       6.0       15.30          15.30
# 2010-01-12 14:53:00       1.25      10.0       12.50          12.50
# 2010-01-12 12:03:00       3.39       6.0       20.34          20.34
# 2010-01-12 14:27:00       4.95       6.0       29.70          29.70
#
#                      DiscountedPrice  NormalizedTotalPrice  \
# CleanedInvoiceDate
# 2010-01-12 09:56:00           13.365                   NaN
# 2010-01-12 08:26:00           13.770                   NaN
# 2010-01-12 14:53:00           11.250                   NaN
# 2010-01-12 12:03:00           18.306                   NaN
# 2010-01-12 14:27:00           26.730                   NaN
#
#                      CustomerTotalPriceMovingAvg  ... StockLevel  Discount  \
# CleanedInvoiceDate                                ...
# 2010-01-12 09:56:00                        14.85  ...        956     25.63
# 2010-01-12 08:26:00                        15.30  ...        817     47.14
# 2010-01-12 14:53:00                        12.50  ...        623     30.85
# 2010-01-12 12:03:00                        20.34  ...        596     19.22
# 2010-01-12 14:27:00                        29.70  ...        613     47.50
#
#                      SaleChannel  ReturnStatus ProductWeight  \
# CleanedInvoiceDate
# 2010-01-12 09:56:00       Online  Not Returned          4.45
# 2010-01-12 08:26:00     In-Store      Returned          3.30
# 2010-01-12 14:53:00       Online      Returned          1.86
# 2010-01-12 12:03:00     In-Store      Returned          3.67
# 2010-01-12 14:27:00       Online      Returned          7.72
#
#                      ProductDimensions ShippingCost    SalesRegion  \
# CleanedInvoiceDate
# 2010-01-12 09:56:00        40x90x55 cm        11.42           Asia
# 2010-01-12 08:26:00        31x24x99 cm         7.05         Europe
# 2010-01-12 14:53:00        79x94x37 cm        17.77      Australia
# 2010-01-12 12:03:00        81x87x80 cm         7.52  North America
# 2010-01-12 14:27:00        15x59x26 cm         8.25  South America
#
#                     PromotionCode  PaymentMethod
# CleanedInvoiceDate
# 2010-01-12 09:56:00        SALE15    Credit Card
# 2010-01-12 08:26:00       PROMO10    Credit Card
# 2010-01-12 14:53:00           NaN    Credit Card
# 2010-01-12 12:03:00           NaN    Credit Card
# 2010-01-12 14:27:00       PROMO10  Bank Transfer
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Pregunta 32
# **Remuestreo de datos:**
# - Remuestrear los datos del dataset `retail` a una frecuencia mensual y calcule el total de `TotalPrice` por mes.

# %%
# Remuestreo de los datos a frecuencia mensual y cálculo del total de 'TotalPrice' por mes(Month End)
monthly_total = retail2_df.resample('ME').sum()['TotalPrice']
# Visualización
monthly_total
# Out:
# CleanedInvoiceDate
# 1900-01-31    133.97
# 1900-02-28      0.00
# 1900-03-31      0.00
# 1900-04-30      0.00
# 1900-05-31      0.00
#                ...
# 2049-09-30      0.00
# 2049-10-31      0.00
# 2049-11-30      0.00
# 2049-12-31      0.00
# 2050-01-31    143.60
# Name: TotalPrice, Length: 1801, dtype: float64

# %% [markdown]
# ## Pregunta 33
# **Cambio de frecuencia:**
# - Cambie la frecuencia de los datos del dataset `retail` a trimestral y calcule el total de `TotalPrice` por trimestre.

# %%
# Remuestreo de los datos a frecuencia trimestral 
# y cálculo del total de 'TotalPrice' por trimestre(Quarter End)
quarte_total = retail2_df.resample('QE').sum()['TotalPrice']
# Visualización
quarte_total
# Out:
# CleanedInvoiceDate
# 1900-03-31    133.97
# 1900-06-30      0.00
# 1900-09-30      0.00
# 1900-12-31      0.00
# 1901-03-31      0.00
#                ...
# 2049-03-31      0.00
# 2049-06-30      0.00
# 2049-09-30      0.00
# 2049-12-31      0.00
# 2050-03-31    143.60
# Name: TotalPrice, Length: 601, dtype: float64

# %% [markdown]
# ## Pregunta 34
# **Desplazamiento de datos:**
# - Desplace los datos de `TotalPrice` en el dataset `retail` un período hacia adelante.

# %%
# Desplazamiento de los datos de 'TotalPrice' a un período hacia adelante
retail2_df['ShiftedTotalPrice'] = retail2_df['TotalPrice'].shift(1)
# Visualización columnas implicadas
print(retail2_df[['TotalPrice', 'ShiftedTotalPrice']].head())
# Out:
#                      TotalPrice  ShiftedTotalPrice
# CleanedInvoiceDate
# 2010-01-12 09:56:00       14.85                NaN
# 2010-01-12 08:26:00       15.30              14.85
# 2010-01-12 14:53:00       12.50              15.30
# 2010-01-12 12:03:00       20.34              12.50
# 2010-01-12 14:27:00       29.70              20.34

# %% [markdown]
# ## Pregunta 35
# **Ventanas móviles:**
# - Calcule la media móvil de 3 períodos de `TotalPrice` en el dataset `retail`.

# %%
# Cálculo de la media móvil de 3 períodos para 'TotalPrice'
totalprice_moving_avg = retail2_df['TotalPrice'].rolling(window=3).mean()
retail2_df.insert(7, 'TotalPriceMoving3Avg', totalprice_moving_avg)
# Visualización comparativa 'TotalPrice' - 'TotalPriceMovingAvg'
print(retail2_df[['TotalPrice', 'TotalPriceMoving3Avg']].head())
# Out:
#                      TotalPrice  TotalPriceMoving3Avg
# CleanedInvoiceDate
# 2010-01-12 09:56:00       14.85                   NaN
# 2010-01-12 08:26:00       15.30                   NaN
# 2010-01-12 14:53:00       12.50             14.216667
# 2010-01-12 12:03:00       20.34             16.046667
# 2010-01-12 14:27:00       29.70             20.846667

# %% [markdown]
# ## Pregunta 36
# **Detección de tendencias:**
# - Detecte tendencias en la columna `TotalPrice` del dataset `retail` usando una ventana móvil de 12 períodos.

# %%
# Paso 4: Asegúrate de que el DataFrame esté ordenado por la columna 'InvoiceDate'
retail2_df.sort_index(inplace=True)
# Crear la columna de tendencia con la media móvil de 12 períodos
totalprice_moving12_avg = retail2_df['TotalPrice'].rolling(window=12).mean()
# Inserción de nueva columna con 12 periodos
retail2_df.insert(7, 'TotalPriceMoving12Avg', totalprice_moving12_avg)
# Visualización
#print(retail2_df[['CleanedInvoiceDate', 'TotalPrice', 'TotalPriceMoving12Avg']].head(15))
#retail2_df.head()
totalprice_moving12_avg = retail2_df['TotalPriceMoving12Avg']
print(totalprice_moving12_avg)
# Out:
# CleanedInvoiceDate
# 1900-01-01   NaN
# 1900-01-01   NaN
# 1900-01-01   NaN
# 1900-01-01   NaN
# 1900-01-01   NaN
#               ..
# NaT          NaN
# NaT          NaN
# NaT          NaN
# NaT          NaN
# NaT          NaN
# Name: TotalPriceMoving12Avg, Length: 386, dtype: float64

# %% [markdown]
# __GRÁFICO DE OBSERVACIÓN DE TENDENCIAS__

# %%
import matplotlib.pyplot as plt

# Tamaño del gráfico
plt.figure(figsize=(14, 7))
# Gráfico de la columna 'TotalPrice'
plt.plot(retail2_df.index, 
         retail2_df['TotalPrice'], 
         label='TotalPrice', 
         alpha=0.5)
# Gráfico de la media móvil 12 periodos
plt.plot(retail2_df.index, retail2_df['TotalPriceMoving12Avg'], 
         label='12-Month Rolling Mean', 
         color='orange')
# Configuración de los ejes y título
plt.xlabel('Fecha')
plt.ylabel('TotalPrice')
plt.title('Tendencia de TotalPrice con Media Móvil de 12 Períodos')
plt.legend()
plt.grid(True)
# Visualización del gráfico
plt.show()

# %% [markdown]
# - __Tendencia General__: A pesar de la volatilidad, la media móvil sugiere una tendencia ligeramente creciente en TotalPrice a lo largo del tiempo, especialmente a partir de cierto punto en el siglo XX. Sin embargo, esta tendencia no es muy pronunciada y está marcada por períodos de estabilidad y otros de mayor crecimiento.
# - __Anomalía Alrededor de 2010__: Se observa una anomalía significativa en los datos alrededor del año 2010, donde tanto TotalPrice como su media móvil experimentan un pico muy pronunciado. Esto podría indicar un evento o factor externo que causó un aumento abrupto en el valor de TotalPrice.

# %% [markdown]
# ## Pregunta 37
# **Descomposición de series temporales:**
# - Descomponga la serie temporal de `TotalPrice` en componentes de tendencia, estacionalidad y ruido.

# %%
# Importaciones
#   - matplotlib.pyplot
#   - statsmodels.tsa.seasonal 
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# La columna 'CleanedInvoiceDate' es el índice datetime del DataFrame
# retail2_df.set_index('CleanedInvoiceDate', inplace=True)
# Ordenación del DF por índice(fecha) para asegurarse de que la serie esté en orden cronológico
retail2_df = retail2_df.sort_index()
# Comprobación de que 'TotalPrice' no contiene valores nulos
retail2_df['TotalPrice'] = retail2_df['TotalPrice'].fillna(0)
# Descomposición de la serie temporal en 12 periodos
decomposition = seasonal_decompose(retail2_df['TotalPrice'], model='additive', period=12)

# Tamaño del gráfico
plt.figure(figsize=(14, 10))
# Gráfico de la serie original
plt.subplot(4, 1, 1)
plt.plot(decomposition.observed, label='Original')
plt.legend(loc='upper left')
plt.title('Descomposición de la Serie Temporal')
# Gráfico de la tendencia
plt.subplot(4, 1, 2)
plt.plot(decomposition.trend, label='Tendencia', color='orange')
plt.legend(loc='upper left')
# Gráfico de la estacionalidad
plt.subplot(4, 1, 3)
plt.plot(decomposition.seasonal, label='Estacionalidad', color='green')
plt.legend(loc='upper left')
# Gráfico del residuo
plt.subplot(4, 1, 4)
plt.plot(decomposition.resid, label='Ruido', color='red')
plt.legend(loc='upper left')
# Ajuste automático del espaciado entre los subgráficos(subplots) de una figura
plt.tight_layout()
# Visualización del plot
plt.show()

# %% [markdown]
# **************

# %% [markdown]
# __COMPROBACIÓN DE COLUMNA 'InvoiceNo' DUPLICADA__
#
# _¿QUÉ HACER?_

# %%
# Comprobar si hay duplicados en la columna 'InvoiceNo'
duplicates = retail2_df['InvoiceNo'].duplicated()
# Recoger las filas donde 'InvoiceNo' está duplicado
duplicated_rows = retail2_df[duplicates]
# Ver los registros duplicados
duplicated_rows
# Out:
#                      InvoiceNo                 StockCode  \
# CleanedInvoiceDate
# 2010-01-12 08:26:00   536365.0                    85123A
# 2010-01-12 08:26:00   536365.0                     21730
# 2010-01-12 08:26:00   536365.0                    84406B
# 2010-01-12 08:26:00   536365.0                     71053
# 2010-01-12 08:26:00   536365.0                    84029E
# 2010-01-12 08:26:00   536365.0                    84029G
# 2010-01-12 08:28:00   536366.0                     22633
# 2010-01-12 08:34:00   536367.0                     22310
# 2010-01-12 08:34:00   536367.0                     21754
# 2010-01-12 08:34:00   536367.0                     22749
# 2010-01-12 08:34:00   536367.0                     22745
# 2010-01-12 08:34:00   536367.0                     21755
# 2010-01-12 08:34:00   536367.0                     84879
# 2010-01-12 08:34:00   536367.0                     22622
# 2010-01-12 08:34:00   536367.0                     22623
# 2010-01-12 08:34:00   536367.0                     22748
# 2010-01-12 08:35:00   536368.0                     84988
# 2010-01-12 09:00:00   536370.0                     21723
# 2010-01-12 09:01:00   536371.0                     71053
# 2010-01-12 15:13:00   536743.0  LOVE BUILDING BLOCK WORD
# 2010-12-01 00:59:00   536370.0                     21724
#
#                                                      Description  UnitPrice  \
# CleanedInvoiceDate
# 2010-01-12 08:26:00           WHITE HANGING HEART T-LIGHT HOLDER       2.55
# 2010-01-12 08:26:00            GLASS STAR FROSTED T-LIGHT HOLDER     425.00
# 2010-01-12 08:26:00               CREAM CUPID HEARTS COAT HANGER       2.75
# 2010-01-12 08:26:00                          white metal lantern       3.39
# 2010-01-12 08:26:00         ***RED WOOLLY HOTTIE WHITE HEART.***       3.39
# 2010-01-12 08:26:00          KNITTED UNION FLAG HOT WATER BOTTLE       3.39
# 2010-01-12 08:28:00                       HAND WARMER UNION JACK       1.85
# 2010-01-12 08:34:00                       IVORY KNITTED MUG COSY       1.65
# 2010-01-12 08:34:00  ["description": "HOME BUILDING BLOCK WORD"]       5.95
# 2010-01-12 08:34:00            FELTCRAFT PRINCESS CHARLOTTE DOLL       3.75
# 2010-01-12 08:34:00              ***POPPY'S PLAYHOUSE BEDROOM***       2.10
# 2010-01-12 08:34:00                     LOVE BUILDING BLOCK WORD       5.95
# 2010-01-12 08:34:00                                          NaN       1.69
# 2010-01-12 08:34:00               BOX OF VINTAGE ALPHABET BLOCKS       9.95
# 2010-01-12 08:34:00               BOX OF VINTAGE JIGSAW BLOCKS         4.95
# 2010-01-12 08:34:00              ***POPPY'S PLAYHOUSE KITCHEN***       2.10
# 2010-01-12 08:35:00               set 2 tea towels i love london       4.95
# 2010-01-12 09:00:00           STRIPED CHARLIE+LOLA CHARLOTTE BAG       2.95
# 2010-01-12 09:01:00                          WHITE METAL LANTERN       3.39
# 2010-01-12 15:13:00                                          NaN       5.95
# 2010-12-01 00:59:00                        RED  HARMONICA IN BOX       1.25
#
#                      Quantity  TotalPrice  TotalPriceAvg  \
# CleanedInvoiceDate
# 2010-01-12 08:26:00       6.0       15.30          15.30
# 2010-01-12 08:26:00       6.0     2550.00        2550.00
# 2010-01-12 08:26:00       8.0       22.00          22.00
# 2010-01-12 08:26:00       6.0       20.34          20.34
# 2010-01-12 08:26:00       6.0       20.34          20.34
# 2010-01-12 08:26:00       6.0       20.34          20.34
# 2010-01-12 08:28:00       6.0       11.10          11.10
# 2010-01-12 08:34:00       6.0        9.90           9.90
# 2010-01-12 08:34:00       3.0       17.85          17.85
# 2010-01-12 08:34:00       8.0       30.00          30.00
# 2010-01-12 08:34:00       6.0       12.60          12.60
# 2010-01-12 08:34:00       3.0       17.85          17.85
# 2010-01-12 08:34:00      32.0       54.08          54.08
# 2010-01-12 08:34:00       2.0       19.90          19.90
# 2010-01-12 08:34:00       0.0      -14.85         -14.85
# 2010-01-12 08:34:00       6.0       12.60          12.60
# 2010-01-12 08:35:00       3.0       14.85          14.85
# 2010-01-12 09:00:00      20.0       59.00          59.00
# 2010-01-12 09:01:00       6.0       20.34          20.34
# 2010-01-12 15:13:00       3.0       17.85          17.85
# 2010-12-01 00:59:00      10.0       12.50          12.50
#
#                      TotalPriceMoving12Avg  TotalPriceMoving3Avg  \
# CleanedInvoiceDate
# 2010-01-12 08:26:00             231.579167                   NaN
# 2010-01-12 08:26:00             232.429167            860.980000
# 2010-01-12 08:26:00              14.692500           1071.500000
# 2010-01-12 08:26:00              21.304167             25.630000
# 2010-01-12 08:26:00                    NaN                   NaN
# 2010-01-12 08:26:00              21.624167             16.446667
# 2010-01-12 08:28:00             226.497500             20.200000
# 2010-01-12 08:34:00              17.302500             15.180000
# 2010-01-12 08:34:00              17.752500           6794.450000
# 2010-01-12 08:34:00              17.540000             28.080000
# 2010-01-12 08:34:00             227.110000             18.650000
# 2010-01-12 08:34:00             228.538333             15.250000
# 2010-01-12 08:34:00             228.745833             33.160000
# 2010-01-12 08:34:00             225.051667             26.433333
# 2010-01-12 08:34:00             224.218333              5.350000
# 2010-01-12 08:34:00             227.755000             14.966667
# 2010-01-12 08:35:00             281.690000             16.650000
# 2010-01-12 09:00:00             287.560833             30.266667
# 2010-01-12 09:01:00             284.749167             24.013333
# 2010-01-12 15:13:00              18.490000             25.750000
# 2010-12-01 00:59:00              27.393333                   NaN
#
#                      DiscountedPrice  ...  Discount  SaleChannel  \
# CleanedInvoiceDate                    ...
# 2010-01-12 08:26:00           13.770  ...     47.14     In-Store
# 2010-01-12 08:26:00         2295.000  ...      8.31       Online
# 2010-01-12 08:26:00           19.800  ...     11.02       Online
# 2010-01-12 08:26:00           18.306  ...     13.35       Online
# 2010-01-12 08:26:00           18.306  ...      0.23       Online
# 2010-01-12 08:26:00           18.306  ...     11.23     In-Store
# 2010-01-12 08:28:00            9.990  ...     43.49     In-Store
# 2010-01-12 08:34:00            8.910  ...     32.94       Online
# 2010-01-12 08:34:00           16.065  ...      1.97       Online
# 2010-01-12 08:34:00           27.000  ...     38.36     In-Store
# 2010-01-12 08:34:00           11.340  ...     47.31     In-Store
# 2010-01-12 08:34:00           16.065  ...     40.96     In-Store
# 2010-01-12 08:34:00           48.672  ...     28.29       Online
# 2010-01-12 08:34:00           17.910  ...      1.85     In-Store
# 2010-01-12 08:34:00          -13.365  ...     49.06       Online
# 2010-01-12 08:34:00           11.340  ...     10.39       Online
# 2010-01-12 08:35:00           13.365  ...      9.53     In-Store
# 2010-01-12 09:00:00           53.100  ...     43.74     In-Store
# 2010-01-12 09:01:00           18.306  ...     32.76       Online
# 2010-01-12 15:13:00           16.065  ...     21.39     In-Store
# 2010-12-01 00:59:00           11.250  ...     39.74     In-Store
#
#                      ReturnStatus  ProductWeight  ProductDimensions  \
# CleanedInvoiceDate
# 2010-01-12 08:26:00      Returned           3.30        31x24x99 cm
# 2010-01-12 08:26:00  Not Returned           1.83        47x68x76 cm
# 2010-01-12 08:26:00  Not Returned           9.63        25x13x82 cm
# 2010-01-12 08:26:00      Returned           6.47        77x81x40 cm
# 2010-01-12 08:26:00  Not Returned           6.87         5x33x65 cm
# 2010-01-12 08:26:00      Returned           5.25          5x3x53 cm
# 2010-01-12 08:28:00      Returned           1.79        27x63x17 cm
# 2010-01-12 08:34:00      Returned           1.03        38x51x63 cm
# 2010-01-12 08:34:00      Returned           7.97        57x67x88 cm
# 2010-01-12 08:34:00      Returned           9.14        40x11x36 cm
# 2010-01-12 08:34:00      Returned           7.32         5x12x90 cm
# 2010-01-12 08:34:00      Returned           1.10        70x88x33 cm
# 2010-01-12 08:34:00  Not Returned           3.94        77x28x69 cm
# 2010-01-12 08:34:00      Returned           9.67         20x5x37 cm
# 2010-01-12 08:34:00  Not Returned           7.53        93x22x68 cm
# 2010-01-12 08:34:00  Not Returned           1.95        62x94x95 cm
# 2010-01-12 08:35:00      Returned           0.15        17x84x88 cm
# 2010-01-12 09:00:00      Returned           7.05        45x17x26 cm
# 2010-01-12 09:01:00  Not Returned           4.79           6x5x5 cm
# 2010-01-12 15:13:00      Returned           8.24         8x95x21 cm
# 2010-12-01 00:59:00  Not Returned           1.52         2x88x72 cm
#
#                     ShippingCost    SalesRegion  PromotionCode  PaymentMethod  \
# CleanedInvoiceDate
# 2010-01-12 08:26:00         7.05         Europe        PROMO10    Credit Card
# 2010-01-12 08:26:00        13.56      Australia         SALE15      Gift Card
# 2010-01-12 08:26:00        19.87  North America            NaN      Gift Card
# 2010-01-12 08:26:00        18.91           Asia            NaN    Credit Card
# 2010-01-12 08:26:00        12.90      Australia         SALE15  Bank Transfer
# 2010-01-12 08:26:00        10.05      Australia        PROMO10      Gift Card
# 2010-01-12 08:28:00        17.22           Asia         SALE15      Gift Card
# 2010-01-12 08:34:00        12.79      Australia        PROMO10         PayPal
# 2010-01-12 08:34:00        14.12  North America            NaN    Credit Card
# 2010-01-12 08:34:00        14.02      Australia      DISCOUNT5  Bank Transfer
# 2010-01-12 08:34:00        16.00      Australia        PROMO20  Bank Transfer
# 2010-01-12 08:34:00         9.87  South America            NaN    Credit Card
# 2010-01-12 08:34:00        19.89  South America      DISCOUNT5           Cash
# 2010-01-12 08:34:00         8.85         Europe         SALE15  Bank Transfer
# 2010-01-12 08:34:00         8.13  North America        PROMO20    Credit Card
# 2010-01-12 08:34:00        17.43  South America            NaN           Cash
# 2010-01-12 08:35:00        18.01  North America      DISCOUNT5      Gift Card
# 2010-01-12 09:00:00        12.25           Asia        PROMO10           Cash
# 2010-01-12 09:01:00        15.96  South America        PROMO20         PayPal
# 2010-01-12 15:13:00        13.80      Australia        PROMO10           Cash
# 2010-12-01 00:59:00        14.29         Europe        PROMO10  Bank Transfer
#
#                     ShiftedTotalPrice
# CleanedInvoiceDate
# 2010-01-12 08:26:00             14.85
# 2010-01-12 08:26:00             20.34
# 2010-01-12 08:26:00           3180.00
# 2010-01-12 08:26:00             41.70
# 2010-01-12 08:26:00               NaN
# 2010-01-12 08:26:00             12.50
# 2010-01-12 08:28:00             29.70
# 2010-01-12 08:34:00             20.34
# 2010-01-12 08:34:00          20340.00
# 2010-01-12 08:34:00             33.90
# 2010-01-12 08:34:00             17.85
# 2010-01-12 08:34:00             12.60
# 2010-01-12 08:34:00             19.90
# 2010-01-12 08:34:00             25.50
# 2010-01-12 08:34:00             11.10
# 2010-01-12 08:34:00             17.00
# 2010-01-12 08:35:00             15.30
# 2010-01-12 09:00:00             15.30
# 2010-01-12 09:01:00             19.90
# 2010-01-12 15:13:00             29.70
# 2010-12-01 00:59:00               NaN
#
# [21 rows x 35 columns]

# %% [markdown]
# _____

# %% [markdown]
# ## Pregunta 38
# **Interpolación de datos faltantes:**
# - Interpole los valores faltantes en la columna `TotalPrice` utilizando la interpolación lineal.

# %%
# Verificación de los valores faltantes en la columna 'TotalPrice'
print(retail2_df['TotalPrice'].isna().sum())  # Ver cuántos valores faltantes hay
# Out:
# 0

# %%
# *** Como no existen valores faltantes, no es necesario aplicar la interpolación lineal

# Interpolación lineal en 'TotalPrice':
#   - rellenará los valores faltantes de forma lineal, 
#       basándose en los valores antes y después de los NaN
# retail2_df['TotalPrice'] = retail2_df['TotalPrice'].interpolate(method='linear')
# Verificación de valores faltantes después de la interpolación
# print(retail2_df['TotalPrice'].isna().sum())

# %%
# Visualización 'TotalPrice'
print(retail2_df[['TotalPrice']].head())
# Out:
#                     TotalPrice
# CleanedInvoiceDate
# 1900-01-01              -59.00
# 1900-01-01               16.50
# 1900-01-01               20.34
# 1900-01-01               25.50
# 1900-01-01               31.80

# %% [markdown]
# ## Pregunta 39
# **Análisis de autocorrelación:**
# - Realice un análisis de autocorrelación en la columna `TotalPrice` del dataset `retail`.

# %%
# Importaciones
import matplotlib.pyplot as plt
# También podemo usar 'autocorr()' de pandas
from statsmodels.graphics.tsaplots import plot_acf

# %%
# Paso realizado en la pregunta anterior
# Verificamos que no haya valores faltantes
# mediante interpolación lineal de 'TotalPrice'
# retail2_df['TotalPrice'] = retail2_df['TotalPrice'].interpolate(method='linear')

# %%
# Plot para análisis de autocorrelación
# 
plt.figure(figsize=(10, 6))
# Correlación de un valor de la serie temporal con sus valores anteriores (lags)
plot_acf(retail2_df['TotalPrice'], lags=40)  # 'lags' define cuántos rezagos (lags) se analizan
# Establecimiento del título
plt.title('Autocorrelación de TotalPrice')
# Establecimiento del título del eje X
plt.xlabel('Lags')
# Establecimiento del título del eje Y
plt.ylabel('Autocorrelación')
# Visualización del plot
plt.show()

# %% [markdown]
# __Análisis del gráfico:__
#
# 1. **Autocorrelación en el lag 0**:
#    - El valor en lag 0 es siempre 1, porque es la correlación de la serie con ella misma.
#
# 2. **Picos en los primeros lags**:
#    - Se observa un pico en los primeros lags, lo que indica que los valores del `TotalPrice` están correlacionados con valores cercanos en el tiempo, pero esta correlación disminuye rápidamente.
#
# 3. **Comportamiento en otros lags**:
#    - A medida que aumenta el lag, la autocorrelación disminuye y tiende hacia cero.
#    - Algunos valores fuera del intervalo de confianza sugieren posibles relaciones a ciertos lags, aunque en su mayoría la autocorrelación parece no ser significativa en lags mayores.
#
# 4. **Intervalos de confianza**:
#    - La zona sombreada indica el intervalo de confianza. Si los puntos caen dentro de esta área, la autocorrelación no es estadísticamente significativa. Algunos puntos están fuera de este intervalo, lo que indica autocorrelación significativa en esos casos.
#
# En resumen, el análisis sugiere que hay cierta correlación a corto plazo en los valores de `TotalPrice`, pero a medida que aumentan los lags, la autocorrelación desaparece.

# %% [markdown]
# ## Pregunta 40
# **Conversión de zona horaria:**
# - Convierta las fechas en la columna `InvoiceDate` a una zona horaria específica (por ejemplo, UTC) en el dataset `retail`.

# %%
# A) SI 'CleanedInvoiceDate' NO ES ÍNDICE:

# La columna 'CleanedInvoiceDate' ya ha sido convertida en tipo 'datetime'
# retail2_df['CleanedInvoiceDate'] = pd.to_datetime(retail2_df['CleanedInvoiceDate'])

# Establecimiento de la zona horaria actual para 'Europe/Madrid'
# retail2_df['CleanedInvoiceDate'] = retail2_df['CleanedInvoiceDate'].dt.tz_localize('Europe/Madrid')
# Conversión a la zona horaria UTC
# retail2_df['CleanedInvoiceDate'] = retail2_df['CleanedInvoiceDate'].dt.tz_convert('UTC')
# Verificación cambios
# print(retail2_df[['CleanedInvoiceDate']].head())

# %%
# Comprobamos los índices del DF
print(retail2_df.index.name)
# retail2_df.head()
# Out:
# CleanedInvoiceDate

# %%
# Verificación en índice antes de cambio zona horaria
print(retail2_df.index)
# Out:
# DatetimeIndex(['1900-01-01 00:00:00', '1900-01-01 00:00:00',
#                '1900-01-01 00:00:00', '1900-01-01 00:00:00',
#                '1900-01-01 00:00:00', '1900-01-01 00:00:00',
#                '1900-01-01 00:00:00', '1900-01-01 00:00:00',
#                '1900-01-01 00:00:00', '1900-01-01 00:00:00',
#                ...
#                '2050-01-01 00:00:00', '2050-01-01 00:00:00',
#                '2050-01-01 00:00:00', '2050-01-01 00:00:00',
#                '2050-01-01 00:00:00',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT'],
#               dtype='datetime64[ns]', name='CleanedInvoiceDate', length=386, freq=None)

# %%
# B) SI 'CleanedInvoiceDate' ES ÍNDICE:
# Si CleanedInvoiceDate ya es el índice, aplicamos la conversión directamente al índice

# Localización de la zona horaria original('Europe/Madrid')
retail2_df.index = retail2_df.index.tz_localize('Europe/Madrid')
# Conversión a la zona horaria UTC
retail2_df.index = retail2_df.index.tz_convert('UTC')
# Verificación en índice después de cambio zona horaria
print(retail2_df.index)
# Out:
# DatetimeIndex(['1900-01-01 00:15:00+00:00', '1900-01-01 00:15:00+00:00',
#                '1900-01-01 00:15:00+00:00', '1900-01-01 00:15:00+00:00',
#                '1900-01-01 00:15:00+00:00', '1900-01-01 00:15:00+00:00',
#                '1900-01-01 00:15:00+00:00', '1900-01-01 00:15:00+00:00',
#                '1900-01-01 00:15:00+00:00', '1900-01-01 00:15:00+00:00',
#                ...
#                '2049-12-31 23:00:00+00:00', '2049-12-31 23:00:00+00:00',
#                '2049-12-31 23:00:00+00:00', '2049-12-31 23:00:00+00:00',
#                '2049-12-31 23:00:00+00:00',                       'NaT',
#                                      'NaT',                       'NaT',
#                                      'NaT',                       'NaT'],
#               dtype='datetime64[ns, UTC]', name='CleanedInvoiceDate', length=386, freq=None)

# %% [markdown]
# # Parte 5 Preguntas de Negocio

# %% [markdown]
# ## Pregunta 1
# **Análisis de Retorno de Productos:**
# - ¿Cuál es el porcentaje de productos devueltos por país (United Kingdom, Germany, Denmark)? ¿Hay alguna diferencia notable entre los países?

# %%
# Número total de Filas por País

# Filtrado de filas con devoluciones
returned_df = retail2_df[retail2_df['ReturnStatus'] == 'Returned']
# Conteo total de filas por país
total_by_country = retail2_df.groupby('CleanedCountry').size()
# Visualización
print(total_by_country)
# Out:
# CleanedCountry
# United Kingdom                               140
# box of vintage alphabet blocks                 1
# box of vintage jigsaw blocks                   1
# chocolate hot water bottle                     1
# denmark                                      113
# england                                        4
# feltcraft princess charlotte doll              1
# germany                                      119
# knitted union flag hot water bottle            1
# red harmonica in box                           1
# scandinavian reds ribbons                      2
# striped charlielola charlotte bag details      1
# dtype: int64

# %%
# Número de devoluciones por país
returned_by_country = returned_df.groupby('CleanedCountry').size()
print(returned_by_country)
# Out:
# CleanedCountry
# United Kingdom                       72
# chocolate hot water bottle            1
# denmark                              48
# england                               3
# feltcraft princess charlotte doll     1
# germany                              61
# scandinavian reds ribbons             2
# dtype: int64

# %%
# Porcentaje de devoluciones por país
percentage_returned_by_country = (returned_by_country / total_by_country) * 100
print(percentage_returned_by_country)
# Out:
# CleanedCountry
# United Kingdom                                51.428571
# box of vintage alphabet blocks                      NaN
# box of vintage jigsaw blocks                        NaN
# chocolate hot water bottle                   100.000000
# denmark                                       42.477876
# england                                       75.000000
# feltcraft princess charlotte doll            100.000000
# germany                                       51.260504
# knitted union flag hot water bottle                 NaN
# red harmonica in box                                NaN
# scandinavian reds ribbons                    100.000000
# striped charlielola charlotte bag details           NaN
# dtype: float64

# %% [markdown]
# __Análisis del retorno de productos:__
#
# - Dado que en `'United Kingdom'` se devuelven el __51.43%__ de los pedidos, y en `'england'` el mismo porcentaje es de __75%__, tenienedo en cuenta que éste último está dentro del primero, podemos decir que las devoluciones en 'england' están muy por encima de las que se hacen en Gales, Escocia e Irlanda del Norte.
#
# - El __país con un menor porcentaje de devoluciones__, sobre la misma gama de productos, es `'denmark'`. Podríamos inferir que el índice de satisfacción es mayor.
#
# - `'england'` posee una notable diferencia con respecto al resto de paises con __diferencias de hasta 32 puntos porcentuales__. Mientras el resto se mueve en una horquilla mucho más parecida.
#
# - En términos generales, __los porcentajes de devolución son altos__, teniendo en cuenta que los porcentajes son en base a un número de pedidos diferente, lo que indica pesos diferentes de aquellos.

# %% [markdown]
# ## Pregunta 2
# **Impacto de Promociones:**
# - ¿Qué porcentaje de las ventas totales se realizaron utilizando códigos de promoción en cada uno de los tres países? ¿Cuál es el código de promoción más efectivo?

# %%
# Comprobación de columnas
# Búsqueda de 'PromotionCode'
print(retail2_df.columns)
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity',
#        'TotalPrice', 'TotalPriceAvg', 'TotalPriceMoving12Avg',
#        'TotalPriceMoving3Avg', 'DiscountedPrice', 'NormalizedTotalPrice',
#        'CustomerTotalPriceMovingAvg', 'InvoiceDate', 'InvoiceMonth',
#        'InvoiceYear', 'Country', 'CleanedCountry', 'CustomerID',
#        'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category',
#        'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus',
#        'ProductWeight', 'ProductDimensions', 'ShippingCost', 'SalesRegion',
#        'PromotionCode', 'PaymentMethod', 'ShiftedTotalPrice'],
#       dtype='object')

# %%
# Filtrado de filas con código de promoción no nulo
promotions_df = retail2_df[retail2_df['PromotionCode'].notna()]
promotions_df
# Out:
#                            InvoiceNo                       StockCode  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00   536588.0                           21723
# 1900-01-01 00:15:00+00:00   536380.0                           22112
# 1900-01-01 00:15:00+00:00   536425.0                           84969
# 1900-01-01 00:15:00+00:00   536544.0                           21777
# 1900-01-01 00:15:00+00:00   536636.0                           22748
# ...                              ...                             ...
# NaT                         536388.0                           22745
# NaT                         536584.0  SET 2 TEA TOWELS I LOVE LONDON
# NaT                         536475.0                           22748
# NaT                         536568.0                          84029E
# NaT                         536604.0                           21914
#
#                                                   Description  UnitPrice  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00  STRIPED CHARLIE+LOLA CHARLOTTE BAG       2.95
# 1900-01-01 00:15:00+00:00          CHOCOLATE HOT WATER BOTTLE       3.39
# 1900-01-01 00:15:00+00:00  BOX OF 6 ASSORTED COLOUR TEASPOONS       4.25
# 1900-01-01 00:15:00+00:00         RECIPE BOX WITH METAL HEART       7.95
# 1900-01-01 00:15:00+00:00           poppy's playhouse kitchen       2.10
# ...                                                       ...        ...
# NaT                           ***POPPY'S PLAYHOUSE BEDROOM***       2.10
# NaT                                                 ***nan***       4.95
# NaT                                 POPPY'S PLAYHOUSE KITCHEN     210.00
# NaT                            RED WOOLLY HOTTIE WHITE HEART.       3.39
# NaT                                     BLUE HARMONICA IN BOX       1.25
#
#                            Quantity  TotalPrice  TotalPriceAvg  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00       0.0      -59.00         -59.00
# 1900-01-01 00:15:00+00:00       6.0       20.34          20.34
# 1900-01-01 00:15:00+00:00       6.0       25.50          25.50
# 1900-01-01 00:15:00+00:00       4.0       31.80          31.80
# 1900-01-01 00:15:00+00:00       6.0       12.60          12.60
# ...                             ...         ...            ...
# NaT                             6.0       12.60          12.60
# NaT                             3.0       14.85          14.85
# NaT                            60.0    12600.00       12600.00
# NaT                             6.0       20.34          20.34
# NaT                            12.0       15.00          15.00
#
#                            TotalPriceMoving12Avg  TotalPriceMoving3Avg  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00                    NaN            -10.466667
# 1900-01-01 00:15:00+00:00                    NaN             36.346667
# 1900-01-01 00:15:00+00:00                    NaN           6808.166667
# 1900-01-01 00:15:00+00:00                    NaN             21.546667
# 1900-01-01 00:15:00+00:00                    NaN             17.800000
# ...                                          ...                   ...
# NaT                                          NaN             19.480000
# NaT                                          NaN             12.350000
# NaT                                          NaN           4224.766667
# NaT                                          NaN             26.180000
# NaT                                          NaN             31.166667
#
#                            DiscountedPrice  ...  Discount  SaleChannel  \
# CleanedInvoiceDate                          ...
# 1900-01-01 00:15:00+00:00          -53.100  ...      5.21     In-Store
# 1900-01-01 00:15:00+00:00           18.306  ...     47.78     In-Store
# 1900-01-01 00:15:00+00:00           22.950  ...     17.39       Online
# 1900-01-01 00:15:00+00:00           28.620  ...     41.49     In-Store
# 1900-01-01 00:15:00+00:00           11.340  ...     26.45     In-Store
# ...                                    ...  ...       ...          ...
# NaT                                 11.340  ...     27.54     In-Store
# NaT                                 13.365  ...      7.04     In-Store
# NaT                              11340.000  ...     24.82     In-Store
# NaT                                 18.306  ...     30.67     In-Store
# NaT                                 13.500  ...     35.28     In-Store
#
#                            ReturnStatus  ProductWeight  ProductDimensions  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00  Not Returned           0.41         3x23x18 cm
# 1900-01-01 00:15:00+00:00  Not Returned           4.79        93x63x54 cm
# 1900-01-01 00:15:00+00:00  Not Returned           9.41        90x18x70 cm
# 1900-01-01 00:15:00+00:00  Not Returned           3.74        78x53x51 cm
# 1900-01-01 00:15:00+00:00      Returned           3.66        85x92x62 cm
# ...                                 ...            ...                ...
# NaT                            Returned           1.81        54x47x87 cm
# NaT                            Returned           1.93        74x74x83 cm
# NaT                            Returned           3.56        40x15x21 cm
# NaT                        Not Returned           6.41        59x87x93 cm
# NaT                        Not Returned           5.08        87x59x72 cm
#
#                           ShippingCost    SalesRegion  PromotionCode  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00        10.39      Australia         SALE15
# 1900-01-01 00:15:00+00:00        19.91  South America        PROMO10
# 1900-01-01 00:15:00+00:00        10.99  North America      DISCOUNT5
# 1900-01-01 00:15:00+00:00         8.03  South America      DISCOUNT5
# 1900-01-01 00:15:00+00:00        17.09  South America        PROMO10
# ...                                ...            ...            ...
# NaT                              11.98  South America      DISCOUNT5
# NaT                              16.85  North America        PROMO10
# NaT                              11.06      Australia        PROMO10
# NaT                              10.86  North America      DISCOUNT5
# NaT                              16.47  North America         SALE15
#
#                            PaymentMethod ShiftedTotalPrice
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00           Cash             11.10
# 1900-01-01 00:15:00+00:00         PayPal             29.70
# 1900-01-01 00:15:00+00:00    Credit Card             59.00
# 1900-01-01 00:15:00+00:00    Credit Card             20.34
# 1900-01-01 00:15:00+00:00  Bank Transfer             15.30
# ...                                  ...               ...
# NaT                          Credit Card             25.50
# NaT                            Gift Card             11.10
# NaT                          Credit Card             15.30
# NaT                            Gift Card             41.70
# NaT                               PayPal             19.50
#
# [313 rows x 35 columns]

# %%
# Ventas totales por país (con y sin promoción)
total_sales_by_country = retail2_df.groupby('CleanedCountry')['TotalPrice'].sum()
total_sales_by_country
# Out:
# CleanedCountry
# United Kingdom                               121306.18
# box of vintage alphabet blocks                   19.90
# box of vintage jigsaw blocks                     14.85
# chocolate hot water bottle                       33.90
# denmark                                       47267.05
# england                                          67.95
# feltcraft princess charlotte doll                30.00
# germany                                       58900.86
# knitted union flag hot water bottle              20.34
# red harmonica in box                             12.50
# scandinavian reds ribbons                        33.00
# striped charlielola charlotte bag details        59.00
# Name: TotalPrice, dtype: float64

# %%
# Ventas con promoción por país
promo_sales_by_country = promotions_df.groupby('CleanedCountry')['TotalPrice'].sum()
# Porcentaje de ventas con promoción por país
promo_percentage_by_country = (promo_sales_by_country / total_sales_by_country) * 100
promo_percentage_by_country
# Out:
# CleanedCountry
# United Kingdom                                98.190562
# box of vintage alphabet blocks               100.000000
# box of vintage jigsaw blocks                 100.000000
# chocolate hot water bottle                          NaN
# denmark                                       98.904818
# england                                       73.730684
# feltcraft princess charlotte doll            100.000000
# germany                                       96.972744
# knitted union flag hot water bottle          100.000000
# red harmonica in box                         100.000000
# scandinavian reds ribbons                    100.000000
# striped charlielola charlotte bag details    100.000000
# Name: TotalPrice, dtype: float64

# %%
# Filtrado de países que nos interesan['United Kingdom', 'denmark', 'germany', 'england']
promo_percentage_by_country = promo_percentage_by_country.loc[['United Kingdom', 'denmark', 'germany', 'england']]
print(promo_percentage_by_country)
# Out:
# CleanedCountry
# United Kingdom    98.190562
# denmark           98.904818
# germany           96.972744
# england           73.730684
# Name: TotalPrice, dtype: float64

# %%
# Ventas totales por PromotionCode
promo_effectiveness = promotions_df.groupby('PromotionCode')['TotalPrice'].sum()
# Ordenación por ventas(>)
promo_effectiveness = promo_effectiveness.sort_values(ascending=False)
promo_effectiveness
# Out:
# PromotionCode
# SALE15       86947.77
# PROMO20      83498.16
# DISCOUNT5    53592.61
# PROMO10       -803.96
# Name: TotalPrice, dtype: float64

# %%
# Código de promoción más repetido
most_effective_promo = promo_effectiveness.idxmax()
print(f'El código de promoción más efectivo es: {most_effective_promo}')
# Out:
# El código de promoción más efectivo es: SALE15

# %% [markdown]
# ## Pregunta 3
# **Canales de Venta:**
# - ¿Cuál es la distribución de ventas entre los diferentes canales de venta (`SaleChannel`) en cada país? ¿Hay un canal que sea predominantemente más utilizado en alguno de los países?

# %%
# Agrupación de ventas por 
#   - país
#   - canal de venta
sales_by_country_channel = retail2_df.groupby(['CleanedCountry', 'SaleChannel'])['TotalPrice'].sum().unstack()
# Porcentaje de ventas por canal en cada país
sales_percentage_by_channel = sales_by_country_channel.div(sales_by_country_channel.sum(axis=1), axis=0) * 100
print(sales_percentage_by_channel)
# Out:
# SaleChannel                                  In-Store      Online
# CleanedCountry
# United Kingdom                              31.765447   68.234553
# box of vintage alphabet blocks                    NaN  100.000000
# box of vintage jigsaw blocks               100.000000         NaN
# chocolate hot water bottle                        NaN  100.000000
# denmark                                      9.030963   90.969037
# england                                     77.483444   22.516556
# feltcraft princess charlotte doll                 NaN  100.000000
# germany                                     51.514969   48.485031
# knitted union flag hot water bottle        100.000000         NaN
# red harmonica in box                              NaN  100.000000
# scandinavian reds ribbons                  100.000000         NaN
# striped charlielola charlotte bag details  100.000000         NaN

# %%
# Canal predominante por país
dominant_channel_by_country = sales_percentage_by_channel.idxmax(axis=1)
print(dominant_channel_by_country)
# Out:
# CleanedCountry
# United Kingdom                                 Online
# box of vintage alphabet blocks                 Online
# box of vintage jigsaw blocks                 In-Store
# chocolate hot water bottle                     Online
# denmark                                        Online
# england                                      In-Store
# feltcraft princess charlotte doll              Online
# germany                                      In-Store
# knitted union flag hot water bottle          In-Store
# red harmonica in box                           Online
# scandinavian reds ribbons                    In-Store
# striped charlielola charlotte bag details    In-Store
# dtype: object

# %% [markdown]
# ## Pregunta 4
# **Costos de Envío:**
# - ¿Cuál es el costo promedio de envío por país? ¿Existen diferencias significativas en los costos de envío entre los tres países?

# %%
# Comprobación de columnas
# Búsqueda de columna de 'costo promedio'
print(retail2_df.columns)
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity',
#        'TotalPrice', 'TotalPriceAvg', 'TotalPriceMoving12Avg',
#        'TotalPriceMoving3Avg', 'DiscountedPrice', 'NormalizedTotalPrice',
#        'CustomerTotalPriceMovingAvg', 'InvoiceDate', 'InvoiceMonth',
#        'InvoiceYear', 'Country', 'CleanedCountry', 'CustomerID',
#        'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category',
#        'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus',
#        'ProductWeight', 'ProductDimensions', 'ShippingCost', 'SalesRegion',
#        'PromotionCode', 'PaymentMethod', 'ShiftedTotalPrice'],
#       dtype='object')

# %% [markdown]
# __'ShippingCost'__

# %%
# Agrupación por país y costo promedio de envío
avg_shipping_cost_by_country = retail2_df.groupby('CleanedCountry')['ShippingCost'].mean()
print(avg_shipping_cost_by_country)
# Out:
# CleanedCountry
# United Kingdom                               12.293500
# box of vintage alphabet blocks               14.010000
# box of vintage jigsaw blocks                 15.150000
# chocolate hot water bottle                   13.250000
# denmark                                      12.808407
# england                                      12.105000
# feltcraft princess charlotte doll            17.010000
# germany                                      12.486218
# knitted union flag hot water bottle          16.140000
# red harmonica in box                         10.710000
# scandinavian reds ribbons                    14.060000
# striped charlielola charlotte bag details    11.680000
# Name: ShippingCost, dtype: float64

# %%
# Filtrado de países 
selected_countries = ['United Kingdom', 'denmark', 'germany', 'england']
# Costo promedio de envío en los países seleccionados
avg_shipping_selected = avg_shipping_cost_by_country[avg_shipping_cost_by_country.index.isin(selected_countries)]
print(avg_shipping_selected)

# Visualización gráfica
import matplotlib.pyplot as plt
# Gráfico de barras
avg_shipping_selected.plot(kind='bar', title="Costo promedio de envío por país", ylabel="Costo promedio de envío")
plt.show()
# Out:
# CleanedCountry
# United Kingdom    12.293500
# denmark           12.808407
# england           12.105000
# germany           12.486218
# Name: ShippingCost, dtype: float64

# %%
from scipy import stats

# Datos de costo de envío para los países seleccionados
uk_shipping = retail2_df[retail2_df['CleanedCountry'] == 'United Kingdom']['ShippingCost']
denmark_shipping = retail2_df[retail2_df['CleanedCountry'] == 'denmark']['ShippingCost']
germany_shipping = retail2_df[retail2_df['CleanedCountry'] == 'germany']['ShippingCost']
england_shipping = retail2_df[retail2_df['CleanedCountry'] == 'england']['ShippingCost']
# Test ANOVA
f_stat, p_value = stats.f_oneway(uk_shipping.dropna(), 
                                 denmark_shipping.dropna(), 
                                 germany_shipping.dropna(), 
                                 england_shipping.dropna())
print(f"F-Statistic: {f_stat}, P-Value: {p_value}")
# Out:
# F-Statistic: 0.3009455152996849, P-Value: 0.8247150877016478

# %% [markdown]
# - __F-Statistic: 0.3009455152996849 >>__ relación entre la variabilidad entre los grupos (diferencias en los costos de envío entre los países) y la variabilidad dentro de los grupos (variación dentro de los datos de costos de envío en cada país). Un valor bajo sugiere que las diferencias entre los grupos son relativamente pequeñas en comparación con la variación dentro de los grupos.
#
# - __P-Value: 0.8247150877016478 >>__ indica si las diferencias observadas entre los países son estadísticamente significativas. En este caso, el valor p es mayor a 0.05, lo que significa que no hay diferencias estadísticamente significativas en los costos de envío entre United Kingdom, denmark, germany y england.

# %% [markdown]
# ## Pregunta 5
# **Peso del Producto y Costos de Envío:**
# - ¿Existe una correlación entre el peso del producto (`ProductWeight`) y el costo de envío (`ShippingCost`)? ¿Cómo varía esta relación entre los diferentes países?

# %%
# Correlación general entre 'peso del producto' y 'costo de envío'
correlation_overall = retail2_df[['ProductWeight', 'ShippingCost']].corr(method='pearson')
print(correlation_overall)
# Out:
#                ProductWeight  ShippingCost
# ProductWeight       1.000000      0.011653
# ShippingCost        0.011653      1.000000

# %%
# Correlación entre 'peso del producto' y 'costo de envío por país'
correlation_by_country = retail2_df.groupby('CleanedCountry').apply(
    lambda x: x[['ProductWeight', 'ShippingCost']].corr(method='pearson').iloc[0, 1]
)
print(correlation_by_country)
# Out:
# CleanedCountry
# United Kingdom                               0.079098
# box of vintage alphabet blocks                    NaN
# box of vintage jigsaw blocks                      NaN
# chocolate hot water bottle                        NaN
# denmark                                     -0.049223
# england                                      0.667975
# feltcraft princess charlotte doll                 NaN
# germany                                     -0.006204
# knitted union flag hot water bottle               NaN
# red harmonica in box                              NaN
# scandinavian reds ribbons                   -1.000000
# striped charlielola charlotte bag details         NaN
# dtype: float64
# C:\Users\bytetech\AppData\Local\Temp\ipykernel_3396\1580442126.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   correlation_by_country = retail2_df.groupby('CleanedCountry').apply(

# %%
# Filtrado de datos para países deseados
filtered_countries = ['United Kingdom', 'denmark', 'germany', 'england']
filtered_df = retail2_df[retail2_df['CleanedCountry'].isin(filtered_countries)]
# Gráfico de dispersión con ajuste de línea de tendencia para PAISES SELECCIONADOS
sns.lmplot(x='ProductWeight', y='ShippingCost', hue='CleanedCountry', data=filtered_df, aspect=2)
plt.title('Relación entre el Peso del Producto y el Costo de Envío por País')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[272], line 5
#       3 filtered_df = retail2_df[retail2_df['CleanedCountry'].isin(filtered_countries)]
#       4 # Gráfico de dispersión con ajuste de línea de tendencia para PAISES SELECCIONADOS
# ----> 5 sns.lmplot(x='ProductWeight', y='ShippingCost', hue='CleanedCountry', data=filtered_df, aspect=2)
#       6 plt.title('Relación entre el Peso del Producto y el Costo de Envío por País')
#       7 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# __Conclusiones__
#
# - __Líneas de Confianza__: las bandas de confianza (el área sombreada en rojo alrededor de las líneas de tendencia) muestran la incertidumbre o variabilidad de las predicciones. En particular, la banda de England parece mucho más amplia que en otros países, lo que indica una mayor variabilidad en la relación entre el peso y el costo de envío en ese país.
#
# - __No se observa una correlación fuerte__ y consistente entre el peso del producto y el costo de envío en todos los países. 'england' parece ser el único país donde se percibe una tendencia positiva clara (correlación  peso-coste >> 0.667975)
#
# - __El peso no es siempre un factor determinante en el costo de envío__, y varía significativamente entre los países considerados

# %% [markdown]
# ## Pregunta 6
# **Descuentos y Comportamiento de Compra:**
# - ¿Qué porcentaje de las compras en cada país se realizaron con algún tipo de descuento (`Discount`)? ¿Los clientes en algún país en particular son más propensos a utilizar descuentos?

# %%
retail2_df.index.name
# Out:
# 'CleanedInvoiceDate'

# %%
print(retail2_df.columns)
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'Quantity',
#        'TotalPrice', 'TotalPriceAvg', 'TotalPriceMoving12Avg',
#        'TotalPriceMoving3Avg', 'DiscountedPrice', 'NormalizedTotalPrice',
#        'CustomerTotalPriceMovingAvg', 'InvoiceDate', 'InvoiceMonth',
#        'InvoiceYear', 'Country', 'CleanedCountry', 'CustomerID',
#        'CustomerName', 'Email', 'Address', 'PhoneNumber', 'Category',
#        'Supplier', 'StockLevel', 'Discount', 'SaleChannel', 'ReturnStatus',
#        'ProductWeight', 'ProductDimensions', 'ShippingCost', 'SalesRegion',
#        'PromotionCode', 'PaymentMethod', 'ShiftedTotalPrice'],
#       dtype='object')

# %%
retail2_df.head()
# Out:
#                            InvoiceNo StockCode  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00   536588.0     21723
# 1900-01-01 00:15:00+00:00   536598.0     22111
# 1900-01-01 00:15:00+00:00   536380.0     22112
# 1900-01-01 00:15:00+00:00   536425.0     84969
# 1900-01-01 00:15:00+00:00   536544.0     21777
#
#                                                   Description  UnitPrice  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00  STRIPED CHARLIE+LOLA CHARLOTTE BAG       2.95
# 1900-01-01 00:15:00+00:00           SCANDINAVIAN REDS RIBBONS       1.65
# 1900-01-01 00:15:00+00:00          CHOCOLATE HOT WATER BOTTLE       3.39
# 1900-01-01 00:15:00+00:00  BOX OF 6 ASSORTED COLOUR TEASPOONS       4.25
# 1900-01-01 00:15:00+00:00         RECIPE BOX WITH METAL HEART       7.95
#
#                            Quantity  TotalPrice  TotalPriceAvg  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00       0.0      -59.00         -59.00
# 1900-01-01 00:15:00+00:00      10.0       16.50          16.50
# 1900-01-01 00:15:00+00:00       6.0       20.34          20.34
# 1900-01-01 00:15:00+00:00       6.0       25.50          25.50
# 1900-01-01 00:15:00+00:00       4.0       31.80          31.80
#
#                            TotalPriceMoving12Avg  TotalPriceMoving3Avg  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00                    NaN            -10.466667
# 1900-01-01 00:15:00+00:00                    NaN             34.826667
# 1900-01-01 00:15:00+00:00                    NaN             36.346667
# 1900-01-01 00:15:00+00:00                    NaN           6808.166667
# 1900-01-01 00:15:00+00:00                    NaN             21.546667
#
#                            DiscountedPrice  ...  Discount  SaleChannel  \
# CleanedInvoiceDate                          ...
# 1900-01-01 00:15:00+00:00          -53.100  ...      5.21     In-Store
# 1900-01-01 00:15:00+00:00           14.850  ...      7.76       Online
# 1900-01-01 00:15:00+00:00           18.306  ...     47.78     In-Store
# 1900-01-01 00:15:00+00:00           22.950  ...     17.39       Online
# 1900-01-01 00:15:00+00:00           28.620  ...     41.49     In-Store
#
#                            ReturnStatus  ProductWeight  ProductDimensions  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00  Not Returned           0.41         3x23x18 cm
# 1900-01-01 00:15:00+00:00      Returned           0.73         5x82x92 cm
# 1900-01-01 00:15:00+00:00  Not Returned           4.79        93x63x54 cm
# 1900-01-01 00:15:00+00:00  Not Returned           9.41        90x18x70 cm
# 1900-01-01 00:15:00+00:00  Not Returned           3.74        78x53x51 cm
#
#                           ShippingCost    SalesRegion  PromotionCode  \
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00        10.39      Australia         SALE15
# 1900-01-01 00:15:00+00:00         8.16         Europe            NaN
# 1900-01-01 00:15:00+00:00        19.91  South America        PROMO10
# 1900-01-01 00:15:00+00:00        10.99  North America      DISCOUNT5
# 1900-01-01 00:15:00+00:00         8.03  South America      DISCOUNT5
#
#                           PaymentMethod ShiftedTotalPrice
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00          Cash             11.10
# 1900-01-01 00:15:00+00:00     Gift Card             33.90
# 1900-01-01 00:15:00+00:00        PayPal             29.70
# 1900-01-01 00:15:00+00:00   Credit Card             59.00
# 1900-01-01 00:15:00+00:00   Credit Card             20.34
#
# [5 rows x 35 columns]

# %%
# Comprobación visual de la columna 'Discount'
discount = retail2_df['Discount']
print(list(discount))
# Out:
# [5.21, 7.76, 47.78, 17.39, 41.49, 26.45, 3.81, 44.73, 18.67, 23.8, 23.37, 47.14, 8.31, 11.02, 13.35, 0.23, 11.23, 18.05, 43.49, 36.88, 32.94, 1.97, 38.36, 47.31, 40.96, 28.29, 1.85, 49.06, 10.39, 7.55, 9.53, 44.04, 43.74, 41.61, 32.76, 30.57, 46.04, 8.83, 0.91, 44.19, 8.69, 26.22, 37.5, 22.62, 4.28, 5.52, 37.91, 30.39, 36.17, 6.84, 14.72, 35.95, 15.96, 0.99, 12.27, 0.32, 4.27, 34.39, 5.13, 11.01, 21.07, 34.83, 14.35, 34.16, 12.16, 4.14, 21.81, 46.39, 11.5, 29.0, 28.24, 9.32, 10.26, 16.76, 29.03, 36.63, 36.11, 49.75, 28.83, 25.63, 33.4, 40.87, 46.22, 38.78, 40.79, 49.9, 4.47, 19.91, 5.33, 46.61, 43.1, 39.87, 6.5, 21.21, 1.06, 9.08, 47.24, 16.67, 24.92, 45.87, 30.93, 44.44, 15.05, 48.67, 7.63, 31.63, 0.89, 29.31, 1.22, 36.9, 34.8, 36.24, 31.05, 28.26, 12.97, 33.9, 1.11, 31.38, 21.62, 26.85, 43.65, 0.65, 32.57, 1.83, 40.14, 6.03, 14.66, 36.88, 41.23, 41.51, 27.08, 43.61, 20.94, 15.94, 34.87, 43.93, 9.26, 14.87, 24.03, 38.98, 28.4, 19.81, 20.89, 33.59, 45.77, 48.44, 45.74, 18.98, 47.42, 34.87, 27.71, 49.84, 11.65, 21.26, 25.37, 2.89, 11.68, 41.29, 0.55, 3.76, 43.5, 40.33, 29.17, 27.0, 13.54, 7.93, 4.12, 1.7, 33.18, 49.86, 43.59, 29.87, 6.84, 41.94, 2.1, 6.44, 1.35, 2.57, 22.61, 28.32, 45.99, 5.35, 29.56, 29.15, 14.43, 46.95, 14.82, 29.51, 35.42, 35.41, 13.11, 19.22, 20.47, 24.79, 20.42, 13.43, 14.86, 39.94, 7.43, 47.51, 13.7, 12.99, 10.32, 38.55, 29.77, 1.56, 27.6, 41.75, 10.91, 26.97, 29.75, 32.64, 25.29, 32.95, 17.28, 35.8, 36.61, 1.33, 17.09, 38.18, 11.04, 36.82, 20.73, 2.74, 2.29, 42.46, 13.4, 12.89, 29.51, 33.25, 49.22, 11.55, 20.04, 22.3, 0.65, 49.24, 41.45, 32.2, 34.42, 9.03, 49.56, 17.54, 17.35, 17.29, 24.37, 46.84, 7.67, 31.59, 3.39, 18.63, 8.58, 33.98, 39.97, 30.79, 11.53, 24.76, 45.42, 22.04, 46.6, 31.29, 29.11, 7.01, 3.29, 6.23, 12.32, 5.89, 45.0, 41.85, 42.78, 44.9, 21.74, 48.55, 26.87, 0.92, 12.48, 18.12, 11.94, 9.07, 43.09, 29.65, 17.51, 21.31, 19.86, 38.99, 3.35, 24.77, 29.62, 37.64, 44.63, 17.78, 43.68, 9.1, 34.01, 40.9, 11.19, 46.26, 5.66, 42.56, 7.81, 16.71, 31.21, 6.97, 43.11, 24.47, 40.0, 23.1, 30.34, 28.81, 47.5, 11.22, 26.28, 8.9, 48.05, 39.99, 29.81, 16.76, 43.96, 31.67, 3.27, 10.25, 45.71, 13.62, 34.68, 4.57, 4.58, 32.92, 29.84, 46.86, 49.2, 17.32, 43.42, 30.85, 49.39, 17.09, 31.61, 23.6, 8.18, 48.15, 8.77, 11.58, 13.28, 42.53, 11.1, 43.87, 23.71, 19.16, 25.11, 42.23, 34.81, 8.82, 3.37, 30.16, 21.39, 23.99, 35.36, 46.72, 24.43, 44.3, 12.99, 20.44, 27.98, 48.46, 4.97, 33.18, 46.12, 17.73, 39.74, 2.35, 34.61, 25.94, 44.82, 27.06, 47.21, 1.12, 19.95, 25.95, 32.48, 38.41, 47.36, 37.18, 10.5, 27.54, 7.04, 24.82, 30.67, 35.28]

# %%
# Filtrado de filas con descuento mayor que 0
retail2_df['HasDiscount'] = retail2_df['Discount'] > 0
# Porcentaje de compras con descuento agrupadas por país
discount_per_country = retail2_df.groupby('CleanedCountry')['HasDiscount'].mean() * 100
print("Porcentaje de compras con descuento por país:")
print(discount_per_country)
# Out:
# Porcentaje de compras con descuento por país:
# CleanedCountry
# United Kingdom                               100.0
# box of vintage alphabet blocks               100.0
# box of vintage jigsaw blocks                 100.0
# chocolate hot water bottle                   100.0
# denmark                                      100.0
# england                                      100.0
# feltcraft princess charlotte doll            100.0
# germany                                      100.0
# knitted union flag hot water bottle          100.0
# red harmonica in box                         100.0
# scandinavian reds ribbons                    100.0
# striped charlielola charlotte bag details    100.0
# Name: HasDiscount, dtype: float64

# %% [markdown]
# __Conclusiones__
#
# - Todas las filas poseen descuento, así que no hay diferencias entre paises, con un 100% de aplicación de descuentos en los pedidos de compra

# %% [markdown]
# ## Pregunta 7
# **Análisis de Categorías de Productos:**
# - ¿Cuáles son las categorías de productos (`Category`) más vendidas en cada país? ¿Existen diferencias en las preferencias de categorías de productos entre los países?

# %%
# Cantidad de productos vendidos agrupados por país y categoría
category_sales_per_country = retail2_df.groupby(['CleanedCountry', 'Category']).size().reset_index(name='SalesCount')
# Ordenación de mayor a menor en cantidad de ventas
top_categories_per_country = category_sales_per_country.sort_values(by=['CleanedCountry', 'SalesCount'], ascending=[True, False])
# VIsualización
print("Categorías más vendidas por país:\n")
print(top_categories_per_country)
#top_categories_per_country
# Out:
# Categorías más vendidas por país:
#
#                                CleanedCountry       Category  SalesCount
# 7                              United Kingdom           Toys          22
# 1                              United Kingdom         Beauty          21
# 0                              United Kingdom     Automotive          19
# 3                              United Kingdom       Clothing          18
# 6                              United Kingdom         Sports          18
# 2                              United Kingdom          Books          17
# 4                              United Kingdom    Electronics          15
# 5                              United Kingdom  Home & Garden          10
# 8              box of vintage alphabet blocks           Toys           1
# 9                box of vintage jigsaw blocks  Home & Garden           1
# 10                 chocolate hot water bottle  Home & Garden           1
# 15                                    denmark    Electronics          22
# 11                                    denmark     Automotive          19
# 16                                    denmark  Home & Garden          19
# 18                                    denmark           Toys          16
# 12                                    denmark         Beauty          10
# 14                                    denmark       Clothing          10
# 13                                    denmark          Books           9
# 17                                    denmark         Sports           8
# 19                                    england     Automotive           3
# 20                                    england           Toys           1
# 21          feltcraft princess charlotte doll           Toys           1
# 23                                    germany         Beauty          18
# 27                                    germany  Home & Garden          18
# 29                                    germany           Toys          18
# 26                                    germany    Electronics          17
# 24                                    germany          Books          15
# 25                                    germany       Clothing          12
# 22                                    germany     Automotive          11
# 28                                    germany         Sports          10
# 30        knitted union flag hot water bottle           Toys           1
# 31                       red harmonica in box     Automotive           1
# 32                  scandinavian reds ribbons     Automotive           1
# 33                  scandinavian reds ribbons  Home & Garden           1
# 34  striped charlielola charlotte bag details          Books           1

# %% [markdown]
# __Conclusiones por paises:__
#
# - `United Kingdom`
#     - tiene un interés más diversificado, con varias categorías importantes, especialmente productos para entretenimiento (juguetes, libros, deportes)
#     - principal categoría: 'Toys' >> 22
# - `denmark`
#     - parece estar más enfocado en Electronics, Automotive, y Home & Garden, lo que puede reflejar un interés más práctico en tecnología y mantenimiento del hogar.
#     - principal categoría: 'Electronics' >> 22
# - `germany`
#     - muestra un equilibrio entre categorías de cuidado personal (belleza), hogar, y juguetes, lo que refleja una mayor variabilidad en las preferencias de los consumidores.
#     - principal categoría: 'Beauty', 'Home & Garden' y 'Toys' >> 18
# - `england`
#     - tiene datos limitados, pero parece mostrar un interés específico en productos Automotive.
#     - principal categoría: 'Automotive' >> 3
#
# __Conclusión general:__
#
# Cada país tiene preferencias de consumo diferentes. Mientras que Reino Unido y Alemania parecen tener un enfoque más equilibrado entre categorías de entretenimiento, cuidado personal y automóviles, Dinamarca parece tener una mayor inclinación hacia tecnología, productos para el hogar y automóviles.

# %% [markdown]
# ## Pregunta 8
# **Rendimiento de Proveedores:**
# - ¿Cuál es el proveedor (`Supplier`) con el mayor volumen de ventas en cada país? ¿Cómo se distribuyen las ventas entre los diferentes proveedores en cada uno de los países?

# %%
# Volumen total de ventas por proveedor en cada país
supplier_sales = retail2_df.groupby(['CleanedCountry', 'Supplier'])['TotalPrice'].sum().reset_index()
# Proveedor con mayor volumen de ventas por país
top_supplier_per_country = supplier_sales.loc[supplier_sales.groupby('CleanedCountry')['TotalPrice'].idxmax()]
print(top_supplier_per_country)
# Out:
#                                CleanedCountry    Supplier  TotalPrice
# 0                              United Kingdom  Supplier A    79948.81
# 5              box of vintage alphabet blocks  Supplier E       19.90
# 6                box of vintage jigsaw blocks  Supplier C       14.85
# 7                  chocolate hot water bottle  Supplier A       33.90
# 8                                     denmark  Supplier A    45459.28
# 13                                    england  Supplier A       48.45
# 15          feltcraft princess charlotte doll  Supplier E       30.00
# 20                                    germany  Supplier E    20889.57
# 21        knitted union flag hot water bottle  Supplier D       20.34
# 22                       red harmonica in box  Supplier C       12.50
# 23                  scandinavian reds ribbons  Supplier E       33.00
# 24  striped charlielola charlotte bag details  Supplier E       59.00

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Gráfico de distribución de ventas por país y proveedor
plt.figure(figsize=(10,6))
sns.barplot(x='CleanedCountry', y='TotalPrice', hue='Supplier', data=supplier_sales)
plt.title('Distribución de ventas entre proveedores por país')
plt.ylabel('Volumen de Ventas (TotalPrice)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Pregunta 9
# **Promedio de Precios de Venta:**
# - ¿Cuál es el precio promedio de venta (`UnitPrice`) de los productos en cada país? ¿Existen diferencias significativas en los precios de venta entre los tres países?

# %%
# Precio promedio de venta (UnitPrice) por país
avg_unit_price_per_country = retail2_df.groupby('CleanedCountry')['UnitPrice'].mean().reset_index()
# Renombrado de columnas
avg_unit_price_per_country.columns = ['CleanedCountry', 'AvgUnitPrice']
print(avg_unit_price_per_country)
# Out:
#                                CleanedCountry  AvgUnitPrice
# 0                              United Kingdom     17.235373
# 1              box of vintage alphabet blocks      9.950000
# 2                box of vintage jigsaw blocks      4.950000
# 3                  chocolate hot water bottle      3.390000
# 4                                     denmark     16.939541
# 5                                     england      3.250000
# 6           feltcraft princess charlotte doll      3.750000
# 7                                     germany     30.427414
# 8         knitted union flag hot water bottle      3.390000
# 9                        red harmonica in box      1.250000
# 10                  scandinavian reds ribbons      1.650000
# 11  striped charlielola charlotte bag details      2.950000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Gráfico de barras para visualizar el precio promedio de venta por país
plt.figure(figsize=(10,6))
sns.barplot(x='CleanedCountry', y='AvgUnitPrice', data=avg_unit_price_per_country)
plt.title('Precio Promedio de Venta por País')
plt.ylabel('Precio Promedio (UnitPrice)')
plt.xticks(rotation=45)
plt.show()

# %%
# Primer Intento:

from scipy import stats

# Filtrado por países de interés
countries_of_interest = retail2_df[retail2_df['CleanedCountry'].isin(['United Kingdom', 'denmark', 'germany', 'england'])]
# Precios por país para la prueba ANOVA
uk_prices = countries_of_interest[countries_of_interest['CleanedCountry'] == 'United Kingdom']['UnitPrice']
denmark_prices = countries_of_interest[countries_of_interest['CleanedCountry'] == 'denmark']['UnitPrice']
germany_prices = countries_of_interest[countries_of_interest['CleanedCountry'] == 'germany']['UnitPrice']
england_prices = countries_of_interest[countries_of_interest['CleanedCountry'] == 'england']['UnitPrice']
# Prueba ANOVA
f_stat, p_value = stats.f_oneway(uk_prices, denmark_prices, germany_prices, england_prices)
print(f'F-Statistic: {f_stat}, P-Value: {p_value}')
# Out:
# F-Statistic: nan, P-Value: nan

# %%
# Verificación de valores nulos en columna
unitprice_nan = retail2_df['UnitPrice'].isna().sum()
unitprice_nan
# Out:
# np.int64(13)

# %%
# Rellenado con ceros para los valores nulos (NaN) en columna UnitPrice
retail2_df['UnitPrice'] = retail2_df['UnitPrice'].fillna(0)
# Verificación de valores nulos después de la operación
print(retail2_df['UnitPrice'].isnull().sum())
# Out:
# 0

# %%
# Segundo Intento:

from scipy import stats

# Filtrado por países de interés
countries_of_interest = retail2_df[retail2_df['CleanedCountry'].isin(['United Kingdom', 'denmark', 'germany', 'england'])]
# Precios por país para la prueba ANOVA
uk_prices = countries_of_interest[countries_of_interest['CleanedCountry'] == 'United Kingdom']['UnitPrice']
denmark_prices = countries_of_interest[countries_of_interest['CleanedCountry'] == 'denmark']['UnitPrice']
germany_prices = countries_of_interest[countries_of_interest['CleanedCountry'] == 'germany']['UnitPrice']
england_prices = countries_of_interest[countries_of_interest['CleanedCountry'] == 'england']['UnitPrice']
# Prueba ANOVA
f_stat, p_value = stats.f_oneway(uk_prices, denmark_prices, germany_prices, england_prices)
print(f'F-Statistic: {f_stat}, P-Value: {p_value}')
# Out:
# F-Statistic: 0.5084821194821703, P-Value: 0.6766571925859961

# %% [markdown]
# - __F-Statistic__: Un valor de `0.508` indica que la variación entre los precios promedio de los países es pequeña en comparación con la variación dentro de los países.
#
# - __P-Value__: Un valor de `0.677` es mayor que el nivel de significancia típico de 0.05. Esto significa que no se puede rechazar la hipótesis nula. En otras palabras, no hay evidencia estadísticamente significativa de que los precios promedio de venta (UnitPrice) difieran entre los países.

# %% [markdown]
# ## Pregunta 10
# **Tendencias de Venta por Región:**
# - ¿Cómo se distribuyen las ventas (`TotalPrice`) por región de ventas (`SalesRegion`) dentro de cada país? ¿Hay alguna región que destaque en términos de volumen de ventas en alguno de los países?

# %%
# Sumatorio de ventas totales por país y región
ventas_por_region = retail2_df.groupby(['CleanedCountry', 'SalesRegion'])['TotalPrice'].sum().reset_index()
# Región que destaca en volumen de ventas por país
ventas_max = ventas_por_region.loc[ventas_por_region.groupby('CleanedCountry')['TotalPrice'].idxmax()]
# Visualización
print("VENTAS POR REGIÓN:")
print(ventas_por_region)
print("\nREGIÓN PRINCIPAL POR PAÍS:")
print(ventas_max)
# Out:
# VENTAS POR REGIÓN:
#                                CleanedCountry    SalesRegion  TotalPrice
# 0                              United Kingdom           Asia    79826.55
# 1                              United Kingdom      Australia    39829.70
# 2                              United Kingdom         Europe      533.13
# 3                              United Kingdom  North America      551.52
# 4                              United Kingdom  South America      565.28
# 5              box of vintage alphabet blocks      Australia       19.90
# 6                box of vintage jigsaw blocks  North America       14.85
# 7                  chocolate hot water bottle  South America       33.90
# 8                                     denmark           Asia      321.69
# 9                                     denmark      Australia      559.33
# 10                                    denmark         Europe      449.39
# 11                                    denmark  North America    42139.11
# 12                                    denmark  South America     3797.53
# 13                                    england           Asia       15.30
# 14                                    england         Europe       19.50
# 15                                    england  North America       15.30
# 16                                    england  South America       17.85
# 17          feltcraft princess charlotte doll      Australia       30.00
# 18                                    germany           Asia     4903.34
# 19                                    germany      Australia    20701.54
# 20                                    germany         Europe      651.93
# 21                                    germany  North America    15796.82
# 22                                    germany  South America    16847.23
# 23        knitted union flag hot water bottle  South America       20.34
# 24                       red harmonica in box      Australia       12.50
# 25                  scandinavian reds ribbons  North America       16.50
# 26                  scandinavian reds ribbons  South America       16.50
# 27  striped charlielola charlotte bag details  North America       59.00
#
# REGIÓN PRINCIPAL POR PAÍS:
#                                CleanedCountry    SalesRegion  TotalPrice
# 0                              United Kingdom           Asia    79826.55
# 5              box of vintage alphabet blocks      Australia       19.90
# 6                box of vintage jigsaw blocks  North America       14.85
# 7                  chocolate hot water bottle  South America       33.90
# 11                                    denmark  North America    42139.11
# 14                                    england         Europe       19.50
# 17          feltcraft princess charlotte doll      Australia       30.00
# 19                                    germany      Australia    20701.54
# 23        knitted union flag hot water bottle  South America       20.34
# 24                       red harmonica in box      Australia       12.50
# 25                  scandinavian reds ribbons  North America       16.50
# 27  striped charlielola charlotte bag details  North America       59.00

# %% [markdown]
# __Región destacada por país:__
#
# - `United Kingdom`: __Asia__         79826.55
# - `denmark`: __North America__       42139.11
# - `england`: __Europe__              19.50

# %% [markdown]
# ## Pregunta 11
# **Análisis de Frecuencia de Compras:**
# - ¿Cuál es la frecuencia promedio de compras por cliente (`CustomerID`) en cada país? ¿Los clientes en algún país compran con mayor frecuencia?

# %%
# Frecuencia de compras por cliente en cada país
sales_frequency = retail2_df.groupby(['CleanedCountry', 'CustomerID'])['InvoiceNo'].count().reset_index()
# Frecuencia promedio de compras por cliente en cada país
frequency_avg = sales_frequency.groupby('CleanedCountry')['InvoiceNo'].mean().reset_index()
# Renombrado de columna
frequency_avg.columns = ['CleanedCountry', 'SalesAvgFrequency']
# País con mayor frecuencia de compras
most_frequent_country = frequency_avg.loc[frequency_avg['SalesAvgFrequency'].idxmax()]
# Visualización
print("FRECUENCIA PROMEDIO COMPRAS POR PAÍS:")
print(frequency_avg)
print("\nPAÍS CON MAYOR FRECUENCIA DE COMPRAS:")
print(most_frequent_country)
# Out:
# FRECUENCIA PROMEDIO COMPRAS POR PAÍS:
#                                CleanedCountry  SalesAvgFrequency
# 0                              United Kingdom           1.007194
# 1              box of vintage alphabet blocks           1.000000
# 2                box of vintage jigsaw blocks           1.000000
# 3                  chocolate hot water bottle           1.000000
# 4                                     denmark           1.000000
# 5                                     england           1.000000
# 6           feltcraft princess charlotte doll           1.000000
# 7                                     germany           1.000000
# 8         knitted union flag hot water bottle           1.000000
# 9                        red harmonica in box           1.000000
# 10                  scandinavian reds ribbons           1.000000
# 11  striped charlielola charlotte bag details           1.000000
#
# PAÍS CON MAYOR FRECUENCIA DE COMPRAS:
# CleanedCountry       United Kingdom
# SalesAvgFrequency          1.007194
# Name: 0, dtype: object

# %% [markdown]
# ## Pregunta 12
# **Valor de Vida del Cliente:**
# - ¿Cuál es el valor promedio de vida del cliente (suma de `TotalPrice`) en cada país? ¿Existe una diferencia significativa en el valor de vida del cliente entre los tres países?

# %%
# Valor total de vida del cliente por cliente y país
customer_life_value = retail2_df.groupby(['CleanedCountry', 'CustomerID'])['TotalPrice'].sum().reset_index()
# Valor promedio de vida del cliente en cada país
avg_value = customer_life_value.groupby('CleanedCountry')['TotalPrice'].mean().reset_index()
# Renombrado columna
avg_value.columns = ['CleanedCountry', 'AverageLifeCustomerValue']
# Visualización
print("Valor promedio de vida del cliente por país:")
print(avg_value)
# Out:
# Valor promedio de vida del cliente por país:
#                                CleanedCountry  AverageLifeCustomerValue
# 0                              United Kingdom                872.706331
# 1              box of vintage alphabet blocks                 19.900000
# 2                box of vintage jigsaw blocks                 14.850000
# 3                  chocolate hot water bottle                 33.900000
# 4                                     denmark                418.292478
# 5                                     england                 16.987500
# 6           feltcraft princess charlotte doll                 30.000000
# 7                                     germany                494.965210
# 8         knitted union flag hot water bottle                 20.340000
# 9                        red harmonica in box                 12.500000
# 10                  scandinavian reds ribbons                 16.500000
# 11  striped charlielola charlotte bag details                 59.000000

# %%
from scipy import stats

# Realizar ANOVA si hay más de un país
if avg_value.shape[0] > 1:
    anova_result = stats.f_oneway(*[grupo['TotalPrice'].values for nombre, 
                                    grupo in customer_life_value.groupby('CleanedCountry')])
    print("\nResultado de ANOVA:")
    print("Estadístico F:", anova_result.statistic)
    print("Valor p:", anova_result.pvalue)
else:
    print("\nNo hay suficientes países para realizar Test ANOVA.")
# Out:
# Resultado de ANOVA:
# Estadístico F: 0.06695072918688358
# Valor p: 0.9999889230224976

# %% [markdown]
# - El `Estadístico F: 0.06695072918688358` indica que __hay poca variación__ entre los promedios de vida de cliente entre los paises cuando hay variaciones en los promedios de vida de cliente dentro del país.
#
# - El `Valor p: 0.9999889230224976` indica que __no hay evidencia estadísticamente significativa__ de que los valores promedio de vida difieran entre los países.

# %% [markdown]
# ## Pregunta 13
# **Métodos de Pago:**
# - ¿Cuál es el método de pago (`PaymentMethod`) más utilizado en cada país? ¿Hay una preferencia notable por ciertos métodos de pago en algún país específico?

# %%
# Ocurrencias totales por método de pago y país
pay_methods = retail2_df.groupby(['CleanedCountry', 'PaymentMethod'])['InvoiceNo'].count().reset_index()
print(pay_methods)
# Out:
#                                CleanedCountry  PaymentMethod  InvoiceNo
# 0                              United Kingdom  Bank Transfer         36
# 1                              United Kingdom           Cash         24
# 2                              United Kingdom    Credit Card         20
# 3                              United Kingdom      Gift Card         36
# 4                              United Kingdom         PayPal         24
# 5              box of vintage alphabet blocks      Gift Card          1
# 6                box of vintage jigsaw blocks         PayPal          1
# 7                  chocolate hot water bottle    Credit Card          1
# 8                                     denmark  Bank Transfer         20
# 9                                     denmark           Cash         21
# 10                                    denmark    Credit Card         31
# 11                                    denmark      Gift Card         20
# 12                                    denmark         PayPal         21
# 13                                    england           Cash          2
# 14                                    england    Credit Card          1
# 15                                    england         PayPal          1
# 16          feltcraft princess charlotte doll      Gift Card          1
# 17                                    germany  Bank Transfer         24
# 18                                    germany           Cash         20
# 19                                    germany    Credit Card         26
# 20                                    germany      Gift Card         24
# 21                                    germany         PayPal         25
# 22        knitted union flag hot water bottle           Cash          1
# 23                       red harmonica in box  Bank Transfer          1
# 24                  scandinavian reds ribbons         PayPal          2
# 25  striped charlielola charlotte bag details           Cash          1

# %%
# Renombrado de columnas
pay_methods.columns = ['CleanedCountry', 'PaymentMethod', 'Count']
# Método de pago más utilizado agrupado por país
most_used_method = pay_methods.loc[pay_methods.groupby('CleanedCountry')['Count'].idxmax()].reset_index(drop=True)
# Visualización
print("Método de pago más utilizado por país:")
print(most_used_method)
# Out:
# Método de pago más utilizado por país:
#                                CleanedCountry  PaymentMethod  Count
# 0                              United Kingdom  Bank Transfer     36
# 1              box of vintage alphabet blocks      Gift Card      1
# 2                box of vintage jigsaw blocks         PayPal      1
# 3                  chocolate hot water bottle    Credit Card      1
# 4                                     denmark    Credit Card     31
# 5                                     england           Cash      2
# 6           feltcraft princess charlotte doll      Gift Card      1
# 7                                     germany    Credit Card     26
# 8         knitted union flag hot water bottle           Cash      1
# 9                        red harmonica in box  Bank Transfer      1
# 10                  scandinavian reds ribbons         PayPal      2
# 11  striped charlielola charlotte bag details           Cash      1

# %%
# Ocurrencias por método de pago y por país
pay_methods = retail2_df.groupby(['CleanedCountry', 'PaymentMethod'])['InvoiceNo'].count().reset_index()
# Columnas
pay_methods.columns = ['CleanedCountry', 'PaymentMethod', 'Count']
# Porcentaje de uso de cada método de pago por país
pay_methods['Percentage'] = pay_methods.groupby('CleanedCountry')['Count'].transform(lambda x: 100 * x / x.sum())
# Máyor porcentaje por país por un método de pago
remarkable_preferences = pay_methods.loc[pay_methods.groupby('CleanedCountry')['Percentage'].idxmax()].reset_index(drop=True)
print("\nPreferencias notables por método de pago en cada país (en %):")
print(remarkable_preferences)
# Out:
# Preferencias notables por método de pago en cada país (en %):
#                                CleanedCountry  PaymentMethod  Count  \
# 0                              United Kingdom  Bank Transfer     36
# 1              box of vintage alphabet blocks      Gift Card      1
# 2                box of vintage jigsaw blocks         PayPal      1
# 3                  chocolate hot water bottle    Credit Card      1
# 4                                     denmark    Credit Card     31
# 5                                     england           Cash      2
# 6           feltcraft princess charlotte doll      Gift Card      1
# 7                                     germany    Credit Card     26
# 8         knitted union flag hot water bottle           Cash      1
# 9                        red harmonica in box  Bank Transfer      1
# 10                  scandinavian reds ribbons         PayPal      2
# 11  striped charlielola charlotte bag details           Cash      1
#
#     Percentage
# 0    25.714286
# 1   100.000000
# 2   100.000000
# 3   100.000000
# 4    27.433628
# 5    50.000000
# 6   100.000000
# 7    21.848739
# 8   100.000000
# 9   100.000000
# 10  100.000000
# 11  100.000000

# %% [markdown]
# ## Pregunta 14
# **Evaluación de la Eficiencia de Descuentos:**
# - ¿Qué impacto tienen los descuentos (`Discount`) en el valor total de las ventas en cada país? ¿Los descuentos resultan en un aumento significativo en el volumen de ventas?

# %%
print(retail2_df['HasDiscount'])
# Out:
# CleanedInvoiceDate
# 1900-01-01 00:15:00+00:00    True
# 1900-01-01 00:15:00+00:00    True
# 1900-01-01 00:15:00+00:00    True
# 1900-01-01 00:15:00+00:00    True
# 1900-01-01 00:15:00+00:00    True
#                              ...
# NaT                          True
# NaT                          True
# NaT                          True
# NaT                          True
# NaT                          True
# Name: HasDiscount, Length: 386, dtype: bool

# %%
# Sumatorio del valor total de ventas por país
total_sales = retail2_df.groupby('CleanedCountry')['TotalPrice'].sum().reset_index()
total_sales
# Out:
#                                CleanedCountry  TotalPrice
# 0                              United Kingdom   121306.18
# 1              box of vintage alphabet blocks       19.90
# 2                box of vintage jigsaw blocks       14.85
# 3                  chocolate hot water bottle       33.90
# 4                                     denmark    47267.05
# 5                                     england       67.95
# 6           feltcraft princess charlotte doll       30.00
# 7                                     germany    58900.86
# 8         knitted union flag hot water bottle       20.34
# 9                        red harmonica in box       12.50
# 10                  scandinavian reds ribbons       33.00
# 11  striped charlielola charlotte bag details       59.00

# %%
# Sumatorio del valor total de ventas por país con y sin descuento 
discount_sales = retail2_df.groupby(['CleanedCountry', 'HasDiscount'])['TotalPrice'].sum().reset_index()

# %%
# Columnas
discount_sales.columns = ['CleanedCountry', 'HasDiscount', 'TotalSales']
print("Impacto de los descuentos en el 'VALOR TOTAL DE VENTAS' por país:")
print(discount_sales)
# Out:
# Impacto de los descuentos en el 'VALOR TOTAL DE VENTAS' por país:
#                                CleanedCountry  HasDiscount  TotalSales
# 0                              United Kingdom         True   121306.18
# 1              box of vintage alphabet blocks         True       19.90
# 2                box of vintage jigsaw blocks         True       14.85
# 3                  chocolate hot water bottle         True       33.90
# 4                                     denmark         True    47267.05
# 5                                     england         True       67.95
# 6           feltcraft princess charlotte doll         True       30.00
# 7                                     germany         True    58900.86
# 8         knitted union flag hot water bottle         True       20.34
# 9                        red harmonica in box         True       12.50
# 10                  scandinavian reds ribbons         True       33.00
# 11  striped charlielola charlotte bag details         True       59.00

# %%
# Número de transacciones por país con descuento o no
volumen_ventas_con_descuento = retail2_df.groupby(['CleanedCountry', 'HasDiscount'])['InvoiceNo'].count().reset_index()
# Columnas
volumen_ventas_con_descuento.columns = ['CleanedCountry', 'HasDiscount', 'NumTransactions']
# Visualización
print("Impacto de los descuentos en el 'VOLUMEN DE VENTAS' por país:")
print(volumen_ventas_con_descuento)
# Out:
# Impacto de los descuentos en el 'VOLUMEN DE VENTAS' por país:
#                                CleanedCountry  HasDiscount  NumTransactions
# 0                              United Kingdom         True              140
# 1              box of vintage alphabet blocks         True                1
# 2                box of vintage jigsaw blocks         True                1
# 3                  chocolate hot water bottle         True                1
# 4                                     denmark         True              113
# 5                                     england         True                4
# 6           feltcraft princess charlotte doll         True                1
# 7                                     germany         True              119
# 8         knitted union flag hot water bottle         True                1
# 9                        red harmonica in box         True                1
# 10                  scandinavian reds ribbons         True                2
# 11  striped charlielola charlotte bag details         True                1

# %%
from scipy import stats

# Filtrar ventas con y sin descuento
ventas_sin_descuento = retail2_df[retail2_df['Discount'] == 0]['TotalPrice']
ventas_con_descuento = retail2_df[retail2_df['Discount'] > 0]['TotalPrice']

# Realizar prueba t para ver si la diferencia es significativa
t_stat, p_value = stats.ttest_ind(ventas_con_descuento, ventas_sin_descuento, equal_var=False)

print("\nPrueba T:")
print(f"Estadístico T: {t_stat}")
print(f"Valor p: {p_value}")
print(f"Tamaño de ventas sin descuento: {len(ventas_sin_descuento)}")
print(f"Tamaño de ventas con descuento: {len(ventas_con_descuento)}")
# Out:
# Prueba T:
# Estadístico T: nan
# Valor p: nan
# Tamaño de ventas sin descuento: 0
# Tamaño de ventas con descuento: 386
# C:\Users\bytetech\AppData\Local\Temp\ipykernel_652\4269063838.py:8: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, p_value = stats.ttest_ind(ventas_con_descuento, ventas_sin_descuento, equal_var=False)

# %% [markdown]
# Al no tener datos de ventas SIN descuento('Tamaño de ventas sin descuento: 0') no podemos realizar la `Prueba T` ni `Prueba U de Mann-Whitney` para realizar comparaciones.

# %% [markdown]
# ## Pregunta 15
# **Análisis de Clientes por Región:**
# - ¿Cuál es la distribución de clientes (`CustomerID`) por región de ventas (`SalesRegion`) en cada país? ¿Hay regiones con una concentración notablemente mayor de clientes?

# %%
# Comprobación de duplicados en las combinaciones de CustomerID y SalesRegion
unique_customers = retail2_df[['CustomerID', 'CleanedCountry', 'SalesRegion']].drop_duplicates()
# Número de clientes únicos por país y región de ventas
customers_by_region = unique_customers.groupby(['CleanedCountry', 'SalesRegion'])['CustomerID'].nunique().reset_index()
# Columnas
customers_by_region.columns = ['CleanedCountry', 'SalesRegion', 'NumCustomers']
# Total de clientes por país para calcular las proporciones
total_customers_by_country = unique_customers.groupby('CleanedCountry')['CustomerID'].nunique().reset_index()
total_customers_by_country.columns = ['CleanedCountry', 'TotalCustomers']
# Combinación de los datos de clientes por región con el total de clientes por país
customers_by_region = pd.merge(customers_by_region, total_customers_by_country, on='CleanedCountry')
# Proporción de clientes en cada región
customers_by_region['CustomerProportion'] = 100 * (customers_by_region['NumCustomers'] / customers_by_region['TotalCustomers'])
# Visualización
print("Distribución de clientes por región de ventas en cada país:")
print(customers_by_region.sort_values(by=['CleanedCountry', 'CustomerProportion'], ascending=[True, False]))
# Out:
# Distribución de clientes por región de ventas en cada país:
#                                CleanedCountry    SalesRegion  NumCustomers  \
# 1                              United Kingdom      Australia            36
# 4                              United Kingdom  South America            31
# 3                              United Kingdom  North America            28
# 2                              United Kingdom         Europe            26
# 0                              United Kingdom           Asia            19
# 5              box of vintage alphabet blocks      Australia             1
# 6                box of vintage jigsaw blocks  North America             1
# 7                  chocolate hot water bottle  South America             1
# 12                                    denmark  South America            26
# 11                                    denmark  North America            24
# 9                                     denmark      Australia            22
# 10                                    denmark         Europe            22
# 8                                     denmark           Asia            19
# 13                                    england           Asia             1
# 14                                    england         Europe             1
# 15                                    england  North America             1
# 16                                    england  South America             1
# 17          feltcraft princess charlotte doll      Australia             1
# 19                                    germany      Australia            31
# 20                                    germany         Europe            27
# 18                                    germany           Asia            21
# 22                                    germany  South America            21
# 21                                    germany  North America            19
# 23        knitted union flag hot water bottle  South America             1
# 24                       red harmonica in box      Australia             1
# 25                  scandinavian reds ribbons  North America             1
# 26                  scandinavian reds ribbons  South America             1
# 27  striped charlielola charlotte bag details  North America             1
#
#     TotalCustomers  CustomerProportion
# 1              139           25.899281
# 4              139           22.302158
# 3              139           20.143885
# 2              139           18.705036
# 0              139           13.669065
# 5                1          100.000000
# 6                1          100.000000
# 7                1          100.000000
# 12             113           23.008850
# 11             113           21.238938
# 9              113           19.469027
# 10             113           19.469027
# 8              113           16.814159
# 13               4           25.000000
# 14               4           25.000000
# 15               4           25.000000
# 16               4           25.000000
# 17               1          100.000000
# 19             119           26.050420
# 20             119           22.689076
# 18             119           17.647059
# 22             119           17.647059
# 21             119           15.966387
# 23               1          100.000000
# 24               1          100.000000
# 25               2           50.000000
# 26               2           50.000000
# 27               1          100.000000

# %% [markdown]
# ## Pregunta 16
# **Promociones y Segmentos de Mercado:**
# - ¿Cuál es el código de promoción (`PromotionCode`) más utilizado en cada segmento de mercado (`SalesRegion`) dentro de cada país?

# %%
# Agrupar por país, región de ventas y código de promoción, y contar la frecuencia de uso
region_promotions = retail2_df.groupby(['CleanedCountry', 'SalesRegion', 'PromotionCode']).size().reset_index(name='PromotionCount')
# Código de promoción más utilizado en cada región de ventas
region_max_promotion = region_promotions.loc[region_promotions.groupby(['CleanedCountry', 'SalesRegion'])['PromotionCount'].idxmax()]
# Ordenación de resultados por país y región
region_max_promotion = region_max_promotion.sort_values(by=['CleanedCountry', 'SalesRegion']).reset_index(drop=True)
# Visualización
print("Código de promoción más utilizado en cada segmento de mercado (región de ventas) por país:")
print(region_max_promotion)
# Out:
# Código de promoción más utilizado en cada segmento de mercado (región de ventas) por país:
#                                CleanedCountry    SalesRegion PromotionCode  \
# 0                              United Kingdom           Asia       PROMO10
# 1                              United Kingdom      Australia        SALE15
# 2                              United Kingdom         Europe     DISCOUNT5
# 3                              United Kingdom  North America       PROMO20
# 4                              United Kingdom  South America     DISCOUNT5
# 5              box of vintage alphabet blocks      Australia       PROMO20
# 6                box of vintage jigsaw blocks  North America        SALE15
# 7                                     denmark           Asia        SALE15
# 8                                     denmark      Australia     DISCOUNT5
# 9                                     denmark         Europe       PROMO10
# 10                                    denmark  North America     DISCOUNT5
# 11                                    denmark  South America       PROMO10
# 12                                    england           Asia       PROMO20
# 13                                    england         Europe        SALE15
# 14                                    england  North America       PROMO10
# 15          feltcraft princess charlotte doll      Australia     DISCOUNT5
# 16                                    germany           Asia       PROMO10
# 17                                    germany      Australia       PROMO10
# 18                                    germany         Europe        SALE15
# 19                                    germany  North America     DISCOUNT5
# 20                                    germany  South America       PROMO10
# 21        knitted union flag hot water bottle  South America        SALE15
# 22                       red harmonica in box      Australia     DISCOUNT5
# 23                  scandinavian reds ribbons  North America       PROMO20
# 24                  scandinavian reds ribbons  South America     DISCOUNT5
# 25  striped charlielola charlotte bag details  North America     DISCOUNT5
#
#     PromotionCount
# 0                6
# 1               10
# 2                6
# 3                9
# 4               10
# 5                1
# 6                1
# 7                6
# 8                5
# 9                6
# 10               5
# 11               8
# 12               1
# 13               1
# 14               1
# 15               1
# 16               5
# 17              11
# 18              10
# 19               7
# 20               6
# 21               1
# 22               1
# 23               1
# 24               1
# 25               1

# %% [markdown]
# ## Pregunta 17
# **Análisis de Temporadas de Venta:**
# - ¿Existen patrones estacionales en las ventas (`InvoiceDate`) en cada país? ¿Hay picos de ventas en ciertos meses o temporadas en alguno de los países?

# %%
# Filtrar solo para los cuatro países: United Kingdom, Denmark, England, Germany
paises_seleccionados = ['United Kingdom', 'denmark', 'england', 'germany']
retail2_df_filtrado = retail2_df[retail2_df['CleanedCountry'].isin(paises_seleccionados)]
# Agrupar las ventas por país y mes, y calcular el total de ventas
ventas_mensuales = retail2_df_filtrado.groupby(['CleanedCountry', 'InvoiceYear', 'InvoiceMonth'])['TotalPrice'].sum().reset_index()
# Mostrar los primeros resultados
print("Ventas mensuales por país:")
print(ventas_mensuales.head())
# Graficar las ventas mensuales para cada uno de los cuatro países
for country in paises_seleccionados:
    country_data = ventas_mensuales[ventas_mensuales['CleanedCountry'] == country]
    
    plt.figure(figsize=(10,6))
    plt.plot(country_data['InvoiceMonth'], country_data['TotalPrice'], marker='o', label=f'Ventas en {country}')
    plt.title(f'Patrón Estacional de Ventas en {country}')
    plt.xlabel('Mes')
    plt.ylabel('Ventas Totales')
    plt.xticks(range(1, 13), ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'])
    plt.grid(True)
    plt.legend()
    plt.show()
# Out:
# Ventas mensuales por país:
#    CleanedCountry  InvoiceYear  InvoiceMonth  TotalPrice
# 0  United Kingdom            0             0       14.85
# 1  United Kingdom         1900             1      -20.10
# 2  United Kingdom         2010             1   121070.69
# 3  United Kingdom         2010             2       45.84
# 4  United Kingdom         2010            12      132.60

# %% [markdown]
# ## Pregunta 18
# **Preferencias de Productos:**
# - ¿Cuáles son los productos (`StockCode` y `Description`) más vendidos en cada país? ¿Hay diferencias notables en las preferencias de productos entre los países?

# %%
# Agrupación por país, código de producto y descripción, sumando la cantidad
products_by_country = retail2_df.groupby(['CleanedCountry', 'StockCode', 'Description'])['Quantity'].sum().reset_index()
print(products_by_country)
# Out:
#                                 CleanedCountry                  StockCode  \
# 0                               United Kingdom                      21723
# 1                               United Kingdom                      21723
# 2                               United Kingdom                      21724
# 3                               United Kingdom                      21730
# 4                               United Kingdom                      21731
# ..                                         ...                        ...
# 195                                    germany  HAND WARMER RED POLKA DOT
# 196        knitted union flag hot water bottle                     84029G
# 197                       red harmonica in box                      21724
# 198                  scandinavian reds ribbons                      22111
# 199  striped charlielola charlotte bag details                      21723
#
#                                      Description  Quantity
# 0       ***striped charlie+lola charlotte bag***      20.0
# 1             STRIPED CHARLIE+LOLA CHARLOTTE BAG     100.0
# 2                           RED HARMONICA IN BOX      50.0
# 3              GLASS STAR FROSTED T-LIGHT HOLDER       0.0
# 4            ***RED TOADSTOOL LED NIGHT LIGHT***      12.0
# ..                                           ...       ...
# 195                                        nan         6.0
# 196          KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 197                         RED HARMONICA IN BOX      10.0
# 198                    SCANDINAVIAN REDS RIBBONS      20.0
# 199  STRIPED CHARLIE+LOLA CHARLOTTE BAG: details      20.0
#
# [200 rows x 4 columns]

# %%
# Ordenación por cantidad de productos vendidos en cada país
products_by_country = products_by_country.sort_values(['CleanedCountry', 'Quantity'], ascending=[True, False])
print(products_by_country)
# Out:
#                                 CleanedCountry StockCode  \
# 61                              United Kingdom    84907B
# 9                               United Kingdom     21756
# 1                               United Kingdom     21723
# 56                              United Kingdom    84029G
# 5                               United Kingdom     21731
# ..                                         ...       ...
# 165                                    germany     22622
# 196        knitted union flag hot water bottle    84029G
# 197                       red harmonica in box     21724
# 198                  scandinavian reds ribbons     22111
# 199  striped charlielola charlotte bag details     21723
#
#                                            Description  Quantity
# 61                    PACK OF 12 RED RETROSPOT TISSUES     200.0
# 9                                  DOORMAT NEW ENGLAND     106.0
# 1                   STRIPED CHARLIE+LOLA CHARLOTTE BAG     100.0
# 56                 KNITTED UNION FLAG HOT WATER BOTTLE      78.0
# 5                        RED TOADSTOOL LED NIGHT LIGHT      60.0
# ..                                                 ...       ...
# 165  ["description": "BOX OF VINTAGE ALPHABET BLOCKS"]       2.0
# 196                KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 197                               RED HARMONICA IN BOX      10.0
# 198                          SCANDINAVIAN REDS RIBBONS      20.0
# 199        STRIPED CHARLIE+LOLA CHARLOTTE BAG: details      20.0
#
# [200 rows x 4 columns]

# %%
# Top 5 productos más vendidos por país
top_products_by_country = products_by_country.groupby('CleanedCountry').head(5)
print(top_products_by_country)
# Out:
#                                 CleanedCountry StockCode  \
# 61                              United Kingdom    84907B
# 9                               United Kingdom     21756
# 1                               United Kingdom     21723
# 56                              United Kingdom    84029G
# 5                               United Kingdom     21731
# 69              box of vintage alphabet blocks     22622
# 70                box of vintage jigsaw blocks     22623
# 71                  chocolate hot water bottle     22112
# 73                                     denmark     21723
# 90                                     denmark     22139
# 122                                    denmark     84879
# 80                                     denmark     21731
# 86                                     denmark     22111
# 131                                    england    85123A
# 130                                    england     21755
# 132          feltcraft princess charlotte doll     22749
# 133                                    germany     21723
# 149                                    germany     22111
# 176                                    germany     22748
# 135                                    germany     21724
# 146                                    germany     21914
# 196        knitted union flag hot water bottle    84029G
# 197                       red harmonica in box     21724
# 198                  scandinavian reds ribbons     22111
# 199  striped charlielola charlotte bag details     21723
#
#                                      Description  Quantity
# 61              PACK OF 12 RED RETROSPOT TISSUES     200.0
# 9                            DOORMAT NEW ENGLAND     106.0
# 1             STRIPED CHARLIE+LOLA CHARLOTTE BAG     100.0
# 56           KNITTED UNION FLAG HOT WATER BOTTLE      78.0
# 5                  RED TOADSTOOL LED NIGHT LIGHT      60.0
# 69                BOX OF VINTAGE ALPHABET BLOCKS       2.0
# 70                  BOX OF VINTAGE JIGSAW BLOCKS       3.0
# 71              ***CHOCOLATE HOT WATER BOTTLE***      10.0
# 73            STRIPED CHARLIE+LOLA CHARLOTTE BAG      80.0
# 90               RETROSPOT TEA SET CERAMIC 11 PC      72.0
# 122                ASSORTED COLOUR BIRD ORNAMENT      64.0
# 80                 RED TOADSTOOL LED NIGHT LIGHT      48.0
# 86                     SCANDINAVIAN REDS RIBBONS      40.0
# 131           WHITE HANGING HEART T-LIGHT HOLDER      12.0
# 130                     LOVE BUILDING BLOCK WORD       3.0
# 132      ***FELTCRAFT PRINCESS CHARLOTTE DOLL***       8.0
# 133           STRIPED CHARLIE+LOLA CHARLOTTE BAG     100.0
# 149                  SCANDINAVIAN  REDS  RIBBONS     100.0
# 176                    POPPY'S PLAYHOUSE KITCHEN      72.0
# 135                         RED HARMONICA IN BOX      60.0
# 146                        BLUE HARMONICA IN BOX      60.0
# 196          KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 197                         RED HARMONICA IN BOX      10.0
# 198                    SCANDINAVIAN REDS RIBBONS      20.0
# 199  STRIPED CHARLIE+LOLA CHARLOTTE BAG: details      20.0

# %% [markdown]
# ## Pregunta 19
# **Impacto de las Devoluciones en las Ventas:**
# - ¿Qué porcentaje de las ventas totales son afectadas por devoluciones (`ReturnStatus`)? ¿Cómo varía este porcentaje entre los diferentes países?

# %%
# Filtrar ventas devueltas
returns = retail2_df[retail2_df['ReturnStatus'] == 'Returned']
print(returns.shape)
# Out:
# (188, 35)

# %%
# Calcular el total de ventas por país
total_sales = retail2_df.groupby('CleanedCountry')['TotalPrice'].sum().reset_index(name='TotalSales')
print(total_sales)
# Out:
#                                CleanedCountry  TotalSales
# 0                              United Kingdom   121306.18
# 1              box of vintage alphabet blocks       19.90
# 2                box of vintage jigsaw blocks       14.85
# 3                  chocolate hot water bottle       33.90
# 4                                     denmark    47267.05
# 5                                     england       67.95
# 6           feltcraft princess charlotte doll       30.00
# 7                                     germany    58900.86
# 8         knitted union flag hot water bottle       20.34
# 9                        red harmonica in box       12.50
# 10                  scandinavian reds ribbons       33.00
# 11  striped charlielola charlotte bag details       59.00

# %%
# Calcular el total de ventas devueltas por país
returned_total_sales = returns.groupby('CleanedCountry')['TotalPrice'].sum().reset_index(name='ReturnedTotalSales')
print(returned_total_sales)
# Out:
#                       CleanedCountry  ReturnedTotalSales
# 0                     United Kingdom            18428.30
# 1         chocolate hot water bottle               33.90
# 2                            denmark            45900.91
# 3                            england               48.45
# 4  feltcraft princess charlotte doll               30.00
# 5                            germany            30489.35
# 6          scandinavian reds ribbons               33.00

# %%
# Combinar ambas tablas
returned_sales = total_sales.merge(returned_total_sales, on='CleanedCountry', how='left')
print(returned_sales)
# Out:
#                                CleanedCountry  TotalSales  ReturnedTotalSales
# 0                              United Kingdom   121306.18            18428.30
# 1              box of vintage alphabet blocks       19.90                 NaN
# 2                box of vintage jigsaw blocks       14.85                 NaN
# 3                  chocolate hot water bottle       33.90               33.90
# 4                                     denmark    47267.05            45900.91
# 5                                     england       67.95               48.45
# 6           feltcraft princess charlotte doll       30.00               30.00
# 7                                     germany    58900.86            30489.35
# 8         knitted union flag hot water bottle       20.34                 NaN
# 9                        red harmonica in box       12.50                 NaN
# 10                  scandinavian reds ribbons       33.00               33.00
# 11  striped charlielola charlotte bag details       59.00                 NaN

# %%
# Calcular el porcentaje de ventas afectadas por devoluciones
returned_sales['ReturnsAvg'] = (returned_sales['ReturnedTotalSales'] / returned_sales['TotalSales']) * 100
print(returned_sales[['CleanedCountry', 'ReturnsAvg']])
# Out:
#                                CleanedCountry  ReturnsAvg
# 0                              United Kingdom   15.191559
# 1              box of vintage alphabet blocks         NaN
# 2                box of vintage jigsaw blocks         NaN
# 3                  chocolate hot water bottle  100.000000
# 4                                     denmark   97.109741
# 5                                     england   71.302428
# 6           feltcraft princess charlotte doll  100.000000
# 7                                     germany   51.763845
# 8         knitted union flag hot water bottle         NaN
# 9                        red harmonica in box         NaN
# 10                  scandinavian reds ribbons  100.000000
# 11  striped charlielola charlotte bag details         NaN

# %% [markdown]
# ## Pregunta 20
# **Análisis de Margen de Ganancia:**
# - ¿Cuál es el margen de ganancia promedio (`UnitPrice - Discount`) por producto en cada país? ¿Hay productos o categorías con márgenes significativamente mayores o menores en alguno de los países?

# %%
# Margen de ganancia por producto (UnitPrice - Discount)
retail2_df['ProfitMargin'] = retail2_df['UnitPrice'] - retail2_df['Discount']
# Margen de ganancia promedio agrupando por país y producto
margen_por_pais_producto = retail2_df.groupby(['CleanedCountry', 'StockCode', 'Description'])['ProfitMargin'].mean().reset_index()
# Productos con mayores y menores márgenes por país
top_margenes = margen_por_pais_producto.groupby('CleanedCountry').apply(lambda x: x.nlargest(5, 'ProfitMargin')).reset_index(drop=True)
low_margenes = margen_por_pais_producto.groupby('CleanedCountry').apply(lambda x: x.nsmallest(5, 'ProfitMargin')).reset_index(drop=True)
# Visualización
print("A) PRODUCTOS con los MAYORES MÁRGENES de GANANCIA por país:\n")
print(top_margenes)

print("\nB) PRODUCTOS con los MENORES MÁRGENES de GANANCIA por país:\n")
print(low_margenes)
# Out:
# A) PRODUCTOS con los MAYORES MÁRGENES de GANANCIA por país:
#
#                                CleanedCountry StockCode  \
# 0                              United Kingdom     21756
# 1                              United Kingdom     21755
# 2                              United Kingdom    84029G
# 3                              United Kingdom    84907B
# 4                              United Kingdom     22622
# 5              box of vintage alphabet blocks     22622
# 6                box of vintage jigsaw blocks     22623
# 7                  chocolate hot water bottle     22112
# 8                                     denmark     21777
# 9                                     denmark     22139
# 10                                    denmark     22754
# 11                                    denmark     22745
# 12                                    denmark     22632
# 13                                    england    85123A
# 14                                    england     21755
# 15          feltcraft princess charlotte doll     22749
# 16                                    germany     21730
# 17                                    germany    84029E
# 18                                    germany     21777
# 19                                    germany     22745
# 20                                    germany     22111
# 21        knitted union flag hot water bottle    84029G
# 22                       red harmonica in box     21724
# 23                  scandinavian reds ribbons     22111
# 24  striped charlielola charlotte bag details     21723
#
#                                     Description  ProfitMargin
# 0                           DOORMAT NEW ENGLAND    382.945000
# 1                      LOVE BUILDING BLOCK WORD    181.863333
# 2           KNITTED UNION FLAG HOT WATER BOTTLE     64.907500
# 3              PACK OF 12 RED RETROSPOT TISSUES     63.930000
# 4              BOX OF VINTAGE ALPHABET BLOCKS        3.720000
# 5                BOX OF VINTAGE ALPHABET BLOCKS    -30.950000
# 6                  BOX OF VINTAGE JIGSAW BLOCKS     -7.320000
# 7              ***CHOCOLATE HOT WATER BOTTLE***    -43.560000
# 8                   RECIPE BOX WITH METAL HEART    787.450000
# 9               RETROSPOT TEA SET CERAMIC 11 PC    207.970000
# 10                     COFFEE MUG APPLES DESIGN      1.630000
# 11                  POPPY'S PLAYHOUSE BEDROOM        0.000000
# 12                  HAND WARMER RED POLKA DOT       -0.440000
# 13           WHITE HANGING HEART T-LIGHT HOLDER    -34.175000
# 14                     LOVE BUILDING BLOCK WORD    -35.010000
# 15      ***FELTCRAFT PRINCESS CHARLOTTE DOLL***    -42.370000
# 16            GLASS STAR FROSTED T-LIGHT HOLDER    416.690000
# 17               RED WOOLLY HOTTIE WHITE HEART.    314.230000
# 18                  RECIPE BOX WITH METAL HEART    246.510000
# 19                    POPPY'S PLAYHOUSE BEDROOM    180.250000
# 20                  SCANDINAVIAN  REDS  RIBBONS    135.490000
# 21          KNITTED UNION FLAG HOT WATER BOTTLE    -26.380000
# 22                         RED HARMONICA IN BOX    -25.750000
# 23                    SCANDINAVIAN REDS RIBBONS     -0.655000
# 24  STRIPED CHARLIE+LOLA CHARLOTTE BAG: details    -30.640000
#
# B) PRODUCTOS con los MENORES MÁRGENES de GANANCIA por país:
#
#                                CleanedCountry StockCode  \
# 0                              United Kingdom     22745
# 1                              United Kingdom     22632
# 2                              United Kingdom     22632
# 3                              United Kingdom     22633
# 4                              United Kingdom     84879
# 5              box of vintage alphabet blocks     22622
# 6                box of vintage jigsaw blocks     22623
# 7                  chocolate hot water bottle     22112
# 8                                     denmark     21731
# 9                                     denmark    84029E
# 10                                    denmark     21723
# 11                                    denmark     22749
# 12                                    denmark     71053
# 13                                    england     21755
# 14                                    england    85123A
# 15          feltcraft princess charlotte doll     22749
# 16                                    germany     22112
# 17                                    germany     21755
# 18                                    germany     21755
# 19                                    germany     22112
# 20                                    germany     22111
# 21        knitted union flag hot water bottle    84029G
# 22                       red harmonica in box     21724
# 23                  scandinavian reds ribbons     22111
# 24  striped charlielola charlotte bag details     21723
#
#                                     Description  ProfitMargin
# 0               ***POPPY'S PLAYHOUSE BEDROOM***       -45.210
# 1                   HAND WARMER RED POLKA DOT         -43.890
# 2               ***HAND WARMER RED POLKA DOT***       -42.780
# 3                        HAND WARMER UNION JACK       -41.640
# 4                 assorted colour bird ornament       -40.250
# 5                BOX OF VINTAGE ALPHABET BLOCKS       -30.950
# 6                  BOX OF VINTAGE JIGSAW BLOCKS        -7.320
# 7              ***CHOCOLATE HOT WATER BOTTLE***       -43.560
# 8               RED TOADSTOOL LED NIGHT LIGHT         -47.020
# 9            RED  WOOLLY  HOTTIE  WHITE  HEART.       -46.470
# 10           striped charlie+lola charlotte bag       -46.440
# 11            FELTCRAFT PRINCESS CHARLOTTE DOLL       -46.000
# 12       ["description": "WHITE METAL LANTERN"]       -45.050
# 13                     LOVE BUILDING BLOCK WORD       -35.010
# 14           WHITE HANGING HEART T-LIGHT HOLDER       -34.175
# 15      ***FELTCRAFT PRINCESS CHARLOTTE DOLL***       -42.370
# 16             ***CHOCOLATE HOT WATER BOTTLE***       -45.810
# 17                  LOVE  BUILDING  BLOCK  WORD       -40.310
# 18                        InvalidDescription123       -40.270
# 19          CHOCOLATE HOT WATER BOTTLE: details       -40.110
# 20                    SCANDINAVIAN REDS RIBBONS       -37.125
# 21          KNITTED UNION FLAG HOT WATER BOTTLE       -26.380
# 22                         RED HARMONICA IN BOX       -25.750
# 23                    SCANDINAVIAN REDS RIBBONS        -0.655
# 24  STRIPED CHARLIE+LOLA CHARLOTTE BAG: details       -30.640
# C:\Users\bytetech\AppData\Local\Temp\ipykernel_3396\3310667475.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_margenes = margen_por_pais_producto.groupby('CleanedCountry').apply(lambda x: x.nlargest(5, 'ProfitMargin')).reset_index(drop=True)
# C:\Users\bytetech\AppData\Local\Temp\ipykernel_3396\3310667475.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   low_margenes = margen_por_pais_producto.groupby('CleanedCountry').apply(lambda x: x.nsmallest(5, 'ProfitMargin')).reset_index(drop=True)
